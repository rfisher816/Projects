# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import ast
import json
# %matplotlib inline

# %%
movies = pd.read_csv('/Users/ryanfisher/Documents/Springboard/Springboard/Capstone 2/3405-6663-bundle-archive/movies_metadata.csv', header = 0).rename(columns={'id': 'movieId'})
# Out:
# /Users/ryanfisher/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movies
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage movieId    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45466 rows x 24 columns]

# %%
movies.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# movieId                   object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
movies[movies['revenue'] == 0]
# Out:
#        adult                              belongs_to_collection    budget  \
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 6      False                                                NaN  58000000
# 7      False                                                NaN         0
# 11     False                                                NaN         0
# 21     False                                                NaN         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 6      [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11     [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 21     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage movieId    imdb_id  \
# 2                                       NaN   15602  tt0113228
# 6                                       NaN   11860  tt0114319
# 7                                       NaN   45325  tt0112302
# 11                                      NaN   12110  tt0112896
# 21                                      NaN    1710  tt0112722
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 2                    en             Grumpier Old Men
# 6                    en                      Sabrina
# 7                    en                 Tom and Huck
# 11                   en  Dracula: Dead and Loving It
# 21                   en                      Copycat
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 6      An ugly duckling having undergone a remarkable...  ...   1995-12-15
# 7      A mischievous young boy, Tom Sawyer, witnesses...  ...   1995-12-22
# 11     When a lawyer shows up at the vampire's doorst...  ...   1995-12-22
# 21     An agoraphobic psychologist and a female detec...  ...   1995-10-27
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#       revenue runtime                                   spoken_languages  \
# 2         0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6         0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7         0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 11        0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 21        0.0   124.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...       ...     ...                                                ...
# 45461     0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462     0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463     0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464     0.0    87.0                                                 []
# 45465     0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 6      Released  You are cordially invited to the most surprisi...
# 7      Released                             The Original Bad Boys.
# 11     Released                                                NaN
# 21     Released  One man is copying the most notorious killers ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 2                 Grumpier Old Men  False          6.5       92.0
# 6                          Sabrina  False          6.2      141.0
# 7                     Tom and Huck  False          5.4       45.0
# 11     Dracula: Dead and Loving It  False          5.7      210.0
# 21                         Copycat  False          6.5      199.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [38052 rows x 24 columns]

# %%
mo

# %%
ratings = pd.read_csv('/Users/ryanfisher/Documents/Springboard/Springboard/Capstone 2/3405-6663-bundle-archive/ratings.csv', header = 0)

# %%
credits = pd.read_csv('/Users/ryanfisher/Documents/Springboard/Springboard/Capstone 2/3405-6663-bundle-archive/credits.csv', header = 0).rename(columns={'id': 'movieId'})

# %%
dfdict = {}
for i,m in movies.iterrows():
    if str(m['belongs_to_collection'])!='nan':
        #print(m['belongs_to_collection'])
        #print(m['belongs_to_collection'].replace("\'", "\""))
        print(m['belongs_to_collection'].split(",")[1].split(":")[1])
        #dfdict[i] = json.loads(m['belongs_to_collection'].replace("\'", "\"").replace('None',"\"None\""))
    else:
        dfdict[i] = None

    #for col in movies_in_collection_cols:
        #print(i)
        #dfdict[i]={}
        #dfdict[i][col] = m[col]
# Out:
#  'Toy Story Collection'
#  'Grumpy Old Men Collection'
#  'Father of the Bride Collection'
#  'James Bond Collection'
#  'Balto Collection'
#  'Ace Ventura Collection'
#  'Chili Palmer Collection'
#  'Babe Collection'
#  'Mortal Kombat Collection'
#  'Pocahontas Collection'
#  'The Lawnmower Man Collection'
#  'Friday Collection'
#  'From Dusk Till Dawn Collection'
#  'Screamers Collection'
#  'The Muppet Collection'
#  'The Neverending Story Collection'
#  'Bad Boys Collection'
#  'Batman Collection'
#  'Brooklyn Cigar Store Collection'
#  'Casper Collection'
#  'Mexico Trilogy'
#  'Die Hard Collection'
#  'Teenage Apocalypse Trilogy'
#  'Free Willy Collection'
#  'Power Rangers Collection'
#  'Síť (kolekce)'
#  'The Prophecy Collection'
#  'Showgirls Collection'
#  'Brooklyn Cigar Store Collection'
#  'Species Collection'
#  'Under Siege Collection'
#  'Burnt by the Sun Trilogy'
#  'Before... Collection'
#  'Clerks Collection'
#  'Dumb and Dumber Collection'
#  'A Goofy Movie Collection'
#  'The Vampire Chronicles'
#  'Star Wars Collection'
#  'Nemesis Collection'
#  'Once were Warriors Collection'
#  'Poison Ivy Collection'
#  'Three Colors Collection'
#  'Three Colors Collection'
#  'Three Colors Collection'
#  'Swan Princess Series'
#  'The Santa Clause Collection'
#  'Tales from the Crypt Collection'
#  'Star Trek
#  'Ace Ventura Collection'
#  'The Jack Ryan Collection'
#  'The Crow Collection'
#  'The Flintstones (Live-Action) Collection'
#  'The Lion King Collection'
#  'A Nightmare on Elm Street Collection'
#  'The Mask Collection'
#  'Naked Gun Collection'
#  'Richie Rich Collection'
#  'Speed Collection'
#  'Timecop Collection'
#  'Street Fighter'
#  'Fear Collection'
#  'Highlander Collection'
#  'Addams Family Collection'
#  'Stakeout Collection'
#  'Beverly Hills Cop Collection'
#  'City Slickers Collection'
#  'The Endless Summer Collection'
#  'Free Willy Collection'
#  'The Fugitive / U.S. Marshals Collection'
#  'Hard Target Collection'
#  'Hot Shots! Collection'
#  'House Party Collection'
#  'Jurassic Park Collection'
#  'The Karate Kid Collection'
#  'RoboCop Collection'
#  'The Secret Garden Collection'
#  'The Shadow Collection'
#  'Blade Runner Collection'
#  'The Brady Bunch Collection'
#  'Home Alone Collection'
#  'Aladdin Collection'
#  'The Terminator Collection'
#  'Batman Collection'
#  'The Hannibal Lecter Anthology'
#  'Beauty and the Beast Collection'
#  'Candyman Collection'
#  'Homeward Bound Collection'
#  'Heavy Metal Collection'
#  'Hellraiser Collection'
#  'All Dogs Go to Heaven Collection'
#  'Mission
#  'DragonHeart Collection'
#  'Bloodsport Collection'
#  'The Apu Collection'
#  'The Apu Collection'
#  'Lemmy Caution Collection'
#  'The Substitute Collection'
#  'The Visitors Collection'
#  'Ghost in the Shell Collection'
#  'Wallace & Gromit Collection'
#  'The Arrival Collection'
#  'Martin Scorsese’s World Cinema Project
#  'Trainspotting Collection'
#  'Independence Day Collection'
#  'The Hunchback of Notre Dame Collection'
#  'The Nutty Professor Collection'
#  'The Brady Bunch Collection'
#  'The Crow Collection'
#  'Tales from the Crypt Collection'
#  'Escape From ... Collection'
#  'The Godfather Collection'
#  'Police Story Collection'
#  'Police Story Collection'
#  'The Land Before Time Collection'
#  'Halloween Collection'
#  'The Space Odyssey Series'
#  'The Thin Man Collection'
#  'Living Dead Collection'
#  'In the Line of Duty Collection'
#  'The Mighty Ducks Collection'
#  'The Apple Dumpling Gang Collection'
#  'Davy Crockett Collection'
#  'Witch Mountain Collection'
#  'Herbie Collection'
#  'Herbie Collection'
#  'Parent Trap Collection'
#  'Homeward Bound Collection'
#  'The Shaggy Dog Collection'
#  'Cinderella Collection'
#  'Caballeros Collection'
#  'The Fox and the Hound Collection'
#  'Freeway Collection'
#  'Die Hard Collection'
#  'The Lawnmower Man Collection'
#  'Aladdin Collection'
#  'Dirty Dancing Collection'
#  "Weekend at Bernie's Collection"
#  'Basic Instinct Collection'
#  'Children of the Corn Collection'
#  'The Pink Panther (Original) Collection'
#  'Escape From ... Collection'
#  'The Howling Collection'
#  'The Water of the Hills Collection'
#  'The Water of the Hills Collection'
#  'Wallace & Gromit Collection'
#  'Best of the Best Collection'
#  'Cheech & Chong Collection'
#  'Star Wars Collection'
#  'Indiana Jones Collection'
#  'Alien Collection'
#  'The Man With No Name Collection'
#  'Star Wars Collection'
#  'Alien Collection'
#  'Evil Dead Collection'
#  'Psycho Collection'
#  'The Blues Brothers Collection'
#  'The Godfather Collection'
#  'Wallace & Gromit Collection'
#  'The Sting Collection'
#  'The Terminator Collection'
#  'The Jake Gittes Collection'
#  'Evil Dead Collection'
#  'Back to the Future Collection'
#  'Highlander Collection'
#  'Fantasia Collection'
#  'Qatsi Collection'
#  'Indiana Jones Collection'
#  'Alien Collection'
#  'The Amityville Horror Collection'
#  'The Amityville Horror Collection'
#  'The Amityville Horror Collection'
#  'The Amityville Horror Collection'
#  'The Amityville Horror Collection'
#  'The Amityville Horror Collection'
#  'The Amityville Horror Collection'
#  'The Blob Collection'
#  'Frankenstein (Universal Series)'
#  'Candyman Collection'
#  'Carrie Collection'
#  'A Nightmare on Elm Street Collection'
#  'The Omen Collection'
#  'Heart of Gold Collection'
#  'Star Trek
#  'Jingle All the Way Collection'
#  'Paradise Lost Collection'
#  '101 Dalmatians (Live-Action) Collection'
#  'Die Hard Collection'
#  'Star Trek
#  'Star Trek
#  'Star Trek
#  'Star Trek
#  'Star Trek
#  'Star Trek
#  'Batman Collection'
#  'Young Guns Collection'
#  'Young Guns Collection'
#  'Grease Collection'
#  'Grease Collection'
#  'Under Siege Collection'
#  'The Jaws Collection'
#  'The Jaws Collection'
#  'The Jaws Collection'
#  'Scream Collection'
#  'Turbulence Collection'
#  'Police Story Collection'
#  "McHale's Navy Collection"
#  "National Lampoon's Vacation Collection"
#  'The Saint Collection'
#  'Barrytown Trilogy'
#  'Power Rangers Collection'
#  'Anaconda Collection'
#  'Austin Powers Collection'
#  'Warriors of Virtue Collection'
#  'Teenage Apocalypse Trilogy'
#  'Jurassic Park Collection'
#  'Shiloh Collection'
#  'Speed Collection'
#  'Batman Collection'
#  'Tetsuo Collection'
#  'Men In Black Collection'
#  'Conan the Barbarian Collection'
#  'George of the Jungle Collection'
#  'Air Bud Collection'
#  'Free Willy Collection'
#  'Mimic Collection'
#  'The Jack Ryan Collection'
#  'Alex Cross Collection'
#  'Wishmaster Collection'
#  'I Know What You Did Last Summer Collection'
#  'Mr. Bean Collection'
#  'Starship Troopers Collection'
#  'Mortal Kombat Collection'
#  'Alien Collection'
#  'Les Boys'
#  'Home Alone Collection'
#  'Scream Collection'
#  'James Bond Collection'
#  'The Postman Collection'
#  '3 Ninjas Collection'
#  'The Prophecy Collection'
#  'The Blues Brothers Collection'
#  'The Fugitive / U.S. Marshals Collection'
#  'Wild Things Collection'
#  'Barney Collection'
#  'The Odd Couple Collection'
#  'Species Collection'
#  'Major League Collection'
#  'Henry Fool Collection'
#  'Mulan Collection'
#  'The X-Files Collection'
#  'Dr. Dolittle Collection'
#  'Lethal Weapon Collection'
#  'French Connection Collection'
#  'Rocky Collection'
#  'A Nightmare on Elm Street Collection'
#  'A Nightmare on Elm Street Collection'
#  'A Nightmare on Elm Street Collection'
#  'A Nightmare on Elm Street Collection'
#  'A Nightmare on Elm Street Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Friday the 13th Collection'
#  'Halloween Collection'
#  'Halloween Collection'
#  'Halloween Collection'
#  'Halloween Collection'
#  'Halloween Collection'
#  'Prom Night Collection'
#  'Prom Night Collection'
#  'Prom Night Collection'
#  'Prom Night Collection'
#  "Child's Play Collection"
#  "Child's Play Collection"
#  "Child's Play Collection"
#  'Poltergeist Collection'
#  'Poltergeist Collection'
#  'Poltergeist Collection'
#  'The Exorcist Collection'
#  'The Exorcist Collection'
#  'The Exorcist Collection'
#  'Lethal Weapon Collection'
#  'Lethal Weapon Collection'
#  'Lethal Weapon Collection'
#  'The Gremlins Collection'
#  'The Gremlins Collection'
#  'Zorro Collection'
#  'Back to the Future Collection'
#  'Back to the Future Collection'
#  'The Poseidon Adventure Collection'
#  'Flubber Collection'
#  'The Apple Dumpling Gang Collection'
#  'Bambi Collection'
#  'The Godfather Collection'
#  'Dexter Riley Collection'
#  'The Mighty Ducks Collection'
#  'Herbie Collection'
#  'Herbie Collection'
#  'Honey
#  'Honey
#  'The Jungle Book Collection'
#  'Lady and the Tramp Collection'
#  'The Little Mermaid Collection'
#  'The Mighty Ducks Collection'
#  'The Muppet Collection'
#  '101 Dalmatians (Animated) Collection'
#  'Peter Pan Collection'
#  'The Rescuers Collection'
#  'The Rescuers Collection'
#  'Witch Mountain Collection'
#  'Aladdin Collection'
#  'The Shaggy Dog Collection'
#  'Flubber Collection'
#  'Splash Collection'
#  'TRON Collection'
#  'Halloween Collection'
#  'Indiana Jones Collection'
#  'The Lord of the Rings Animated Collection'
#  'Children of the Corn Collection'
#  'All Dogs Go to Heaven Collection'
#  'Addams Family Collection'
#  "Charlotte's Web Collection"
#  'The Secret Of NIMH Collection'
#  'Fievel Collection'
#  'Fievel Collection'
#  'House Collection'
#  'House Collection'
#  'The Gods Must Be Crazy Collection'
#  'The Gods Must Be Crazy Collection'
#  'Air Bud Collection'
#  'Henry
#  'Henry
#  "Rosemary's Baby Collection"
#  'The Neverending Story Collection'
#  'The Neverending Story Collection'
#  'Killer Tomatoes! Collection'
#  'Blade Collection'
#  'Cube Collection'
#  'Rush Hour Collection'
#  'Urban Legend'
#  'The Thing Collection'
#  'The Space Odyssey Series'
#  "Child's Play Collection"
#  'Vampires Collection'
#  'Elizabeth Collection'
#  'I Know What You Did Last Summer Collection'
#  'Stepford Collection'
#  'Rugrats Collection'
#  'Godzilla (Showa) Collection'
#  'Godzilla (Heisei) Collection'
#  'Godzilla (Showa) Collection'
#  'King Kong (1933 series)'
#  'King Kong (1976 series)'
#  'King Kong (1976 series)'
#  'Fletch Collection'
#  'Fletch Collection'
#  'Conan the Barbarian Collection'
#  'James Bond Collection'
#  'Police Academy Collection'
#  'Police Academy Collection'
#  'Police Academy Collection'
#  'Police Academy Collection'
#  'Police Academy Collection'
#  'Police Academy Collection'
#  'Babe Collection'
#  'Star Trek
#  'Rambo Collection'
#  'Rambo Collection'
#  'Rambo Collection'
#  'Romancing the Stone Collection'
#  'Romancing the Stone Collection'
#  'Cocoon Collection'
#  'Cocoon Collection'
#  'Rocky Collection'
#  'Rocky Collection'
#  'Rocky Collection'
#  'Rocky Collection'
#  'The Karate Kid Collection'
#  'The Karate Kid Collection'
#  'The Karate Kid Collection'
#  "National Lampoon's Vacation Collection"
#  'The Gate Collection'
#  'The Gate Collection'
#  'The Fly (1958 series)'
#  'The Fly Collection'
#  'The Fly Collection'
#  'Texas Chainsaw Massacre Collection'
#  'Texas Chainsaw Massacre Collection'
#  'Texas Chainsaw Massacre Collection'
#  'Texas Chainsaw Massacre Collection'
#  'Crocodile Dundee Collection'
#  'Crocodile Dundee Collection'
#  'The Hustler Collection'
#  '8MM Collection'
#  'Pet Sematary Collection'
#  'Pet Sematary Collection'
#  'Children of the Corn Collection'
#  'Children of the Corn Collection'
#  'Airport Collection'
#  'Airport Collection'
#  'Airport Collection'
#  'Alligator Collection'
#  'Westworld Collection'
#  'Planet of the Apes Original Collection'
#  'Planet of the Apes Original Collection'
#  'Planet of the Apes Original Collection'
#  'Planet of the Apes Original Collection'
#  'Planet of the Apes Original Collection'
#  'Airport Collection'
#  'The Poseidon Adventure Collection'
#  'Analyze Collection'
#  'Cruel Intentions Collection'
#  'Carrie Collection'
#  'The Matrix Collection'
#  'The Mummy Collection'
#  'The Black Mask Collection'
#  'Star Wars Collection'
#  'The Mummy (Universal Series)'
#  'The Mummy (Hammer Series)'
#  'The Mummy (Universal Series)'
#  'The Mummy (Universal Series)'
#  'The Mummy (Universal Series)'
#  'The Mummy (Universal Series)'
#  'Superman Collection'
#  'Superman Collection'
#  'Superman Collection'
#  'Superman Collection'
#  'Dracula (Universal Series)'
#  'Dracula (Universal Series)'
#  'Frankenstein (Universal Series)'
#  'Frankenstein (Universal Series)'
#  'Frankenstein (Universal Series)'
#  'Frankenstein (Universal Series)'
#  'The Wolf Man (Universal Series)'
#  'Frankenstein (Hammer Series)'
#  'Dracula (Universal Series)'
#  'The Wolf Man (Universal Series)'
#  'The Howling Collection'
#  'Rocky Horror Collection'
#  'Swamp Thing Collection'
#  'Austin Powers Collection'
#  'Tarzan (Animation) Collection'
#  'American Pie Collection'
#  'Tales of the Four Seasons'
#  'The Muppet Collection'
#  'Blair Witch Collection'
#  'Lake Placid Collection'
#  'Ghostbusters Collection'
#  'Ghostbusters Collection'
#  'Inspector Gadget Collection'
#  'The Adventures of Antoine Doinel'
#  'Allan Quatermain Collection'
#  'The Omen Collection'
#  'The Omen Collection'
#  'Airplane Collection'
#  'Airplane Collection'
#  "National Lampoon's Vacation Collection"
#  "National Lampoon's Vacation Collection"
#  'Problem Child Collection'
#  'Problem Child Collection'
#  'A Christmas Story Collection'
#  'Universal Soldier Collection'
#  'Universal Soldier Collection'
#  'Iron Eagle Collection'
#  'Iron Eagle Collection'
#  'Iron Eagle Collection'
#  'Iron Eagle Collection'
#  'The Spiders Serial'
#  'Stir of Echoes Collection'
#  'Fright Night Collection'
#  'Fright Night Collection'
#  'Armour of God Collection'
#  'Armour of God Collection'
#  'Phantasm Collection'
#  'Psycho Collection'
#  'Psycho Collection'
#  'Drunken Master Collection'
#  'The Dirty Dozen Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'The Blue Lagoon collection'
#  'The Man With No Name Collection'
#  'Home Alone Collection'
#  'Penitenciaría - Colección'
#  'Penitenciaría - Colección'
#  'Omega Code Series'
#  'Bats Collection'
#  'The Best Man Collection'
#  'Harry Palmer Collection'
#  'On Any Sunday Collection'
#  'RoboCop Collection'
#  'RoboCop Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'House on Haunted Hill Collection'
#  'Re-Animator Collection'
#  'Creepshow Collection'
#  'Creepshow Collection'
#  'Re-Animator Collection'
#  'Piranha Collection'
#  'Mister Roberts Collection'
#  'Meatballs Collection'
#  'Meatballs Collection'
#  'Meatballs Collection'
#  'Meatballs Collection'
#  'Pokémon Collection'
#  'Barrytown Trilogy'
#  'Poison Ivy Collection'
#  'Poison Ivy Collection'
#  'The Up Series'
#  'James Bond Collection'
#  'Toy Story Collection'
#  'The Jake Gittes Collection'
#  'Deuce Bigalow Collection'
#  'The Last Picture Show Collection'
#  'The Sinbad Collection'
#  'Stuart Little Collection'
#  'Fantasia Collection'
#  'Friday Collection'
#  'Batman (DC Universe Animated) Collection'
#  'Sister Act Collection'
#  'Sister Act Collection'
#  "Wayne's World Collection"
#  "Wayne's World Collection"
#  'The Jack Ryan Collection'
#  'Mexico Trilogy'
#  'The Cutting Edge Collection'
#  'Scream Collection'
#  'Single White Female Collection'
#  'The Boondock Saints Collection'
#  'To Sir
#  'The Chronicles of Riddick Collection'
#  'The Whole Nine/Ten Yards Collection'
#  'Cross of Iron Collection'
#  'American Graffiti Collection'
#  'The Muppet Collection'
#  'The Muppet Collection'
#  'Final Destination Collection'
#  'Death Wish Collection'
#  'Death Wish Collection'
#  'Death Wish Collection'
#  'Death Wish Collection'
#  'Death Wish Collection'
#  'Teenage Mutant Ninja Turtles (Original) Collection'
#  'Teenage Mutant Ninja Turtles (Original) Collection'
#  'Teenage Mutant Ninja Turtles (Original) Collection'
#  'Bloodsport Collection'
#  'Grumpy Old Men Collection'
#  'The Hustler Collection'
#  'The Skulls Collection'
#  'The Odd Couple Collection'
#  'Navarone Collection'
#  'Beach Party Collection'
#  'Arthur Collection'
#  'Bachelor Party Collection'
#  'Predator Collection'
#  'American Psycho Collection'
#  'East is East Collection'
#  'Caddyshack Collection'
#  'The Crow Collection'
#  'The Flintstones (Live-Action) Collection'
#  'Heart of Gold Collection'
#  'Carnosaur Collection'
#  'Carnosaur Collection'
#  'Carnosaur Collection'
#  'Hidden Collection'
#  'The Three Mothers Collection'
#  'Die Nibelungen Filmreihe'
#  'Center Stage Collection'
#  "Pee-wee's Collection"
#  'Caballeros Collection'
#  'Road Trip Collection'
#  'Mission
#  'Shanghai Noon Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  "Big Momma's House Collection"
#  'The Endless Summer Collection'
#  'Navarone Collection'
#  'Quatermass (Hammer series)'
#  'Quatermass (Hammer series)'
#  'Puppet Master Collection'
#  'Puppet Master Collection'
#  'Puppet Master Collection'
#  'Puppet Master Collection'
#  'Puppet Master Collection'
#  'Puppet Master Collection'
#  'Puppet Master Collection'
#  'The Benji Collection'
#  'The Benji Collection'
#  'The Benji Collection'
#  'The Decline of Western Civilization Collection'
#  'The Decline of Western Civilization Collection'
#  'The Man With No Name Collection'
#  'Dirty Harry Collection'
#  "Porky's Collection"
#  "Porky's Collection"
#  "Porky's Collection"
#  "Nuke 'Em High Collection"
#  'The Toxic Avenger Collection'
#  'The Toxic Avenger Collection'
#  'The Toxic Avenger Collection'
#  'Predator Collection'
#  'Alien Nation Collection'
#  'Mad Max Collection'
#  'Mad Max Collection'
#  'Mad Max Collection'
#  '9½ Weeks Collection'
#  'Firestarter Collection'
#  'Shaft Collection'
#  'Shaft Collection'
#  'F/X Collection'
#  'F/X Collection'
#  'Missing in Action Collection'
#  'Missing in Action Collection'
#  'Missing in Action Collection'
#  'The Sinbad Collection'
#  'House Party Collection'
#  'House Party Collection'
#  'Nekromantik Collection'
#  'Shaft Collection'
#  'Shaft Collection'
#  'Scary Movie Collection'
#  'X-Men Collection'
#  'Pokémon Collection'
#  'The Sinbad Collection'
#  'The Nutty Professor Collection'
#  'Hollow Man Collection'
#  'Phantasm Collection'
#  'Phantasm Collection'
#  'Phantasm Collection'
#  'Pumpkinhead Collection'
#  'Sleepaway Camp Collection'
#  'Ilsa
#  'The Cell Collection'
#  'Godzilla (Millennium) Collection'
#  'Naked Gun Collection'
#  'Naked Gun Collection'
#  'The Art of War Collection'
#  'Bring It On Collection'
#  'Highlander Collection'
#  'Anatomy Collection'
#  'Urban Legend'
#  'Heart of Gold Collection'
#  'Hellraiser Collection'
#  'Hellraiser Collection'
#  'Hellraiser Collection'
#  'Beach Party Collection'
#  'Beach Party Collection'
#  'The Fly (1958 series)'
#  'Beach Party Collection'
#  'Creature From The Black Lagoon (Universal Series)'
#  'The Invisible Man (Universal Series)'
#  'The Slumber Party Massacre Collection'
#  'The Slumber Party Massacre Collection'
#  'The Slumber Party Massacre Collection'
#  'The Sorority House Massacre Collection'
#  'The Sorority House Massacre Collection'
#  'Digimon Collection'
#  'Meet the Parents Collection'
#  'Billy Jack Collection'
#  'Billy Jack Collection'
#  'Ghoulies Collection'
#  'Ghoulies Collection'
#  'Drunken Master Collection'
#  'Blair Witch Collection'
#  "Charlie's Angels Collection"
#  'James Bond Collection'
#  'Rugrats Collection'
#  '101 Dalmatians (Live-Action) Collection'
#  'Crouching Tiger
#  'Dungeons & Dragons Collection'
#  'James Bond Collection'
#  'Wall Street Collection'
#  "The Emperor's New Groove Collection"
#  'Miss Congeniality Collection'
#  'Dracula 2000 Collection'
#  'Annie Collection'
#  'Save The Last Dance Collection'
#  'Beverly Hills Cop Collection'
#  'Beverly Hills Cop Collection'
#  'The Brave Little Toaster Collection'
#  'Ernest Collection'
#  'Evil Dead Collection'
#  'The Jaws Collection'
#  'Lost Boys Collection'
#  'Mannequin Collection'
#  'Left Behind Collection'
#  "Wong Kar-Wai's Informal Collection"
#  'The Hannibal Lecter Anthology'
#  'Disneys Große Pause'
#  'Demetrius Filmreihe'
#  'Dr. Phibes Collection'
#  'The Hannibal Lecter Anthology'
#  'Revenge of the Nerds Collection'
#  'Revenge of the Nerds Collection'
#  'C.H.U.D. Collection'
#  'Spy Kids Collection'
#  'Alex Cross Collection'
#  'The Visitors Collection'
#  'Pokémon Collection'
#  'Bridget Jones Collection'
#  'Joe Dirt Collection'
#  'Crocodile Dundee Collection'
#  'The Mummy Collection'
#  'Shrek Collection'
#  'City Slickers Collection'
#  'Alienation Trilogy'
#  'The Magnificent Seven Collection'
#  'The Magnificent Seven Collection'
#  'Atlantis Collection'
#  'Tomb Raider Collection'
#  'Dr. Dolittle Collection'
#  'The Fast and the Furious Collection'
#  'The Crimson Rivers Collection'
#  'Cats & Dogs Collection'
#  'Scary Movie Collection'
#  'Beach Party Collection'
#  'Totò Collection'
#  'Cannonball Run Collection'
#  'Cannonball Run Collection'
#  'Cannonball Run Collection'
#  'Dr Goldfoot Collection'
#  'Cheech & Chong Collection'
#  'Cheech & Chong Collection'
#  'The Three Mothers Collection'
#  'Final Fantasy Collection'
#  'Legally Blonde Collection'
#  'Arthur Collection'
#  "Pee-wee's Collection"
#  'Caddyshack Collection'
#  'Critters Collection'
#  'Critters Collection'
#  'Critters Collection'
#  'Dirty Harry Collection'
#  'Elvira Collection'
#  'Ernest Collection'
#  'The Howling Collection'
#  'The Land Before Time Collection'
#  'Return of the Living Dead Collection'
#  'Return of the Living Dead Collection'
#  'The Man From Snowy River Collection'
#  'The Man From Snowy River Collection'
#  'Short Circuit Collection'
#  'Short Circuit Collection'
#  'Tetsuo Collection'
#  'The Waxwork Collection'
#  'American Ninja Collection'
#  'American Ninja Collection'
#  'American Ninja Collection'
#  'Best of the Best Collection'
#  "Bill & Ted's Most Excellent Collection"
#  'C.H.U.D. Collection'
#  'Cyborg Collection'
#  'Dream a Little Dream Collection'
#  'Eddie and the Cruisers Collection'
#  'Eddie and the Cruisers Collection'
#  'K-9 Collection'
#  'Kickboxer Collection'
#  "Look Who's Talking Collection"
#  'Major League Collection'
#  'Jurassic Park Collection'
#  'Swamp Thing Collection'
#  'The Musketeers Collection'
#  'Road House Collection'
#  'The Stepfather Collection'
#  'The Stepfather Collection'
#  'Warlock Collection'
#  'Warlock Collection'
#  "Weekend at Bernie's Collection"
#  'Basket Case Collection'
#  'The Princess Diaries Collection'
#  'Rush Hour Collection'
#  'La cage aux folles'
#  'La cage aux folles'
#  'Philo & Clyde Collection'
#  'American Pie Collection'
#  'Jeepers Creepers Collection'
#  '3 Ninjas Collection'
#  '3 Ninjas Collection'
#  '3 Ninjas Collection'
#  'Omega Code Series'
#  'A Man Called Horse Collection'
#  'Zoolander Collection'
#  'Joy Ride Collection'
#  'The Party Collection'
#  'Cheech & Chong Collection'
#  'Dirty Harry Collection'
#  'Darko Collection'
#  'Monsters
#  'When a Stranger Calls Collection'
#  'Harry Potter Collection'
#  'Fanny Brice Collection'
#  'Beastmaster Collection'
#  'Harry Palmer Collection'
#  'The Exterminator Collection'
#  'Caprona Collection'
#  'Dirty Harry Collection'
#  'Caprona Collection'
#  'Dirty Harry Collection'
#  'Behind Enemy Lines Collection'
#  "Ocean's Collection"
#  "Bill & Ted's Most Excellent Collection"
#  'The Lord of the Rings Collection'
#  'Fritz the Cat Collection'
#  'Fritz the Cat Collection'
#  'Sex and Zen Collection'
#  '48 Hrs. Collection'
#  'Conan the Barbarian Collection'
#  '48 Hrs. Collection'
#  'The Sandlot Collection'
#  'Peter Pan Collection'
#  'Super Troopers Collection'
#  'Fanny Brice Collection'
#  'Sleuth Collection'
#  'The Vampire Chronicles'
#  'State Property Collection'
#  'The Bad New Bears Collection'
#  'The Bad New Bears Collection'
#  'The Bad New Bears Collection'
#  'The Lone Ranger (Clayton Moore) Collection'
#  'The Lone Ranger (Clayton Moore) Collection'
#  'Vampire Hunter D Collection'
#  'FernGully Collection'
#  'Zombi Collection'
#  'Get Smart Collection'
#  'Oh
#  'Oh
#  'Ice Age Collection'
#  'Resident Evil Collection'
#  'The Paleface Collection'
#  'Road to Collection'
#  'Road to Collection'
#  'Road to Collection'
#  'Road to Collection'
#  'Tales of the Four Seasons'
#  'Smokey and the Bandit Collection'
#  'Smokey and the Bandit Collection'
#  'Smokey and the Bandit Collection'
#  'Sällskapsresorna'
#  'Blade Collection'
#  'National Lampoon’s Van Wilder Collection'
#  'Slap Shot Collection'
#  'My Big Fat Greek Wedding Collection'
#  'War Trilogy'
#  'Killer Tomatoes! Collection'
#  'Horror High Collection'
#  '3 Men Collection'
#  '3 Men Collection'
#  'The Scorpion King Collection'
#  'Friday the 13th Collection'
#  'Wild Orchid Collection'
#  'Spider-Man Collection'
#  'White Fang Collection'
#  'White Fang Collection'
#  'Star Wars Collection'
#  'Philo & Clyde Collection'
#  'The Jack Ryan Collection'
#  'The Bourne Collection'
#  'Scooby-Doo Collection'
#  'Cheech & Chong Collection'
#  'Lilo & Stitch Collection'
#  "Look Who's Talking Collection"
#  'Like Mike Collection'
#  'Men In Black Collection'
#  'Halloween Collection'
#  'Stuart Little Collection'
#  'Austin Powers Collection'
#  'Our Man Flint Collection'
#  'The Modesty Blaise Collection'
#  'Our Man Flint Collection'
#  'Spy Kids Collection'
#  'xXx Collection'
#  'Living Trilogy'
#  'Blue Crush Collection'
#  'Undisputed Collection'
#  'Care Bears Collection'
#  'Care Bears Collection'
#  'Hot Shots! Collection'
#  '976-EVIL Collection'
#  'Frankenstein (Hammer Series)'
#  'Stakeout Collection'
#  'Barbershop Collection'
#  'The Transporter Collection'
#  'Ernest Collection'
#  'Ernest Collection'
#  'The Hills Have Eyes (Original) Collection'
#  'The Hills Have Eyes (Original) Collection'
#  'The Hannibal Lecter Anthology'
#  'Heaven
#  'Godzilla (Showa) Collection'
#  'Godzilla (Showa) Collection'
#  'Godzilla (Showa) Collection'
#  'Qatsi Collection'
#  'The Last Picture Show Collection'
#  'Ernest Collection'
#  'Ernest Collection'
#  'Dracula (Hammer Series)'
#  'Django - Original films'
#  'Django - Original films'
#  'Pokémon Collection'
#  'The Ring Collection'
#  'Qatsi Collection'
#  'Friday the 13th Collection'
#  'Saturday Night Fever Collection'
#  'Saturday Night Fever Collection'
#  'Man of Marble/Iron Collection'
#  'Enter the Ninja Collection'
#  'Faces of Death Collection'
#  'Faces of Death Collection'
#  'Faces of Death Collection'
#  'Faces of Death Collection'
#  'Faces of Death Collection'
#  'Faces of Death Collection'
#  'Göta kanal collection'
#  'The BRD Collection'
#  'My Bloody Valentine Collection'
#  'Piranha Collection'
#  'Jackass Collection'
#  'James Bond Collection'
#  'The Santa Clause Collection'
#  'Half Past Dead Collection'
#  'Harry Potter Collection'
#  'Left Behind Collection'
#  "Pagnol
#  "Pagnol
#  'The Blue Lagoon collection'
#  'Scanners Collection'
#  'Rocky Horror Collection'
#  'James Bond Collection'
#  'Friday Collection'
#  'Brother Collection'
#  'Elling Collection'
#  'I Spit on Your Grave (Original) Collection'
#  'Anglo-Zulu War Collection'
#  'Analyze Collection'
#  'Vabank (Collection)'
#  'Jönsson Gang'
#  'The Party Collection'
#  'Class of 1999 Collection'
#  'Turkish Star Wars'
#  'Star Trek
#  'The Lord of the Rings Collection'
#  'My Girl Collection'
#  'My Girl Collection'
#  'Road to Collection'
#  'Heavy Metal Collection'
#  'Blue Collar Comedy Tour Collection'
#  'Final Destination Collection'
#  'Tokyo Decadence series'
#  'Le Gendarme de St. Tropez Collection'
#  'Jönsson Gang'
#  'The BRD Collection'
#  'They Call Me Bruce Collection'
#  'The Pink Panther (Original) Collection'
#  'Zapped Collection'
#  'Shanghai Noon Collection'
#  'The Jungle Book Collection'
#  'Dennis the Menace Collection'
#  'The Black Stallion Collection'
#  'The Black Stallion Collection'
#  'Willard'
#  'Born Free Trilogy'
#  'Ringu Collection'
#  'Ringu Collection'
#  'I Am Curious Collection'
#  'The Flicka Collection'
#  'Demetrius Filmreihe'
#  "Aki Kaurismäki's Finland trilogy"
#  'House of 1000 Corpses Collection'
#  'X-Men Collection'
#  'Daddy Day Camp Collection'
#  "Breakin' Collection"
#  "Breakin' Collection"
#  'Nevada Smith Collection'
#  'The Matrix Collection'
#  'The Klapisch Trilogy'
#  'Pokémon Collection'
#  'Almighty Collection'
#  'Finding Nemo Collection'
#  'Wrong Turn Collection'
#  'The Fast and the Furious Collection'
#  'Nevada Smith Collection'
#  'A Man Called Horse Collection'
#  'Dumb and Dumber Collection'
#  'Rugrats Collection'
#  'Dracula (Hammer Series)'
#  '28 Days/Weeks Later Collection'
#  "Charlie's Angels Collection"
#  'Legally Blonde Collection'
#  'The Terminator Collection'
#  'Pirates of the Caribbean Collection'
#  'Bad Boys Collection'
#  'Johnny English Collection'
#  'Trilogie'
#  'Tomb Raider Collection'
#  'Spy Kids Collection'
#  'Gator Collection'
#  'Kickboxer Collection'
#  'Gator Collection'
#  'American Pie Collection'
#  'S.W.A.T. Collection'
#  'Totò Collection'
#  'Friday the 13th Collection'
#  'Agent Cody Banks Collection'
#  'Tremors Collection'
#  'The Pink Panther (Original) Collection'
#  'The Pink Panther (Original) Collection'
#  'Elements Trilogy'
#  'Elements Trilogy'
#  'Jeepers Creepers Collection'
#  'Sides of the Bed'
#  'The Cabin Fever Collection'
#  'Mexico Trilogy'
#  'Once Upon a Time in China Collection'
#  'Once Upon a Time in China Collection'
#  'Once Upon a Time in China Collection'
#  'Living Dead Collection'
#  'Underworld Collection'
#  'Yossi Collection'
#  'Dorm Daze Collection'
#  'Leningrad Cowboys Collection'
#  'Beethoven Collection'
#  'Beethoven Collection'
#  'Ginger Snaps Collection'
#  'American Graffiti Collection'
#  'House of the Dead Collection'
#  'Kill Bill Collection'
#  'Texas Chainsaw (Reboot) Collection'
#  'Scary Movie Collection'
#  'Brother Bear Collection'
#  'The Eye Collection'
#  'Frankenstein (Hammer Series)'
#  'The Apu Collection'
#  'Man of Marble/Iron Collection'
#  'Sherlock Holmes (1939 series)'
#  'Sherlock Holmes (1939 series)'
#  'Sherlock Holmes (1939 series)'
#  'The Matrix Collection'
#  'Father of the Bride Collection'
#  'Bad Santa Collection'
#  'Darkman Collection'
#  'Europa Trilogy'
#  'Tales from the Crypt Collection'
#  'WarGames Collection'
#  'Highlander Collection'
#  'Kindergarten Cop Collection'
#  'Battle Royale Collection'
#  'Teen Wolf Collection'
#  'The Pink Panther (Original) Collection'
#  'Leprechaun Collection (Original Series)'
#  'Europa Trilogy'
#  'The Adventures of Antoine Doinel'
#  'Honey Collection'
#  'The Lord of the Rings Collection'
#  'Cheaper by the Dozen Collection'
#  'Re-Animator Collection'
#  'Pumping Iron Collection'
#  'The Matt Helm Collection'
#  'The Butterfly Effect Collection'
#  'You Got Served Collection'
#  'Barbershop Collection'
#  'Trilogie'
#  'The Lost Skeleton Collection'
#  'Blacula Collection'
#  'Blacula Collection'
#  'Trilogie'
#  'Allan Quatermain Collection'
#  'Dirty Dancing Collection'
#  'Agent Cody Banks Collection'
#  'Scooby-Doo Collection'
#  'USA
#  'Hellboy Collection'
#  'The Prince & Me Collection'
#  'Walking Tall Collection'
#  'The Whole Nine/Ten Yards Collection'
#  'Living Dead Collection'
#  'Road to Collection'
#  'Kill Bill Collection'
#  'Mean Girls Collection'
#  'Van Helsing Collection'
#  'The Kingdom'
#  '100 Girls Collection'
#  'The Up Series'
#  'James Bond Collection'
#  'James Bond Collection'
#  'James Bond Collection'
#  'Babylon 5 Collection'
#  "Look Who's Talking Collection"
#  'The Delta Force Collection'
#  'Cat People Collection'
#  'The Musketeers Collection'
#  'Bang Rajan Collection'
#  'Sniper Collection'
#  'Babylon 5 Collection'
#  'Babylon 5 Collection'
#  'Babylon 5 Collection'
#  'The Thin Man Collection'
#  'The Thin Man Collection'
#  'The Thin Man Collection'
#  'The Thin Man Collection'
#  'The Thin Man Collection'
#  'Lammbock Collection'
#  'The Legend Collection'
#  'Tremors Collection'
#  'Tremors Collection'
#  'Vampire Karnstein (Hammer series)'
#  'The Cheerleaders - Collection'
#  'The Streetfighter Collection'
#  'The Streetfighter Collection'
#  'Frankenstein (Hammer Series)'
#  'The Gidget Collection'
#  'Silence of God Trilogy by Ingmar Bergman'
#  'Silence of God Trilogy by Ingmar Bergman'
#  'Silence of God Trilogy by Ingmar Bergman'
#  'The Complete Monterey Pop Festival'
#  'Infernal Affairs Collection'
#  'Robot Jox Collection'
#  'Death Race Original Collection'
#  'Lew Harper Collection'
#  'In China They Eat Dogs Collection'
#  'The Delta Force Collection'
#  'Per Fly trilogien (Samling)'
#  'Dead or Alive Collection'
#  'Alienation Trilogy'
#  'Dr. Mabuse Collection'
#  'Teenage Apocalypse Trilogy'
#  'Lupin the Third Collection'
#  'The Toxic Avenger Collection'
#  'Grey Gardens Collection'
#  'Shrek Collection'
#  'Harry Potter Collection'
#  'The Chronicles of Riddick Collection'
#  'Garfield Collection'
#  'Police Academy Collection'
#  'Sherlock Holmes (1939 series)'
#  'Sherlock Holmes (1939 series)'
#  'Super Size Me Collection'
#  'Billy Jack Collection'
#  'The Human Condition'
#  'Godzilla (Showa) Collection'
#  'The Hitcher (1986) Collection'
#  'Dexter Riley Collection'
#  'The Philadelphia Experiment - Collezione'
#  'The Pink Panther (Original) Collection'
#  'Taxi Collection'
#  'Taxi Collection'
#  'Lassie (Kinofilme)'
#  'Spider-Man Collection'
#  'Before... Collection'
#  'Anchorman Collection'
#  'Cinderella Story Collection'
#  'Trylogia Sienkiewicza'
#  'The Bourne Collection'
#  'The Magnificent Seven Collection'
#  'The Magnificent Seven Collection'
#  'Sherlock Holmes (1939 series)'
#  'Sherlock Holmes (1939 series)'
#  'Sherlock Holmes (1939 series)'
#  'Sherlock Holmes (1939 series)'
#  'Thunderbirds (Animation) Collection'
#  'Thunderbirds (Animation) Collection'
#  'PTU Collection'
#  'Harold & Kumar Collection'
#  'The Princess Diaries Collection'
#  'AVP Collection'
#  'Without a Paddle Collection'
#  'The Exorcist Collection'
#  'The Sting Collection'
#  'The Benji Collection'
#  'Anaconda Collection'
#  'The Mangler Collection'
#  'Night of the Demons Collection'
#  'Witchboard Collection'
#  'Resident Evil Collection'
#  "Nuke 'Em High Collection"
#  'Basket Case Collection'
#  'Basket Case Collection'
#  'Europa Trilogy'
#  "It's Alive Collection"
#  'The Grudge Collection'
#  'Saw Collection'
#  'The Incredibles Collection'
#  "Child's Play Collection"
#  'Bridget Jones Collection'
#  'National Treasure Collection'
#  'SpongeBob Collection'
#  "Ocean's Collection"
#  'Blade Collection'
#  "That's Entertainment Collection"
#  "That's Entertainment Collection"
#  "That's Entertainment Collection"
#  'The Invisible Man (Universal Series)'
#  'I Love a Mystery movie series'
#  'King Kong (1933 series)'
#  'The Wolf Man (Universal Series)'
#  'Topper Collection'
#  'Why We Fight'
#  'Cat People Collection'
#  'Ivan The Terrible Collection'
#  'Road to Collection'
#  'The Orphic Trilogy'
#  'Allan Quatermain (1950 series)'
#  'The Paleface Collection'
#  "St. Trinian's Collection"
#  'Samurai Collection'
#  'Samurai Collection'
#  'Samurai Collection'
#  'The Human Condition'
#  'The Human Condition'
#  'Alienation Trilogy'
#  'Dracula (Hammer Series)'
#  'Asterix and Obelix (Animation) Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Dracula (Hammer Series)'
#  'Dracula (Hammer Series)'
#  'Gamera Films'
#  'Trinità  Collection'
#  'Dracula (Hammer Series)'
#  'The Emigrants Collection'
#  'Dr. Phibes Collection'
#  'Dracula (Hammer Series)'
#  'The Tall Blond Man Collection'
#  'Lone Wolf and Cub Collection'
#  'Lone Wolf and Cub Collection'
#  'Nobody Collection'
#  'Walking Tall Original Collection'
#  'Emmanuelle Collection'
#  'Gone in 60 Seconds Trilogy'
#  'Mountain Family Robinson Collection'
#  'Dolemite Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Emmanuelle Collection'
#  'French Connection Collection'
#  'Ирония судьбы (Коллекция)'
#  'The Sister Street Fighter Collection'
#  'Vixens Collection'
#  'Trilogy of Terror Collection'
#  'Westworld Collection'
#  'Vixens Collection'
#  'The Rutles Collection'
#  'The Lord of the Rings Animated Collection'
#  'French Fried Vacation'
#  'Barefoot Gen Collection'
#  'Star Wars
#  'Silent Night
#  'Anne of Green Gables Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Barbarian Queen Collection'
#  'Demons Collection'
#  'Star Wars
#  'Mr. Vampire Collection'
#  'Police Story Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Flodder Collection'
#  'A Better Tomorrow Collection'
#  'The Frogtown Collection'
#  'Koker Trilogy'
#  'A Chinese Ghost Story Collection'
#  'A Better Tomorrow Collection'
#  'Patlabor Collection'
#  'The Up Series'
#  "Wong Kar-Wai's Informal Collection"
#  'Begotten Collection'
#  'Mannequin Collection'
#  'Barbarian Queen Collection'
#  'Koker Trilogy'
#  'House of Angels Collection'
#  'Lonesome Dove Collection'
#  'American Ninja Collection'
#  'The Bride with White Hair Collection'
#  'Cyborg Collection'
#  'The Legend Collection'
#  'Fortress Collection'
#  'Leningrad Cowboys Collection'
#  'The Philadelphia Experiment - Collezione'
#  'Barrytown Trilogy'
#  'Trilogía de la violencia de Michael Haneke'
#  'Naked Collection'
#  'Darkman Collection'
#  'Major League Collection'
#  'Pumpkinhead Collection'
#  'Gonin collection'
#  'Street Fighter Collection'
#  'Tales of the Four Seasons'
#  'Jack Frost Collection'
#  'The Hunters Collection'
#  "Aki Kaurismäki's Finland trilogy"
#  'Pusher Collection'
#  'Bikini Summer Collection'
#  'The Cremaster Cycle'
#  'Hamilton Collection'
#  'The Lion King Collection'
#  'From Dusk Till Dawn Collection'
#  'From Dusk Till Dawn Collection'
#  'Torrente Collection'
#  'The Kingdom'
#  'Unna Trilogie'
#  'Batman (DC Universe Animated) Collection'
#  'Addams Family Collection'
#  'Lady Snowblood Collection'
#  'Candyman Collection'
#  'Superman (DC Universe Animated) Collection'
#  'Evangelion Collection'
#  'Freeway Collection'
#  'Kirikou'
#  'The Prophecy Collection'
#  'Taxi Collection'
#  'Osobennosti Natsionalnoy ... - Collection'
#  'Cruel Intentions Collection'
#  'The Big Bottom Box'
#  'If These Walls Could Talk Collection'
#  'A Goofy Movie Collection'
#  "Wong Kar-Wai's Informal Collection"
#  'The Cremaster Cycle'
#  'Running Out Of Time Collection'
#  'The Wog Boy Collection'
#  'The Female Prisoner Series'
#  'The Female Prisoner Series'
#  'Batman Beyond Collection'
#  'Mimic Collection'
#  'Paradise Lost Collection'
#  'In China They Eat Dogs Collection'
#  'Asterix and Obelix Collection'
#  'Godzilla (Millennium) Collection'
#  'American Psycho Collection'
#  'Dead or Alive Collection'
#  'Cube Collection'
#  'My Sassy Girl Collection'
#  'Annika Bengtzon Collection'
#  'My Wife is a Gangster Collection'
#  'Dead or Alive Collection'
#  'Fubar Collection'
#  'The Vengeance Collection'
#  'The Foreigner Collection'
#  'Johan Falk Collection'
#  'The Lion King Collection'
#  'The Cremaster Cycle'
#  'Herr Lehmann Filmreihe'
#  'Ju-on Collection'
#  'Ju-on Collection'
#  'Tremors Collection'
#  'Bring It On Collection'
#  'The Crimson Rivers Collection'
#  'Sniper Collection'
#  'Battle Royale Collection'
#  'Naked Collection'
#  'Ghost in the Shell Collection'
#  'Samurai Trilogy'
#  'The Twins Effect Collection'
#  'Ginger Snaps Collection'
#  'Dark Woods Collection'
#  'Ju-on Collection'
#  'The Vengeance Collection'
#  'Ginger Snaps Collection'
#  'One Missed Call Collection'
#  'Inuyasha Collection'
#  'Starship Troopers Collection'
#  'Ju-on Collection'
#  'Ong Bak Collection'
#  'Infernal Affairs Collection'
#  'Saints and Soldiers Collection'
#  'Open Water Collection'
#  'Infernal Affairs Collection'
#  'The Ring Collection'
#  'The Yes Men Collection'
#  'Bummer Collection'
#  'Azumi Collection'
#  'Cruel Intentions Collection'
#  'What the Bleep! Collection'
#  'The Eye Collection'
#  'Hellraiser Collection'
#  'Meet the Parents Collection'
#  'White Noise Collection'
#  'Godzilla (Showa) Collection'
#  'The Yakuza Papers Collection'
#  'Brancaleone Collection'
#  'Appleseed Collection'
#  'Pippi Longstocking'
#  'Pippi Longstocking'
#  'Father Flanagan Collection'
#  'Beastmaster Collection'
#  'Dr. Who Collection'
#  'The Are We Collection'
#  'Alone in the Dark Collection'
#  'The Boogeyman Collection'
#  'The BRD Collection'
#  'Constantine Collection'
#  'The Mask Collection'
#  'World of Watches Collection'
#  'Topper Collection'
#  'No Retreat
#  'The ChubbChubbs Collection'
#  'The Musketeers Collection'
#  'The Adventures of Antoine Doinel'
#  'War Trilogy'
#  'The Blind Dead Collection'
#  'Chili Palmer Collection'
#  'Godzilla (Showa) Collection'
#  'Godzilla (Heisei) Collection'
#  'Oh
#  'Cube Collection'
#  'Vares Collection'
#  'Miss Congeniality Collection'
#  'Zu Warriors Collection'
#  'Godzilla (Showa) Collection'
#  'Sin City Collection'
#  'Trilogy of Life'
#  'Ringu Collection'
#  'The Love Comes Softly Collection'
#  'The Amityville Horror Collection'
#  'State Property Collection'
#  'xXx Collection'
#  'Zatôichi
#  'Ukraine Trilogy'
#  'Vampire Hunter D Collection'
#  'Star Wars Collection'
#  'The Invisible Man (Universal Series)'
#  'Madagascar Collection'
#  'The Exorcist Collection'
#  'The Sisterhood of the Traveling Pants Collection'
#  'Godzilla (Heisei) Collection'
#  'The Dark Knight Collection'
#  'Godzilla (Millennium) Collection'
#  'Herbie Collection'
#  'Living Dead Collection'
#  'The Emigrants Collection'
#  'My Friends Collection'
#  'Godzilla (Showa) Collection'
#  'Harry Palmer Collection'
#  'Fantastic Four Collection'
#  'The Klapisch Trilogy'
#  'House of 1000 Corpses Collection'
#  'Whispering Corridors Collection'
#  'The Dukes Of Hazzard Collection'
#  'Deuce Bigalow Collection'
#  'Pusher Collection'
#  'Mr. Wong Collection'
#  'Asterix and Obelix Collection'
#  'The Transporter Collection'
#  'Enter the Ninja Collection'
#  'Police Story Collection'
#  'Police Story Collection'
#  'Waiting Collection'
#  'Green Street Hooligans Collection'
#  'Final Fantasy Collection'
#  'Into the Blue Collection'
#  'Wallace & Gromit Collection'
#  'Whispering Corridors Collection'
#  'Goal! Collection'
#  'Star Wreck Collection'
#  'Left Behind Collection'
#  'Zorro Collection'
#  'Saw Collection'
#  'Nobody Collection'
#  'American Pie (Spin-off) Collection'
#  'Tarzan (Johnny Weissmuller series)'
#  'Tarzan (Johnny Weissmuller series)'
#  'USA
#  'The Adventures of Antoine Doinel'
#  'Jarhead Collection'
#  'Dracula (Hammer Series)'
#  'Wolf Creek Collection'
#  'The Descent Collection'
#  'Harry Potter Collection'
#  'The Wild Geese Collection'
#  'Frankenstein (Hammer Series)'
#  'The Chronicles of Narnia Collection'
#  'Havoc Collection'
#  'Ivan The Terrible Collection'
#  'Johan Falk Collection'
#  'The Matt Helm Collection'
#  'Cheaper by the Dozen Collection'
#  'The Dentist Collection'
#  'Yamakasi - Collection'
#  'The Love Comes Softly Collection'
#  'The Vengeance Collection'
#  'District 13 Collection'
#  'BloodRayne Collection'
#  'Hostel Collection'
#  'Hoodwinked! Collection'
#  'Underworld Collection'
#  'Casper Collection'
#  'Project A Collection'
#  'Vabank (Collection)'
#  'Quatermass (Hammer series)'
#  'Hellraiser Collection'
#  'Gamera Films'
#  '8MM Collection'
#  'Elements Trilogy'
#  'Uuno Turhapuro'
#  'French Fried Vacation'
#  "Big Momma's House Collection"
#  'Nanny McPhee Collection'
#  'The Comedians Of Comedy Collection'
#  'Final Destination Collection'
#  'The Pink Panther (Steve Martin) Collection'
#  'Troll Collection'
#  'Curious George Collection'
#  'When a Stranger Calls Collection'
#  'Pulse Collection'
#  'Election Collection'
#  'Ultimate Avengers Collection'
#  'Ice Age Collection'
#  'The Prince & Me Collection'
#  'Leprechaun Collection (Original Series)'
#  'Leprechaun Collection (Original Series)'
#  'Leprechaun Collection (Original Series)'
#  'Leprechaun Collection (Original Series)'
#  "Aki Kaurismäki's Finland trilogy"
#  'The Hills Have Eyes (Reboot) Collection'
#  'The Pink Panther (Original) Collection'
#  'The Pink Panther (Original) Collection'
#  'Urban Legend'
#  'Basic Instinct Collection'
#  'Scary Movie Collection'
#  'Silent Hill Collection'
#  'The Protector Collection'
#  'Mission
#  'Die Nibelungen Collection'
#  'Die Nibelungen Collection'
#  'Samurai Trilogy'
#  'Robert Langdon Collection'
#  'X-Men Collection'
#  'Cars Collection'
#  'Pirates of the Caribbean Collection'
#  'Clerks Collection'
#  'See No Evil Collection'
#  'Hollow Man Collection'
#  'High School Musical Collection'
#  'Jack Frost Collection'
#  'The Fast and the Furious Collection'
#  'Garfield Collection'
#  'The Sheriff and the Satellite Kid Collection'
#  'Superman Collection'
#  'The Pink Panther (Original) Collection'
#  'Mimic Collection'
#  'Krrish Collection'
#  'Whispering Corridors Collection'
#  'Night at the Museum Collection'
#  'Crank Collection'
#  'Step Up Collection'
#  'Bon Cop Bad Cop Collection'
#  'The Heroic Trio Collection'
#  'Swordsman Collection'
#  'Trilogía de la violencia de Michael Haneke'
#  'Vixens Collection'
#  'Jackass Collection'
#  'The Land Before Time Collection'
#  'Open Season Collection'
#  'Texas Chainsaw (Reboot) Collection'
#  'The Grudge Collection'
#  'The Marine Collection'
#  'Feast Collection'
#  "Clint Eastwood's Iwo Jima Collection"
#  'Azumi Collection'
#  'Saw Collection'
#  'Corto Maltese'
#  'The Butterfly Effect Collection'
#  'The Santa Clause Collection'
#  'James Bond Collection'
#  'Happy Feet Collection'
#  'OSS 117 Collection'
#  'Reeker Collection'
#  'National Lampoon’s Van Wilder Collection'
#  'Dracula (Universal Series)'
#  'She Collection'
#  'Election Collection'
#  'Rocky Collection'
#  'Another Gay Movie Collection'
#  'Loose Change Collection'
#  'Trilogy of Life'
#  "Clint Eastwood's Iwo Jima Collection"
#  "Happily N'Ever After Collection"
#  'Stomp the Yard Collection'
#  'Arthur and the Invisibles Collection'
#  'American Pie (Spin-off) Collection'
#  'Don Camillo Collection'
#  'Don Camillo Collection'
#  'The Orphic Trilogy'
#  'The Orphic Trilogy'
#  'The Up Series'
#  'The Up Series'
#  'The Up Series'
#  "Smokin' Aces Collection"
#  'The Messengers Collection'
#  'The Hannibal Lecter Anthology'
#  'Cocaine Cowboys'
#  'Anchorman Collection'
#  'SPL Collection'
#  'Trailer Park Boys Collection'
#  'Ghost Rider Collection'
#  'Kidulthood Collection'
#  'Like Mike Collection'
#  'The 36th Chamber of Shaolin Collection'
#  'Billy Jack Collection'
#  'Emil i Lönneberga'
#  'Trilogy of Life'
#  '2001 Maniacs Collection'
#  'Teen Wolf Collection'
#  'Pusher Collection'
#  'Babylon 5 Collection'
#  'White Noise Collection'
#  'Atlantis Collection'
#  'The Ultimate Collection'
#  '300 Collection'
#  'The Hills Have Eyes (Reboot) Collection'
#  'Samurai Trilogy'
#  'The Are We Collection'
#  'Vacancy Collection'
#  'Trilogía de la violencia de Michael Haneke'
#  'Mr. Bean Collection'
#  'The Condemned Collection'
#  'Spider-Man Collection'
#  'The Up Series'
#  'Maniac Cop Collection'
#  'World of Watches Collection'
#  'This is England Collection'
#  '28 Days/Weeks Later Collection'
#  'Shrek Collection'
#  'Pirates of the Caribbean Collection'
#  'The Librarian Collection'
#  'The Librarian Collection'
#  'Henry Fool Collection'
#  "Ocean's Collection"
#  'Godzilla (Heisei) Collection'
#  'Godzilla (Heisei) Collection'
#  'Godzilla (Heisei) Collection'
#  'Hostel Collection'
#  'Star Crash Collection'
#  "Surf's Up Collection"
#  'Fantastic Four Collection'
#  'Grindhouse Collection'
#  'Bring It On Collection'
#  'Goal! Collection'
#  'Cheech & Chong Collection'
#  'Die Hard Collection'
#  'Almighty Collection'
#  'Transformers Collection'
#  'Harry Potter Collection'
#  'Arn collection'
#  'The Bourne Collection'
#  'If I Were You Collection'
#  'The Bible Collection'
#  'Brice Collection'
#  'Rush Hour Collection'
#  'Daddy Day Camp Collection'
#  'Halloween (Rob Zombie Series) Collection'
#  '2 Days In... Collection'
#  'Trilogía Sollima'
#  'Taxi Collection'
#  'Grindhouse Collection'
#  'Kevin Smith
#  'Resident Evil Collection'
#  'Elizabeth Collection'
#  'Sleuth Collection'
#  '30 Days of Night Collection'
#  'Why Did I Get Married Collection'
#  'Saw Collection'
#  'The 36th Chamber of Shaolin Collection'
#  'Elite Squad Collection'
#  'Decoys Collection'
#  'Living Trilogy'
#  'The Man from Earth Collection'
#  'Kevin Smith
#  'Hitman Collection'
#  'Alvin and the Chipmunks Collection'
#  'Futurama Collection'
#  'Wrong Turn Collection'
#  'Design Trilogy'
#  'Inoshika Ocho series'
#  'The Hamiltons Collection'
#  'National Treasure Collection'
#  'AVP Collection'
#  'Keinohrhasen Filmreihe'
#  'Battlestar Galactica (Reboot) Collection'
#  '[REC] Collection'
#  'In the Name of the King Collection'
#  'Hatchet Collection'
#  'One Missed Call Collection'
#  'Rambo Collection'
#  'The Eye Collection'
#  'Hellboy Collection'
#  'Footsoldier Collection'
#  'Step Up Collection'
#  'Living Dead Collection'
#  'Zeitgeist Collection'
#  'Anders Matthesen'
#  'Return of the Living Dead Collection'
#  'The Dark Knight Collection'
#  'The Foreigner Collection'
#  'Never Back Down Collection'
#  'Godzilla (Showa) Collection'
#  'Zebraman Collection'
#  "Nim's Island Collection"
#  'Street Kings Collection'
#  'Harold & Kumar Collection'
#  'Outpost Collection'
#  'Tarzan (Johnny Weissmuller series)'
#  'Tarzan (Johnny Weissmuller series)'
#  'Tarzan (Johnny Weissmuller series)'
#  'Tarzan (Johnny Weissmuller series)'
#  'Prom Night Collection'
#  'Iron Man Collection'
#  'Taken Collection'
#  'Stargate SG-1 Collection'
#  'American Pie (Spin-off) Collection'
#  'The Chronicles of Narnia Collection'
#  'Indiana Jones Collection'
#  'Sex and the City Collection'
#  'Kung Fu Panda Collection'
#  'Flesh Gordon Collection'
#  'Wanted - Collection'
#  'Ten Minutes Older... (Collection)'
#  "St. Trinian's Collection"
#  'Futurama Collection'
#  'Bambi Collection'
#  'An American Girl Collection'
#  'Frosty the Snowman Collection'
#  'Mamma Mia! Collection'
#  'Simon Brenner Collection'
#  'Journey Collection'
#  'Per Fly trilogien (Samling)'
#  'Per Fly trilogien (Samling)'
#  'Death Note Collection'
#  'Space Chimps Collection'
#  'Stargate SG-1 Collection'
#  'WarGames Collection'
#  'The X-Files Collection'
#  'The Little Mermaid Collection'
#  'The Discworld Collection'
#  'The Discworld Collection'
#  'The Mummy Collection'
#  'Red Cliff Collection'
#  'The Sisterhood of the Traveling Pants Collection'
#  'High School Musical Collection'
#  'Death Race Collection'
#  'Mirrors Collection'
#  'House on Haunted Hill Collection'
#  'The Three Mothers Collection'
#  'Lassie (Kinofilme)'
#  'The Crow Collection'
#  'Alone in the Dark Collection'
#  'Tulse Luper'
#  'Cat Stevens y Hutch Bessy Trilogy'
#  'The Sabata Collection'
# ...
#  'Galaxy Express 999 Collection'
#  'Mall Cop Collection'
#  'The Grudge Collection'
#  'Uuno Turhapuro'
#  'Futurama Collection'
#  'Afro Samurai Collection'
#  'Trancers Collection'
#  'Waiting Collection'
#  'Street Fighter'
#  'Friday the 13th Collection'
#  'Screamers Collection'
#  'The Pink Panther (Steve Martin) Collection'
#  'La Trilogie Marseillaise'
#  'La Trilogie Marseillaise'
#  'La Trilogie Marseillaise'
#  'The Haunting in Connecticut Collection'
#  "Takashi Miike's Young Thugs series"
#  'Ong Bak Collection'
#  'The Millennium Collection'
#  'Naked Fear Collection'
#  'Trylogia Sienkiewicza'
#  'The Butterfly Effect Collection'
#  'Rest Stop Collection'
#  'Kiler Collection'
#  'The Fast and the Furious Collection'
#  'Sugata Sanshirō Collection'
#  'Sugata Sanshirō Collection'
#  'The Desert Collection'
#  'Crank Collection'
#  'Kiler Collection'
#  'The Wolverine Collection'
#  'Star Trek
#  'Charlie Chan (Sidney Toler) Collection'
#  'Flatfoot Collection'
#  'Red Cliff Collection'
#  'Wild Things Collection'
#  'Darko Collection'
#  'Robert Langdon Collection'
#  'The Terminator Collection'
#  'Night at the Museum Collection'
#  'Sami Swoi Collection'
#  'War Trilogy'
#  'Evangelion Collection'
#  'Fullmetal Alchemist Collection'
#  'OSS 117 Collection'
#  'Without a Paddle Collection'
#  'The Hangover Collection'
#  'Ranma Collection'
#  'Ernest Collection'
#  'U Pana Boga Collection'
#  'Dead Snow Collection'
#  'Anglo-Zulu War Collection'
#  'Caprona Collection'
#  'Garfield (Animation) Collection'
#  'How I Unleashed World War II'
#  'Transformers Collection'
#  'Ice Age Collection'
#  'Ranma Collection'
#  'Koker Trilogy'
#  'Caprinos Eventyrlige Verden'
#  'The Librarian Collection'
#  'Dark Planet Collection'
#  'Harry Potter Collection'
#  'The Visitors Collection'
#  'Open Water Collection'
#  'Slap Shot Collection'
#  'Tales from the Crypt Collection'
#  'The Collector Collection'
#  'G.I. Joe (Live-Action) Collection'
#  '12 Rounds Collection'
#  'Silent Night
#  'Kill Buljo Collection'
#  'Rebuild of Evangelion'
#  'Love Hina Collection'
#  'Feast Collection'
#  'Olympia'
#  'Olympia'
#  'Shadow Warriors'
#  'The Cell Collection'
#  'Vacancy Collection'
#  'Troll Collection'
#  'If These Walls Could Talk Collection'
#  'Halloween (Rob Zombie Series) Collection'
#  'The Carry On Collection'
#  'Green Street Hooligans Collection'
#  'Fuga de cerebros - Collection'
#  'Laid to Rest Collection'
#  'Final Destination Collection'
#  'Cloudy with a Chance of Meatballs Collection'
#  'Hellraiser Collection'
#  'Hellraiser Collection'
#  'Paranormal Activity Collection'
#  'Love Hina Collection'
#  'Die Fritz Lang Indien-Edition'
#  'Saw Collection'
#  'The Boondock Saints Collection'
#  'MVP'
#  'Die Fritz Lang Indien-Edition'
#  'Ukraine Trilogy'
#  'Battlestar Galactica (Reboot) Collection'
#  'The Twilight Collection'
#  'Torrente Collection'
#  'Crows Collection'
#  "Mickey's Upon a Christmas Collection"
#  'Design Trilogy'
#  'Dorm Daze Collection'
#  'The Gorky Collection'
#  'Avatar Collection'
#  'Sherlock Holmes Collection'
#  'The Art of War Collection'
#  'Alvin and the Chipmunks Collection'
#  'American Pie (Spin-off) Collection'
#  'The Gorky Collection'
#  'The Millennium Collection'
#  'Ernest Collection'
#  'Puppet Master Collection'
#  'MacGyver (TV Movies) Collection'
#  'Project A Collection'
#  'Ninja Collection'
#  'Asterix and Obelix Collection'
#  'Mega Shark Collection'
#  'Rudolph the Red-Nosed Reindeer Collection'
#  'Dennis the Menace Collection'
#  'Undisputed Collection'
#  'Inoshika Ocho series'
#  'Arn collection'
#  'Charlie Chan (Warner Oland) Collection'
#  'Captain Harlock Collection'
#  'Anne of Green Gables Collection'
#  'The Millennium Collection'
#  'Steal This Film Collection'
#  'Percy Jackson Collection'
#  'Trailer Park Boys Collection'
#  'District 13 Collection'
#  'The Yes Men Collection'
#  'Tooth Fairy Collection'
#  '[REC] Collection'
#  'The Cabin Fever Collection'
#  'Alice in Wonderland Collection'
#  'Road Trip Collection'
#  'Joy Ride Collection'
#  'Lupin the Third Collection'
#  'Living Dead Collection'
#  'Elektra Luxx Collection'
#  'Deadly Prey Collection'
#  'Mondo Cane Collection'
#  'Ma and Pa Kettle Collection'
#  'Hot Tub Time Machine Collection'
#  'How to Train Your Dragon Collection'
#  'Tom and Jerry Collection'
#  'Universal Soldier Collection'
#  'Sherlock Holmes (1939 series)'
#  'Simon Brenner Collection'
#  'Lupin the Third Collection'
#  'Simon Brenner Collection'
#  'Clash of the Titans Collection'
#  'Kick-Ass Collection'
#  'Varg Veum Collection'
#  'Varg Veum Collection'
#  "The Emperor's New Groove Collection"
#  'The Love Comes Softly Collection'
#  'Steal This Film Collection'
#  'Diary of a Wimpy Kid Collection'
#  'Havoc Collection'
#  'Heaven
#  'Onomichi Trilogy'
#  'The Moment After Collection'
#  'Bananas!* Collection'
#  'Panda! Go Panda! Collección'
#  'The Human Centipede Collection'
#  'Willard'
#  'Stray Cat Rock Collection'
#  'King of the Zombies Collection'
#  'Stray Cat Rock Collection'
#  'Iron Man Collection'
#  '3 Men (Original) Collection'
#  '男はつらいよ シリーズ'
#  'A Nightmare on Elm Street Collection'
#  "St. Trinian's Collection"
#  '男はつらいよ シリーズ'
#  '男はつらいよ シリーズ'
#  'Demonic Toys Collection'
#  'Trilogia Zé do Caixão'
#  'Sex and the City Collection'
#  'Tales of the Four Seasons'
#  'Burnt by the Sun Trilogy'
#  'Kidulthood Collection'
#  'The Descent Collection'
#  'Toy Story Collection'
#  'Nekromantik Collection'
#  'Täällä Pohjantähden alla (Timo Koivusalo)'
#  'Shrek Collection'
#  'Rampage Collection'
#  'The Moment After Collection'
#  'Troll Collection'
#  'The Twilight Collection'
#  'Destricted'
#  'Ernest Collection'
#  'Predator Collection'
#  'Despicable Me Collection'
#  'Grown Ups Collection'
#  'Creepshow Collection'
#  'Nanny McPhee Collection'
#  'Little Nicholas Collection'
#  'Ip Man Collection'
#  'The Wolf Man (Universal Series)'
#  'The Invisible Man (Universal Series)'
#  'The Expendables Collection'
#  'Piranha 3D Collection'
#  'Center Stage Collection'
#  'Tekken Collection'
#  "The President's Man Collection"
#  'Dragon Ball Z (Movie) Collection'
#  'The Last Exorcism Collection'
#  'Jackass Collection'
#  'Gasland Collection'
#  'Machete Collection'
#  'Step Up Collection'
#  'Tarzan (Lex Barker series)'
#  'Vampires Suck Collection'
#  'Men in the City Collection'
#  'Resident Evil Collection'
#  'Superman / Batman (Animated) Collection'
#  'Wall Street Collection'
#  'Cats & Dogs Collection'
#  'Lone Wolf and Cub Collection'
#  'Lone Wolf and Cub Collection'
#  'Mr. Moto Collection'
#  'Monsters Collection'
#  'Lost Boys Collection'
#  'Barefoot Gen Collection'
#  'Jackass Collection'
#  'Korengal Valley Documentaries'
#  '30 Days of Night Collection'
#  'RED Collection'
#  'The Olsen Gang Collection'
#  'Le Gendarme de St. Tropez Collection'
#  'Paranormal Activity Collection'
#  'Undisputed Collection'
#  'The Olsen Gang Collection'
#  'Saw Collection'
#  "Sammy's Adventure Collection"
#  'The Riffs Trilogy'
#  'Ten Minutes Older... (Collection)'
#  'Shrek Collection'
#  'The Bill Douglas Trilogy'
#  'Harry Potter Collection'
#  'Tangled Collection'
#  'The Lost Skeleton Collection'
#  'The Bill Douglas Trilogy'
#  'Cocaine Cowboys'
#  'The Dick Proenneke Collection'
#  'The August Underground Collection'
#  'The Chronicles of Narnia Collection'
#  "It's Alive Collection"
#  'Rare Exports Collection'
#  'Hatchet Collection'
#  'Shiloh Collection'
#  'TRON Collection'
#  "It's Alive Collection"
#  'The One-Armed Swordsman Collection'
#  'Demonic Toys Collection'
#  'Sarah
#  'Garfield Holiday Celebrations'
#  'Meet the Parents Collection'
#  'The Lord of the Rings Animated Collection'
#  'Klovn'
#  'Tere Bin Laden Collection'
#  'Topper Collection'
#  'Trilogia Zé do Caixão'
#  'Trilogia Zé do Caixão'
#  'Pane
#  'Ong Bak Collection'
#  'Outrage Collection'
#  'Vares Collection'
#  'Dexter Riley Collection'
#  'The Magick Lantern Cycle'
#  'The Trip Collection'
#  'Rebuild of Evangelion'
#  'I Spit on Your Grave Collection'
#  'Corto Maltese'
#  'Zeitgeist Collection'
#  "Rosemary's Baby Collection"
#  'Home Alone Collection'
#  'Mirrors Collection'
#  'The Spiders Serial'
#  'Brother Collection'
#  'Napapiirin sankarit'
#  'Mechanic Collection'
#  'Corto Maltese'
#  'Corto Maltese'
#  'Ringu Collection'
#  'Scooby-Doo Collection'
#  'Fubar Collection'
#  'Scooby-Doo Collection'
#  'Elite Squad Collection'
#  'The Mesrine Collection'
#  "Big Momma's House Collection"
#  'Täällä Pohjantähden alla (Timo Koivusalo)'
#  'The Wog Boy Collection'
#  'Unna Trilogie'
#  'Death Note Collection'
#  'Insidious Collection'
#  'Death Note Collection'
#  'Dead Space Collection'
#  'Diary of a Wimpy Kid Collection'
#  'Flodder Collection'
#  'Hababam Sınıfı Collection'
#  'Hababam Sınıfı Collection'
#  'Hababam Sınıfı Collection'
#  'New Kids Collection'
#  'Easy Money Collection'
#  'Daffy Duck Movie Collection'
#  'Scream Collection'
#  'Rio Collection'
#  'Thor Collection'
#  'Atlas Shrugged Collection'
#  'Benvenuti al... Collection'
#  'Silent Night
#  'Keinohrhasen Filmreihe'
#  'The Fast and the Furious Collection'
#  'The Storm Riders Collection'
#  'Eye of the Dolphin Collection'
#  'Mothra Collection'
#  'Godzilla (Showa) Collection'
#  'Pirates of the Caribbean Collection'
#  'The Hangover Collection'
#  'Loose Change Collection'
#  'Godzilla (Showa) Collection'
#  'Martin Scorsese’s World Cinema Project
#  'Open Season Collection'
#  'Turbulence Collection'
#  'Kung Fu Panda Collection'
#  'X-Men Collection'
#  'The Gods Must Be Crazy Collection'
#  'Vääpeli Körmy - Collection'
#  'Godzilla (Showa) Collection'
#  'Vääpeli Körmy - Collection'
#  'Elektra Luxx Collection'
#  "Mickey's Upon a Christmas Collection"
#  'Why Did I Get Married Collection'
#  'Transformers Collection'
#  'Trilogía Sollima'
#  'Vääpeli Körmy - Collection'
#  'Philo Vance Collection'
#  'Pekko aikamiespoika Collection'
#  'Vääpeli Körmy - Collection'
#  'Vääpeli Körmy - Collection'
#  'McDull Collection'
#  'Horrible Bosses Collection'
#  'Cars Collection'
#  'I Am Curious Collection'
#  'Bikini Summer Collection'
#  'Dhamaal Collection'
#  'Lonesome Dove Collection'
#  'Truth in 24 Collection'
#  'Harry Potter Collection'
#  'Captain America Collection'
#  'Quarantine Collection'
#  'Martin Scorsese’s World Cinema Project
#  'Mr. Moto Collection'
#  'Beverly Hills Chihuahua Collection'
#  'The One-Armed Swordsman Collection'
#  'Monsters
#  'The Smurfs (Theatrical) Collection'
#  'Lonesome Dove Collection'
#  'Lonesome Dove Collection'
#  'Alpha and Omega Collection'
#  'Bikini Summer Collection'
#  'Fred Collection'
#  'Death Race Collection'
#  'East is East Collection'
#  'Planet of the Apes (Reboot) Collection'
#  'Gantz Collection'
#  'Final Destination Collection'
#  'Harold & Kumar Collection'
#  'Mr. Moto Collection'
#  'Mr. Moto Collection'
#  'Onomichi Trilogy'
#  'Spy Kids Collection'
#  'Fright Night (Reboot) Collection'
#  'Cold Prey Collection'
#  'Stake Land Collection'
#  'The Messengers Collection'
#  'Birdemic Collection'
#  'The Worricker Collection'
#  'The Inbetweeners Collection'
#  'Fat
#  'Totò Collection'
#  'Masti Collection'
#  'Ironclad Collection'
#  'The Avengers Collection'
#  'The Thing Collection'
#  'Men in the City Collection'
#  'Behind Enemy Lines Collection'
#  'The Dick Proenneke Collection'
#  'The Dick Proenneke Collection'
#  'Paranormal Activity Collection'
#  'Blondie Collection'
#  'Johnny English Collection'
#  'Totò Collection'
#  'Sometimes They Come Back Collection'
#  'Dreileben'
#  'Daffy Duck Movie Collection'
#  'The Muppet Collection'
#  'The Twilight Collection'
#  'Singham Collection'
#  'Cinderella Story Collection'
#  'Gantz Collection'
#  'Xtro Collection'
#  'The Gruffalo Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Asterix and Obelix (Animation) Collection'
#  'Happy Feet Collection'
#  'The Expendables Collection'
#  'The Snowman Collection'
#  'Sharktopus Collection'
#  'The Hunger Games Collection'
#  'The Dark Knight Collection'
#  'The Bourne Collection'
#  'Sherlock Holmes Collection'
#  'Macon County Collection'
#  'Mr. Bones Collection'
#  'Mission
#  'Alvin and the Chipmunks Collection'
#  'Disney Buddies Collection'
#  'Born To Race Collection'
#  'Dolphin Tale Collection'
#  'Cat Run Collection'
#  'Underworld Collection'
#  'The Human Centipede Collection'
#  'Hostel Collection'
#  'Martin Scorsese’s World Cinema Project
#  "Puss 'n Boots Collection"
#  'Six Degrees of Celebration Collection'
#  'Six Degrees of Celebration Collection'
#  'Grave Encounters Collection'
#  'Detective Dee Collection'
#  'The Woman in Black Collection'
#  'Journey Collection'
#  'Kokowääh Filmreihe'
#  "Smokin' Aces Collection"
#  'The Dead Collection'
#  'Ghost Rider Collection'
#  'Mega Shark Collection'
#  'Wrong Turn Collection'
#  'Dr Goldfoot Collection'
#  'Mr. Moto Collection'
#  'Trailer Park Boys Collection'
#  'Goon Collection'
#  'Jump Street Collection'
#  'Letters to Santa Collection'
#  'Eden of the East Collection'
#  'Eden of the East Collection'
#  'Clash of the Titans Collection'
#  'The Incredible Hulk (TV Movie) Collection'
#  'Iron Sky Collection'
#  'American Pie Collection'
#  'The Raid Collection'
#  'Gamma One Collection'
#  'La trilogie de la mort – Nacho Cerda'
#  'Housefull Collection'
#  'Best Exotic Marigold Hotel Collection'
#  'Boston Blackie Series'
#  'Spud Collection'
#  'Think Like a Man Collection'
#  'Feast Collection'
#  'The Scorpion King Collection'
#  'Bananas!* Collection'
#  'Three Steps Above Heaven Collection'
#  'Boys Love Collection'
#  'Largo Winch Collection'
#  'Men In Black Collection'
#  'The Huntsman Collection'
#  'Night of the Demons Collection'
#  'Prometheus Collection'
#  'The Pact Collection'
#  'Vares Collection'
#  'A Few Best Men Collection'
#  'Madagascar Collection'
#  'The Magick Lantern Cycle'
#  'The Magick Lantern Cycle'
#  'Dragon Ball Collection'
#  'Dragon Ball Collection'
#  'Superman / Batman (Animated) Collection'
#  'Dead Space Collection'
#  'Dragon Ball Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Beauty and the Beast Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Pocahontas Collection'
#  'Ted Collection'
#  'Magic Mike Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'The Amazing Spider-Man Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Wrong Turn Collection'
#  'Ice Age Collection'
#  'Balto Collection'
#  'Mr. Wong Collection'
#  '2 Days In... Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Anaconda Collection'
#  'Immaturi Collection'
#  'Dragon Ball Z (Movie) Collection'
#  'Dragon Ball Z OVA Collection'
#  'Subspecies Collection'
#  'La Classe Américaine & Cie'
#  'In the Name of the King Collection'
#  'Dragon Ball Z OVA Collection'
#  'Dick Tracy 1940s Collection'
#  'Decoys Collection'
#  'The Little Mermaid Collection'
#  'James Bond Collection'
#  'Bullit & Riper Collection'
#  "The President's Man Collection"
#  'Diary of a Wimpy Kid Collection'
#  'Cinderella Collection'
#  'Piranha 3D Collection'
#  'Paradise Lost Collection'
#  'Pitch Perfect Collection'
#  "Les Mystères de l'ouest (Collection)"
#  'Arthur and the Invisibles Collection'
#  'Deathstalker Collection'
#  'Deathstalker Collection'
#  'Resident Evil Collection'
#  "Les Mystères de l'ouest (Collection)"
#  "Manuale d'amore - Collezione"
#  'Laid to Rest Collection'
#  'V/H/S Collection'
#  'Taken Collection'
#  'Bleach (Collection)'
#  'Evil Bong Collection'
#  'Design Trilogy'
#  'Sinister Collection'
#  'Hotel Transylvania Collection'
#  'Dr. Who Collection'
#  'Charlie Chan (Warner Oland) Collection'
#  'Charlie Chan (Warner Oland) Collection'
#  'We Are From The Future Collection'
#  'Atlas Shrugged Collection'
#  'Ator Collection'
#  'Marley & Me Collection'
#  'Thermae Romae Collection'
#  'Hoodwinked! Collection'
#  '[REC] Collection'
#  'Gangs of Wasseypur Collection'
#  'Asterix and Obelix Collection'
#  'The Up Series'
#  'Paranormal Activity Collection'
#  'Tai Chi Collection'
#  'Alex Cross Collection'
#  'Silent Hill Collection'
#  'Mann Filmreihe'
#  'Pumping Iron Collection'
#  'Wreck-It Ralph Collection'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-bf35ef38a397> in <module>
#       4         #print(m['belongs_to_collection'])
#       5         #print(m['belongs_to_collection'].replace("\'", "\""))
# ----> 6         print(m['belongs_to_collection'].split(",")[1].split(":")[1])
#       7         #dfdict[i] = json.loads(m['belongs_to_collection'].replace("\'", "\"").replace('None',"\"None\""))
#       8     else:
#
# IndexError: list index out of range

# %%
dfdict = []
for i,m in movies.iterrows():
    if str(m['genres'])!='[]':
        dfdict.append(m['genres'].split(",")[1].split(":")[1].split("}")[0].replace("'",""))
    else:
        dfdict.append(None)

# %%
dfdict = {}
for i,m in movies.iterrows():
    if str(m['production_companies'])!='[]':
        print(m['production_companies'].split(",")[0].split(":")[1])
    else:
        dfdict[i] = None
# Out:
#  'Pixar Animation Studios'
#  'TriStar Pictures'
#  'Warner Bros.'
#  'Twentieth Century Fox Film Corporation'
#  'Sandollar Productions'
#  'Regency Enterprises'
#  'Paramount Pictures'
#  'Walt Disney Pictures'
#  'Universal Pictures'
#  'United Artists'
#  'Columbia Pictures'
#  'Columbia Pictures'
#  'Universal Pictures'
#  'Hollywood Pictures'
#  'Le Studio Canal+'
#  'Universal Pictures'
#  'Columbia Pictures Corporation'
#  'Miramax Films'
#  'O Entertainment'
#  'Columbia Pictures'
#  'Jersey Films'
#  'Regency Enterprises'
#  'Silver Pictures'
#  'Caravan Pictures'
#  'United Artists'
#  'Columbia Pictures'
#  'New Line Cinema'
#  'BBC Films'
#  'Procirep'
#  'Ministère des Affaires Étrangères'
#  'Hollywood Pictures'
#  'Universal Pictures'
#  'Iwerks Entertainment'
#  'Universal Pictures'
#  'StudioCanal'
#  'Havoc'
#  'Sony New Technologies'
#  'Dualstar Productions'
#  'Paramount Pictures'
#  'Miramax'
#  'British Screen'
#  'Caravan Pictures'
#  'Miramax Films'
#  'New Line Cinema'
#  'The Rank Organisation'
#  'Universal Pictures'
#  'New Line Cinema'
#  'Walt Disney Pictures'
#  'Alliance Communications Corporation'
#  'Blue Parrot Productions'
#  'Miramax Films'
#  'Walt Disney Pictures'
#  'Miramax Films'
#  'Telefilm Canada'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Hollywood Pictures'
#  'Miramax Films'
#  'Warner Bros.'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'New Line Cinema'
#  'Miramax Films'
#  'Renn Productions'
#  'New Line Cinema'
#  'A Band Apart'
#  'Silver Pictures'
#  'Castleberg Productions'
#  'Les Films 13'
#  'New Line Cinema'
#  'Warner Bros.'
#  'The Movie Network (TMN)'
#  'Zweites Deutsches Fernsehen (ZDF)'
#  'Miramax Films'
#  'Columbia Pictures Corporation'
#  'I.R.I.B. Channel 2'
#  'Miramax Films'
#  'Bergen Film'
#  'BET Pictures'
#  'Playhouse International Pictures'
#  'Hollywood Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Miramax Films'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Miramax Films'
#  'Twentieth Century Fox Film Corporation'
#  'Castle Rock Entertainment'
#  'Egg Pictures'
#  'Channel Four Films'
#  'British Broadcasting Corporation (BBC)'
#  'Columbia Pictures'
#  'Gracie Films'
#  'Touchstone Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Universal Pictures'
#  'Amblin Entertainment'
#  'Walt Disney Pictures'
#  'Icon Entertainment International'
#  'Columbia Pictures Corporation'
#  'New Line Cinema'
#  'Caravan Pictures'
#  'Téléfilm Canada'
#  'France 2 Cinéma'
#  'Bavaria Film and Television Fund'
#  'TriStar Pictures'
#  'Savoy Pictures'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Jet Tone Production'
#  'Cecchi Gori Group Tiger Cinematografica'
#  'Miramax Films'
#  'Studio Babelsberg'
#  'Canal Horizons'
#  'Fine Line Features'
#  'Paramount Pictures'
#  'Cigua Films'
#  'Twentieth Century Fox Film Corporation'
#  'Couch Potatoe Productions'
#  'Channel Four Films'
#  'Cinergi Pictures Entertainment'
#  'United Artists'
#  'Fox Searchlight Pictures'
#  'Columbia Pictures'
#  'Warner Bros.'
#  'New Line Cinema'
#  'Fine Line Features'
#  'Channel Four Films'
#  'Imagine Entertainment'
#  'United Artists'
#  'October Films'
#  'Warner Bros.'
#  'Paris Films Productions'
#  'Columbia Pictures'
#  'Miramax Films'
#  'PolyGram Filmed Entertainment'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Hollywood Pictures'
#  'Superior Pictures'
#  'Columbia Pictures'
#  'TriStar Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Why Not Productions'
#  'Touchstone Pictures'
#  'Columbia Pictures Corporation'
#  'Regency Enterprises'
#  'United Artists'
#  'The Booking Office'
#  'TriStar Pictures'
#  'Hollywood Pictures'
#  'TriStar Pictures'
#  'Miramax Films'
#  'JDI productions'
#  'United Artists'
#  'The Ontario Film Development Corporation'
#  'Touchstone Pictures'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'PolyGram Filmed Entertainment'
#  'Comet Film Produktion GmbH'
#  'Kino Link Company'
#  'Columbia Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Party Productions'
#  'Dimension Films'
#  'Playhouse International Pictures'
#  'Killer Films'
#  'Hollywood Pictures'
#  'United Artists'
#  'Miramax Films'
#  'Spring Creek Productions'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Malpaso Productions'
#  'Lightstorm Entertainment'
#  'Beta Film'
#  'Hollywood Pictures'
#  'Savoy Pictures'
#  'Société Française de Production (SFP)'
#  'Universal Pictures'
#  'Regency Enterprises'
#  'Hollywood Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Universal Pictures'
#  'HBO'
#  'United Artists'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Canal+'
#  'PolyGram Audiovisuel'
#  'Detour Film Production'
#  'Jack Giarraputo Productions'
#  'Spelling Films International'
#  'Regency Enterprises'
#  'Universal Pictures'
#  'Full Moon Entertainment'
#  'The Rank Organisation'
#  'Miramax Films'
#  'New Line Cinema'
#  'Warner Bros.'
#  'Keystone Pictures'
#  'Paramount Pictures'
#  'Savoy Pictures'
#  'Fine Line Features'
#  'Castle Rock Entertainment'
#  'New Line Cinema'
#  'Ang Lee Productions'
#  'Miramax Films'
#  'Savoy Pictures'
#  'Touchstone Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Columbia Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Walt Disney Pictures'
#  'TriStar Pictures'
#  'Metro-Goldwyn-Mayer'
#  'Italian International Film'
#  'Miramax Films'
#  'Fine Line Features'
#  'WingNut Films'
#  'Caravan Pictures'
#  'Columbia Pictures'
#  'Walt Disney Pictures'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Geffen Pictures'
#  'Merchant Ivory Productions'
#  'Caravan Pictures'
#  'Universal Pictures'
#  'Fountainbridge Films'
#  'Walt Disney Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Lucasfilm'
#  'Columbia Pictures'
#  'Warner Bros.'
#  'Channel Four Films'
#  'MK2 Productions'
#  'Aviacsa'
#  'Bedford Falls Productions'
#  'Universal Pictures'
#  'Fine Line Features'
#  'Channel Four Films'
#  'Warner Bros.'
#  'Paramount Pictures'
#  'Channel Four Films'
#  'American Zoetrope'
#  'Walt Disney Pictures'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Hollywood Pictures'
#  'American Zoetrope'
#  'Wolper Organization'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  '40 Acres & A Mule Filmworks'
#  'TOEI'
#  'Metrodome Films'
#  'Filmwerks'
#  'Triumph Films'
#  'Regency Enterprises'
#  'TriStar Pictures'
#  'Avalon Studios'
#  'New Line Cinema'
#  'Kopelson Entertainment'
#  'Columbia Pictures'
#  'Samuel Goldwyn Company
#  'Hollywood Pictures'
#  'Miramax Films'
#  'Polygram Filmed Entertainment'
#  'Ang Lee Productions'
#  'BBC Films'
#  'Wildwood Enterprises'
#  'Cecile Company'
#  'Renn Productions'
#  'TriStar Pictures'
#  'Hollywood Pictures'
#  'Miramax Films'
#  'Zespół Filmowy TOR'
#  'France 3 Cinéma'
#  'Le Studio Canal+'
#  'Allegro Films'
#  'Paramount Pictures'
#  'Rich Animation Studios'
#  'Jones Entertainment Group'
#  'Jerry Weintraub Productions'
#  'Centropolis Entertainment'
#  'Walt Disney Pictures'
#  'Castle Rock Entertainment'
#  'Channel Four Films'
#  'Kino Korsakoff'
#  'Miramax Films'
#  'Cineville'
#  'Samuel Goldwyn Company'
#  'New Line Cinema'
#  'Shanghai Film Studios'
#  'Trilogy Entertainment Group'
#  'Universal Pictures'
#  'Paramount Pictures'
#  '40 Acres & A Mule Filmworks'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Sony Pictures Classics'
#  'Populist Pictures'
#  'Savoy Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Caravan Pictures'
#  'Universal Pictures'
#  'Fine Line Features'
#  'Ciby 2000'
#  'Columbia Pictures Corporation'
#  'Warner Bros.'
#  'PolyGram Filmed Entertainment'
#  'Gramercy Pictures'
#  'Fine Line Features'
#  'Miramax Films'
#  'Paramount Pictures'
#  'Regency Enterprises'
#  'New Line Cinema'
#  'Universal Pictures'
#  'Miramax Films'
#  'Regency Enterprises'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Channel Four Films'
#  'Columbia Pictures Corporation'
#  'Columbia Pictures Corporation'
#  'Caravan Pictures'
#  'TriStar Pictures'
#  'Channel Four Films'
#  'Walt Disney Pictures'
#  'Miramax Films'
#  'New Line Cinema'
#  'New Line Cinema'
#  'Icon Entertainment International'
#  'Fine Line Features'
#  'Paramount Pictures'
#  'Imagine Entertainment'
#  'Universal Pictures'
#  'Propaganda Films'
#  'Davis Entertainment'
#  'New Line Cinema'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Touchstone Pictures'
#  'Columbia Pictures'
#  'Tig Productions'
#  'Touchstone Pictures'
#  'BBC Films'
#  'Gramercy Pictures'
#  'Caravan Pictures'
#  'Strand Releasing'
#  'Eve Productions Inc.'
#  'Bolex Brothers'
#  'Universal Pictures'
#  'Propaganda Films'
#  'Live Entertainment'
#  'A-Pix Entertainment'
#  'Walt Disney Pictures'
#  'Overseas FilmGroup'
#  'Skyline Entertainment Partners'
#  'Home Box Office (HBO)'
#  'Trans-Film'
#  'New Line Cinema'
#  'New Line Cinema'
#  'New Line Cinema'
#  'Paramount Pictures'
#  'HBO Independent Productions'
#  'Columbia Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Hollywood Pictures'
#  'Touchstone Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Fine Line Features'
#  'Warner Bros.'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Warner Bros.'
#  'New Line Cinema'
#  'Trilogy Entertainment Group'
#  'Paramount Pictures'
#  'Orion Pictures Corporation'
#  'Warner Bros.'
#  'Mainline Pictures'
#  'HBO Films'
#  'Touchstone Pictures'
#  'Columbia Pictures'
#  'Universal Pictures'
#  'Columbia Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Hollywood Pictures'
#  'TriStar Pictures'
#  'Imagine Entertainment'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Donner/Shuler-Donner Productions'
#  'Gramercy Pictures'
#  'Silver Pictures'
#  'Fine Line Features'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Beijing Film Studio'
#  'Orion Pictures'
#  'Spring Creek Productions'
#  'Spring Creek Productions'
#  'Paramount Pictures'
#  'Fine Line Features'
#  'Universal Studios'
#  'Paramount Pictures'
#  'Canal Plus'
#  'Miramax Films'
#  'Warner Bros.'
#  'Columbia Pictures'
#  'Universal Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Killer Films'
#  'Gramercy Pictures'
#  'Hollywood Pictures'
#  'Universal Pictures'
#  'Regency Enterprises'
#  'Twentieth Century Fox Film Corporation'
#  'Spelling Entertainment'
#  'Miramax Films'
#  'Det Danske Filminstitut'
#  'PolyGram Filmed Entertainment'
#  'Gracie Films'
#  'Hollywood Pictures'
#  'Castle Rock Entertainment'
#  'Universal Pictures'
#  'Touchstone Pictures'
#  'Touchstone Pictures'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Propaganda Films'
#  'Live Entertainment'
#  'Gramercy Pictures'
#  'Paramount Pictures'
#  'Columbia Pictures Corporation'
#  'Touchstone Pictures'
#  'Savoy Pictures'
#  'Geffen Pictures'
#  'Regency Enterprises'
#  'Columbia Pictures'
#  'Icon Entertainment International'
#  'TriStar Pictures'
#  'New Line Cinema'
#  'Silver Pictures'
#  'Argos Films'
#  'The Samuel Goldwyn Company'
#  'Renaissance Films'
#  'TriStar Pictures'
#  'Warner Bros.'
#  'Twentieth Century Fox Film Corporation'
#  'Thin Man Films'
#  'Columbia Pictures Corporation'
#  'Regency Enterprises'
#  'Columbia Pictures Corporation'
#  'Columbia Pictures'
#  'Mikado Film'
#  'Malpaso Productions'
#  'TriStar Pictures'
#  'New South Wales Film & Television Office'
#  'Columbia Pictures'
#  'Touchstone Pictures'
#  'Hollywood Pictures'
#  'Universal Pictures'
#  'Touchstone Pictures'
#  'Columbia Pictures'
#  'Cinergi Pictures Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'Columbia Pictures'
#  'Orion Pictures'
#  'Gaumont'
#  'Working Title Films'
#  'The Australian Film Commission'
#  'Ruby in Paradise'
#  'TriStar Pictures'
#  'David V. Picker Productions'
#  'Société Nouvelle de Cinématographie'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Mirage Enterprises'
#  'Regency Enterprises'
#  'American Zoetrope'
#  'Savoy Pictures'
#  'Universal Pictures'
#  'Shadowlands Productions'
#  'Fine Line Features'
#  'Touchstone Pictures'
#  'Miramax Films'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Shaw Brothers'
#  'Hollywood Pictures'
#  'TriStar Pictures'
#  'Columbia Pictures Industries'
#  'Hollywood Pictures'
#  'New Line Cinema'
#  'Hollywood Pictures'
#  'Rhombus Media'
#  'TriStar Pictures'
#  'Tim Burton Productions'
#  'Walt Disney Pictures'
#  'Hollywood Pictures'
#  'Warner Bros.'
#  'Davis-Films'
#  'Twentieth Century Fox Film Corporation'
#  'Téléfilm Canada'
#  'Republic Pictures (II)'
#  'Renn Productions'
#  'Warner Bros.'
#  'CNCAIMC'
#  'Fine Line Features'
#  'CiBy 2000'
#  'Channel 4 Television'
#  'Columbia Pictures'
#  'SVT Drama'
#  'Fine Line Features'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'TriStar Pictures'
#  'Sony Pictures Classics'
#  'Sacher Film'
#  'Oscar Kramer S.A.'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Walt Disney Pictures'
#  'Lightstorm Entertainment'
#  'Tig Productions'
#  'Shapiro-Glickenhaus Entertainment'
#  'PolyGram Filmed Entertainment'
#  'Orion Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'RKO Radio Pictures'
#  'Touchstone Pictures'
#  'Sodaperaga Productions'
#  'Warner Brothers/Seven Arts'
#  'Trimark Pictures'
#  'Long Shong Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Propaganda Films'
#  'BBC'
#  'PolyGram Filmed Entertainment'
#  'Walt Disney Pictures'
#  'Canadian Film Development Corporation (CFDC)'
#  'Miramax Films'
#  'Miramax Films'
#  'Miramax Films'
#  'Walt Disney Productions'
#  'El Deseo'
#  'PolyGram Filmed Entertainment'
#  'Universal Pictures'
#  'TF1 Films Productions'
#  'Cinétéléfilms'
#  'New Line Cinema'
#  'Columbia Pictures Corporation'
#  'Paramount Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Road Movies Filmproduktion GmbH'
#  'Davis Entertainment'
#  'New Line Cinema'
#  'United Artists'
#  'Imagine Entertainment'
#  'Granada Film Productions'
#  'Fox Searchlight Pictures'
#  'Marvin Worth Productions'
#  'Procirep'
#  'Roxy Film'
#  'Westdeutscher Rundfunk (WDR)'
#  'Senator Film Produktion'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Icicle'
#  'Trilogy Entertainment Group'
#  'Constantin Film'
#  'Park Chul-Soo Films Ltd.'
#  'Universal Pictures'
#  'Hollywood Pictures'
#  'Distant Horizons'
#  'Titanus'
#  'Granada Film Productions'
#  'Walt Disney Pictures'
#  'Imagine Entertainment'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'Komuna'
#  'Per Holst Filmproduktion'
#  'FM Entertainment International N.V.'
#  'Government of West Bengal'
#  'Satyajit Ray Productions'
#  'Universal Pictures'
#  'Warner Bros. Family Entertainment'
#  'Paramount Pictures'
#  'Libra Pictures'
#  'Castle Rock Entertainment'
#  'Filmstudio'
#  'Films A2'
#  'Mike Lobell Productions'
#  'Opala Productions'
#  'Walt Disney Pictures'
#  'Studio Babelsberg'
#  'TriStar Pictures'
#  'Van Peebles Films'
#  'Live Entertainment'
#  'Dan Films'
#  'Fine Line Features'
#  'New Line Cinema'
#  'New Line Cinema'
#  'Favorite Films'
#  'Maurice McEndree Productions'
#  'PolyGram Filmed Entertainment'
#  'Universal Pictures'
#  'Jersey Films'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Twentieth Century Fox Film Corporation'
#  'Walt Disney Pictures'
#  'Caravan Pictures'
#  'Universal Pictures'
#  'Distant Horizons'
#  'Miramax Films'
#  'JVC Entertainment'
#  'France 2 Cinéma'
#  'Centaur Pictures Inc.'
#  'Canal Plus'
#  'Columbia Pictures Corporation'
#  'Wood-Thomas Pictures'
#  'Columbia Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Touchstone Pictures'
#  'Pandora Filmproduktion'
#  'New Line Cinema'
#  "Po' Boy Productions"
#  'Hollywood Pictures'
#  'The Rank Organisation'
#  'Canal+'
#  'Universal Pictures'
#  'Propaganda Films'
#  'France 2 Cinéma'
#  'Roxy Film'
#  'Bandai Visual Company'
#  'Paramount Pictures'
#  'Hollywood Pictures'
#  'Renegade Films'
#  'Aardman Animations'
#  'Enterprise Productions'
#  'New Line Cinema'
#  'Live Entertainment'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Hawk Films'
#  'the Canadian Council'
#  'Miramax Films'
#  'Universal Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Channel Four Films'
#  'Beijing Film Studio'
#  'Royal Film'
#  'Paramount Pictures'
#  'Columbia Pictures'
#  'Available Light Productions'
#  'American Zoetrope'
#  'Playhouse International Pictures'
#  'Fine Line Features'
#  'MACT Productions'
#  'Stéphan Films'
#  'Studio Kankourama'
#  'Direction du Cinema Haute Volta'
#  'Cocinor'
#  'Independent Television Service'
#  'Miramax Films'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Fox Searchlight Pictures'
#  'TriStar Pictures'
#  'Walt Disney Pictures'
#  'Columbia Pictures Corporation'
#  'Motion Picture Corporation of America'
#  'Kopelson Entertainment'
#  'Imagine Entertainment'
#  'GEA Cinematográfica'
#  'Canal Plus'
#  'First Run Features'
#  'Initial Productions'
#  'Films A2'
#  'Universal Pictures'
#  'WingNut Films'
#  'Castle Rock Entertainment'
#  'Paramount Pictures'
#  'Touchstone Pictures'
#  'Channel Four Films'
#  'Fox Searchlight Pictures'
#  'Regency Enterprises'
#  'Channel Four Films'
#  'Canal+'
#  'Castle Rock Entertainment'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Touchstone Pictures'
#  'Új Budapest Filmstudió'
#  'United Artists'
#  'British Broadcasting Corporation (BBC)'
#  'Paramount Pictures'
#  'Producciones Tepeyac'
#  'Rome Paris Films'
#  'TLA Releasing'
#  'New Line Cinema'
#  'Scott Rudin Productions'
#  'Killer Films'
#  'Touchstone Pictures'
#  'TriStar Pictures'
#  'Orion Pictures'
#  'Rysher Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'Jersey Films'
#  'Miramax Films'
#  'Miramax Films'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Lux Film'
#  'Universal Pictures'
#  'Zeta Entertainment'
#  'Castle Rock Entertainment'
#  'Paramount Pictures'
#  'Cofimage 5'
#  'Miramax'
#  'Regency Enterprises'
#  'Vertigo Productions'
#  'Shochiku Company'
#  'MK2 Production'
#  'Paramount Pictures'
#  'Constantin Film'
#  'Golden Harvest Company'
#  'Pope Productions'
#  'Toho Company'
#  'Dino De Laurentiis Company'
#  'Regency Enterprises'
#  'Australian Film Finance Corporation (AFFC)'
#  'Fine Line Features'
#  'Caravan Pictures'
#  'Central Motion Pictures'
#  'Albatros Produktion'
#  'Ixtlan Productions'
#  'Golden Harvest Company'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'Walt Disney Pictures'
#  'Universal Pictures'
#  'Regency Enterprises'
#  'Universal Pictures'
#  'Kanzaman'
#  'Universal Cartoon Studios'
#  'Miramax Films'
#  'Fine Line Features'
#  'Fine Line Features'
#  'Elite-Tonfilm-Produktion GmbH'
#  'Les Films Alain Sarde'
#  'Paramount Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  "Loew's"
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Columbia Pictures Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'RKO Radio Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'United Artists'
#  'The Mirisch Corporation'
#  'Universal Pictures'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  "Loew's"
#  "Loew's Incorporated"
#  'Selznick International Pictures'
#  'Brooksfilms'
#  'Paramount Pictures'
#  'RKO Radio Pictures'
#  'Stanley Kubrick Productions'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Selznick International Pictures'
#  'United Artists'
#  'RKO Radio Pictures'
#  'Selznick International Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Allied Artists Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Warner Bros.'
#  'Twentieth Century Fox Film Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Columbia Pictures Corporation'
#  'RKO Radio Pictures'
#  'United Artists'
#  'Universal Pictures'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Columbia Pictures'
#  'Michael Todd Company'
#  'RKO Radio Pictures'
#  'Columbia Pictures'
#  'RKO Radio Pictures'
#  'Columbia Pictures Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Hunt Stromberg Productions'
#  'RKO Radio Pictures'
#  'Premier Productions'
#  'Selznick International Pictures'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Republic Pictures'
#  'Gaumont British Picture Corporation'
#  'Superior Pictures'
#  'Howard Hughes Productions'
#  'Laurel Group'
#  'United Artists'
#  'Santana Pictures Corporation'
#  'Avon Production'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Warner Bros.'
#  'United Artists'
#  'Grand National Pictures'
#  'Paramount Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Channel Four Films'
#  'D & B Films Co. Ltd.'
#  'New Line Cinema'
#  'Columbia Pictures Corporation'
#  'BMG Independents'
#  'Columbia Pictures'
#  'Triumph Films'
#  'Universal Pictures'
#  'Dor Film Produktionsgesellschaft GmbH'
#  'Columbia Pictures'
#  'Geffen Pictures'
#  'Caravan Pictures'
#  'Neo Productions'
#  'Rysher Entertainment'
#  'New Line Cinema'
#  'Cinehaus'
#  'New Line Cinema'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Tinderbox Films'
#  'Columbia Pictures'
#  'Warner Bros.'
#  'Walt Disney'
#  'Imagine Entertainment'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney'
#  'Walt Disney Pictures'
#  'RKO Radio Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Warner Bros.'
#  'Walt Disney Productions'
#  'RKO Radio Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'RKO Radio Pictures'
#  'Walt Disney Productions'
#  'The Kushner-Locke Company'
#  'Twentieth Century Fox Film Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'New Line Cinema'
#  'Miramax Films'
#  'Twentieth Century Fox Film Corporation'
#  'Channel Four Films'
#  'Twentieth Century Fox Film Corporation'
#  'Rastar Pictures'
#  'Merchant Ivory Productions'
#  'Cinema 7'
#  'Channel Four Films'
#  'New Line Cinema'
#  'Constellation Films'
#  'Twentieth Century Fox Film Corporation'
#  'Fine Line Features'
#  'Columbia Pictures'
#  'Hollywood Pictures'
#  'Revolution Films'
#  'Miramax Films'
#  'Overseas FilmGroup'
#  'Bazmark Films'
#  'Miramax Films'
#  'Propaganda Films'
#  'Regency Enterprises'
#  'First Look Pictures'
#  'Walt Disney Television Animation'
#  'Vic Films Productions'
#  'RKO Radio Pictures'
#  'RKO Radio Pictures'
#  'RKO Radio Pictures'
#  'RKO Radio Pictures'
#  'RKO Radio Pictures'
#  'Paramount Pictures'
#  'Transatlantic Films'
#  'Twentieth Century Fox Film Corporation'
#  'Rollins-Joffe Productions'
#  'United Artists'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'HandMade Films'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Tatira-Hiller Productions'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Great American Films Limited Partnership'
#  'Live Entertainment'
#  'Orion Pictures'
#  'Gladden Entertainment'
#  'TriStar Pictures'
#  'Imagine Entertainment'
#  'Miramax Films'
#  'New Line Cinema'
#  'Keith Barish Productions'
#  'Universal Pictures'
#  'Orenda Films'
#  "Loew's"
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Harmony Gold'
#  'Warner Bros.'
#  'Charles K. Feldman Group'
#  'Dimension Films'
#  'Discovery Channel Productions'
#  'Wega Film'
#  'Bac Films'
#  'Playhouse International Pictures'
#  'Universal Pictures'
#  'C&P Productions'
#  'Cinéa'
#  'Eurimages'
#  'Regency Enterprises'
#  'Northern Lights Entertainment'
#  'Sony Pictures'
#  'Woodward Productions'
#  'Universal Pictures'
#  'United Artists'
#  'PolyGram Filmed Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'AVCO Embassy Pictures'
#  'AVCO Embassy Pictures'
#  'AVCO Embassy Pictures'
#  'Renn Productions'
#  'Renn Productions'
#  'Vision Comunicaciones'
#  'Warner Bros.'
#  'Python (Monty) Pictures Limited'
#  'Jürgen Brüning Filmproduktion'
#  'Big Sister Production'
#  'Canal+'
#  'Warren Miller Entertainment'
#  'PolyGram Filmed Entertainment'
#  'Aardman Animations'
#  'Gaumont'
#  'Dussault'
#  'Pandora Cinema'
#  'Bryan Foy Productions'
#  'Eagle-Lion Films'
#  'Edward Small Productions'
#  'Scalera Film S.p.a.'
#  'Paramount Pictures'
#  'Jadran Film'
#  'Keep Films'
#  'UGC PH'
#  'Les Films du Carrosse'
#  'Rysher Entertainment'
#  'Morgan Creek Productions'
#  'Rai Tre Radiotelevisione Italiana'
#  'Elsevira'
#  'Hachette Première'
#  'Canal+'
#  'Miramax Films'
#  'United Artists'
#  'Miramax Films'
#  'Miramax Films'
#  'Royal Oaks Entertainment'
#  'Miramax Films'
#  'Penta Films'
#  'Ferndale Films'
#  'Miramax Films'
#  'Atchafalaya'
#  'Beyond Films'
#  'Third Floor Productions'
#  'El Deseo'
#  'Miramax Films'
#  'United Artists'
#  'Paramount Pictures'
#  'Lucasfilm'
#  'Act III Communications'
#  'Lucasfilm'
#  'Embassy International Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'United Artists'
#  'Handmade Films Ltd.'
#  'United Artists'
#  'Horizon Pictures (II)'
#  'Hawk Films'
#  'Universal Pictures'
#  'United Artists'
#  'Paramount Pictures'
#  'Lucasfilm'
#  'Road Movies Filmproduktion GmbH'
#  'London Film Productions'
#  'Winkler Films'
#  'Twentieth Century Fox Film Corporation'
#  'Universal Pictures'
#  'Gaumont'
#  'Nippon Herald Films'
#  'Film Workshop'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Stanley Kubrick Productions'
#  'Aardman Animations'
#  'BBC Films'
#  'Warner Bros.'
#  'Republic Pictures'
#  'Warner Bros.'
#  'United Artists'
#  'United Artists'
#  'Warner Bros.'
#  'Mosfilm'
#  'Radiant Film GmbH'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Channel Four Films'
#  'Svensk Filmindustri (SF)'
#  'Goldcrest Films International'
#  'Orion Pictures'
#  'WingNut Films'
#  'TriStar Pictures'
#  'Brandenberg'
#  'United Artists'
#  'Twentieth Century Fox Film Corporation'
#  'Touchstone Pictures'
#  'Lawrence Turman'
#  'Universal International Pictures (UI)'
#  'Gaumont'
#  'Columbia Pictures Corporation'
#  'Cineriz'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Warner Bros.'
#  'WingNut Films'
#  'Paramount Pictures'
#  'CBS Entertainment Productions'
#  'Hawk Films'
#  'Columbia Pictures'
#  'Nero-Film AG'
#  'Renaissance Films'
#  'United Artists'
#  'Universal Pictures'
#  'Greenwich Film Productions'
#  'Columbia Pictures'
#  'Malpaso Productions'
#  'United Artists'
#  'New Line Cinema'
#  'Warner Bros.'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Island Pictures'
#  'Bandai Visual Company'
#  'Davis-Panzer Productions'
#  'Warner Bros.'
#  'Hachette Première'
#  'Twentieth Century Fox Film Corporation'
#  'Channel Four Films'
#  'China Film Co-Production Corporation'
#  'United Artists'
#  'Walt Disney Pictures'
#  'United Artists'
#  'Warner Bros.'
#  'New World Pictures'
#  'Rastar Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Spinal Tap Prod.'
#  'IRE Productions'
#  'Paramount Pictures'
#  'Lucasfilm'
#  'United Artists'
#  'Columbia Pictures'
#  'The Saul Zaentz Company'
#  'Goldcrest Films International'
#  'TriStar Pictures'
#  'Goldcrest Films International'
#  'Goldcrest Films International'
#  'Svensk Filmindustri (SF)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Universal Studios'
#  'Persky-Bright Productions'
#  'Twentieth Century Fox Film Corporation'
#  'Channel Four Films'
#  'Village Roadshow Pictures'
#  'Castle Rock Entertainment'
#  'Helvey-Pray Production'
#  'Hit Entertainment'
#  'Degeto Film'
#  'Bruin Grip Services'
#  'Eureka Pictures'
#  'Greenestreet Films'
#  'Skreba Films'
#  'Twentieth Century Fox Film Corporation'
#  'Universal Pictures'
#  'Steve White Productions'
#  'De Laurentiis Entertainment Group (DEG)'
#  'Zeta Entertainment'
#  'A. Ninety-Three Productions'
#  'Dino De Laurentiis Company'
#  'American International Pictures (AIP)'
#  'Allegro Films'
#  'Compagnia Cinematografica Champion'
#  'Paramount Pictures'
#  'Sterobcar Productions'
#  'Orion Pictures'
#  'Alfred J. Hitchcock Productions'
#  'Paramount Pictures'
#  'Compass International Pictures'
#  'Vista Street Entertainment'
#  'RKO Radio Pictures'
#  'American Zoetrope'
#  'Universal Pictures'
#  'United Artists'
#  'Propaganda Films'
#  'Universal Pictures'
#  'Melville-Talbot Productions'
#  'United Artists'
#  'Universal Pictures'
#  'New Line Cinema'
#  'Jofa Atelier'
#  'Reteitalia'
#  'Twentieth Century Fox Film Corporation'
#  'Fox Searchlight Pictures'
#  'Miramax Films'
#  'TriStar Pictures'
#  'Trust Film'
#  'Michael Obel Productions'
#  'Paramount Pictures'
#  'Fine Line Features'
#  'Miramax Films'
#  'Twentieth Century Fox Film Corporation'
#  'Touchstone Pictures'
#  'Sandrews'
#  'Epithète Films'
#  'Twentieth Century Fox Film Corporation'
#  'Walt Disney Pictures'
#  'Pyramide Productions'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'PolyGram Filmed Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'Morgan Creek Productions'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Filmwerks'
#  'Miramax'
#  'Regency Enterprises'
#  'Seltzer Films'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Warner Bros.'
#  'Tim Burton Productions'
#  'Miramax Films'
#  'Gracie Films'
#  'Twentieth Century Fox Film Corporation'
#  'Touchstone Pictures'
#  'Universal Pictures'
#  'New Line Cinema'
#  'Miramax Films'
#  'Redhead Productions'
#  'Columbia Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Prokino Filmproduktion'
#  'Woods Entertainment'
#  'Morgan Creek Productions'
#  'Turner Pictures'
#  'Paramount Pictures'
#  'Castle Rock Entertainment'
#  'Castle Rock Entertainment'
#  'Paramount Pictures'
#  'Les Films Alain Sarde'
#  'Hollywood Pictures'
#  'Propaganda Films'
#  'Si Litvinoff Film Production'
#  'Regency Enterprises'
#  'Elkins Entertainment'
#  'Universal Pictures'
#  'Rysher Entertainment'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Astral Films
#  'Golden Harvest Company'
#  'TriStar Pictures'
#  'Caravan Pictures'
#  'O.T.A. Productions'
#  'Zweites Deutsches Fernsehen (ZDF)'
#  'Universal Pictures'
#  'Columbia Pictures'
#  'Roth-Arnold Productions'
#  'Hollywood Pictures'
#  'Universal Pictures'
#  'Pandora Cinema'
#  'PolyGram Filmed Entertainment'
#  'Sony Pictures Classics'
#  'Paramount Pictures'
#  'Castle Rock Entertainment'
#  'Village Roadshow'
#  'TriStar Pictures'
#  'Columbia Pictures'
#  'United Artists'
#  'Columbia Pictures'
#  'Walt Disney Pictures'
#  'Jerry Weintraub Productions'
#  'Universal Pictures'
#  'Ciby 2000'
#  'New Deal Productions'
#  'TriStar Pictures'
#  'Columbia Pictures'
#  'Stand See'
#  'Orion Pictures'
#  'Orion Pictures'
#  'Walt Disney Pictures'
#  'Mirabai Films'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'Paramount Pictures'
#  'Fox Searchlight Pictures'
#  'Fox Searchlight Pictures'
#  'Fine Line Features'
#  'Imagine Entertainment'
#  'Q Productions'
#  'Columbia Pictures'
#  'Warner Bros. Pictures'
#  'New Line Cinema'
#  'Twentieth Century Fox Film Corporation'
#  'Icon Entertainment International'
#  'Columbia Pictures'
#  'Fox 2000 Pictures'
#  'Columbia Pictures Corporation'
#  'Caravan Pictures'
#  'British Columbia Film'
#  'Orion Pictures'
#  'Fox Searchlight Pictures'
#  'MDP Worldwide'
#  'Baldini Pictures'
#  'La Sept Cinéma'
#  'Touchstone Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Australian Film Finance Corporation (AFFC)'
#  'New Line Cinema'
#  'Paramount Pictures'
#  'New Zealand Film Commission'
#  'C&P Productions'
#  'Triumph Films'
#  'China Film Co-Production Corporation'
#  'Silver Pictures'
#  'Columbia Pictures'
#  'Desperate Pictures'
#  'Hallmark Entertainment'
#  'Studio Babelsberg'
#  'Parc Film'
#  'Fine Line Features'
#  'Altamira Pictures Inc.'
#  'TriStar Pictures'
#  'Figment Films'
#  'Warner Bros.'
#  'Miramax Films'
#  'Universal Pictures'
#  'Les Films Alain Sarde'
#  '.406 Production'
#  'Bruin Grip Services'
#  'Touchstone Pictures'
#  'Goldwyn Films'
#  'New Line Cinema'
#  'Columbia Pictures'
#  'Jerry Bruckheimer Films'
#  'Kasander & Wigman Productions'
#  'Twentieth Century Fox Film Corporation'
#  'Phaedra Cinema'
#  'Curb Entertainment'
#  'PolyGram Filmed Entertainment'
#  'Fine Line Features'
#  'Fine Line Features'
#  'Walt Disney Pictures'
#  'Tapestry Films'
#  'MURDER and murder Production'
#  'TriStar Pictures'
#  'Vertigo Productions'
#  'Rome Paris Films'
#  'Paramount Pictures'
#  'Terence Michael Productions'
#  'MK2 Productions'
#  'Centre National de la Cinématographie (CNC)'
#  'Timedial Films'
#  'Avventura Films'
#  'Amblin Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'Morgan Creek Productions'
#  'Universal Pictures'
#  'Warner Bros.'
#  'New South Wales Film & Television Office'
#  'Caravan Pictures'
#  'Universal Pictures'
#  'Walt Disney Pictures'
#  'Miramax Films'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'Walt Disney Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Alliance Atlantis Communications'
#  'Regency Enterprises'
#  'Channel Four Films'
#  'Silver Pictures'
#  'TriStar Pictures'
#  'Quincy Jones-David Salzman Entertainment'
#  'Miramax Films'
#  'United Artists Pictures'
#  'Universal Pictures'
#  'Miramax Films'
#  'New Line Cinema'
#  'Columbia Pictures Corporation'
#  'Universal Pictures'
#  'Columbia Pictures Corporation'
#  'Icon Entertainment International'
#  'Paramount Pictures'
#  'Fine Line Features'
#  'Capitol Films'
#  'Paramount Pictures'
#  'Art Linson Productions'
#  'DreamWorks SKG'
#  'Regency Enterprises'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Fox 2000 Pictures'
#  'De Fina-Cappa'
#  'Live Entertainment'
#  'Propaganda Films'
#  'PolyGram Filmed Entertainment'
#  'Warner Bros.'
#  'Illusion Entertainment Group'
#  'Good Film Company'
#  'The Movie Network (TMN)'
#  'Paramount Pictures'
#  'Clinica Estetico'
#  'Fox Searchlight Pictures'
#  'Lions Gate Films'
#  'Miramax Films'
#  'Island Pictures'
#  'Channel Four Films'
#  'Greentrees Films'
#  'Miramax Films'
#  'Columbia Pictures Corporation'
#  'Regency Enterprises'
#  'Walt Disney Pictures'
#  'Touchstone Pictures'
#  'Miramax Films'
#  'Caravan Pictures'
#  'Kuzui Enterprises'
#  'Columbia Pictures'
#  'Icon Productions'
#  'Miramax Films'
#  'Tapson Steel Films Productions'
#  'Channel Four Films'
#  'United Artists'
#  'Paramount Pictures'
#  'Orion Pictures'
#  'Columbia Pictures Industries'
#  'Tiger Aspect Productions'
#  'Nomadic Pictures'
#  'Warner Bros.'
#  'New Line Cinema'
#  'Arts Council of England'
#  'Miramax Films'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'Paramount Pictures'
#  'Warner Bros.'
#  'TriStar Pictures'
#  'Live Entertainment'
#  'Hollywood Pictures'
#  '101st Street Films'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'Paramount Pictures'
#  'Miramax Films'
#  'Bergen Film'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Regency Enterprises'
#  'Twentieth Century Fox Film Corporation'
#  'DreamWorks SKG'
#  "Butcher's Run Productions"
#  'France 3 Cinema'
#  'Channel Four Films'
#  'Asylum Films'
#  'Telefilm Canada'
#  'Geffen Pictures'
#  'Fine Line Features'
#  'Walt Disney Pictures'
#  'Universal Pictures'
#  'Miramax Films'
#  'Twentieth Century Fox Film Corporation'
#  'The Image Organization'
#  'Warner Bros.'
#  'DreamWorks'
#  'Miramax Films'
#  'Allegro Films'
#  'Fine Line Features'
#  'Chase Regency'
#  'Paramount Pictures'
#  'Eon Productions'
#  'Miravista Films'
#  'Allied Films'
#  'Tig Productions'
#  'Wildwood Enterprises'
#  'Miramax Films'
#  'Touchstone Pictures'
#  'Walt Disney Pictures'
#  'Gramercy Pictures'
#  'Sony Pictures Classics'
#  'Centre National de la Cinématographie'
#  'Twentieth Century Fox Film Corporation'
#  'TriStar Pictures'
#  'Saban Entertainment'
#  'Live Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'Dimension Films'
#  'New Line Cinema'
#  'New Line Cinema'
#  'J&M Entertainment'
#  'Trimark Pictures'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Atlas Entertainment'
#  'Arts Council of England'
#  'Jet Tone Production'
#  'Miramax Films'
#  'Columbia Pictures Corporation'
#  'Hollywood Pictures'
#  'Zero Film GmbH'
#  'Columbia Pictures Corporation'
#  'Miramax Films'
#  'New Amsterdam Entertainment'
#  'Universal Pictures'
#  'Dimension Films'
#  'New Line Cinema'
#  'Punch Productions'
#  'Channel Four Films'
#  'Bandeira Entertainment'
#  'Castle Rock Entertainment'
#  'Gracie Films'
#  'The Rank Organisation'
#  'Paramount Pictures'
#  'Kopelson Entertainment'
#  'Wildgaze Films'
#  'Arts Council of England'
#  'Alameda Films'
#  'TriStar Pictures'
#  'MacGillivray Freeman Films'
#  'TriStar Pictures'
#  'Live Entertainment'
#  'United Artists Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Mandalay Entertainment'
#  'DreamWorks SKG'
#  'Fox 2000 Pictures'
#  'Bandai Visual Company'
#  'Universal Pictures'
#  'Shooting Gallery'
#  'Miramax Films'
#  'Miramax Films'
#  'Front Street Pictures'
#  'Fox Searchlight Pictures'
#  'Wildwood Enterprises'
#  'PolyGram Filmed Entertainment'
#  'Twentieth Century Fox Film Corporation'
#  'Walt Disney Pictures'
#  'New Line Cinema'
#  'PolyGram Filmed Entertainment'
#  'British Broadcasting Corporation (BBC)'
#  'Canal Plus'
#  'New Line Cinema'
#  'Duo Art Productions'
#  'Imagine Entertainment'
#  'Jean Doumanian Productions'
#  'Atlas Entertainment'
#  'Castle Rock Entertainment'
#  'Paramount Pictures'
#  'Columbia Pictures'
#  '40 Acres & A Mule Filmworks'
#  'Island Pictures'
#  'TriStar Pictures'
#  'El Deseo'
#  'Castle Rock Entertainment'
#  'SE8 Group'
#  'Working Title Films'
#  'Constantin Film Produktion'
#  'Here Studios'
#  'Hollywood Pictures'
#  'Universal Pictures'
#  'Touchstone Pictures'
#  'Strength Ltd.'
#  'Lakeshore Entertainment'
#  'Golden Harvest Company'
#  'Abbas Kiarostami Productions'
#  'First Floor Features'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Warner Bros.'
#  'Castle Rock Entertainment'
#  'Cabin Creek Films'
#  'TriStar Pictures'
#  'Village Roadshow Pictures'
#  'Universal Pictures'
#  'HSX Films'
#  'Centre National de la Cinématographie (CNC)'
#  'PolyGram Filmed Entertainment'
#  'Columbia Pictures'
#  'Paramount Pictures'
#  'New Line Cinema'
#  'The Rank Organisation'
#  'Warner Bros.'
#  'TriStar Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Universal Pictures'
#  'Dimension Films'
#  'DiNovi Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Norsk Film'
#  'New Zealand Film Commission'
#  'Kopelson Entertainment'
#  'Roxy Film'
#  'Caravan Pictures'
#  'Columbia Pictures'
#  'October Films'
#  'Channel Four Films'
#  'Fine Line Features'
#  'The Institute for the Intellectual Development of Children & Young Adults'
#  'Tritone Productions'
#  'Shooting Gallery'
#  'Joel Castleberg Productions'
#  'Walt Disney Pictures'
#  'Revolution Films'
#  'Twentieth Century Fox Film Corporation'
#  'Shooting Gallery'
#  'Twentieth Century Fox Film Corporation'
#  'Universal Pictures'
#  'The Australian Film Commission'
#  'Miramax Films'
#  'Jerry Bruckheimer Films'
#  'Silver Pictures'
#  'TriStar Pictures'
#  'Universal Pictures'
#  'Truth and Soul Pictures Inc'
#  'Circle Films'
#  'Twentieth Century Fox Film Corporation'
#  'Reynolds Pictures'
#  'Paramount Famous Lasky Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Universal Pictures'
#  'RKO Radio Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Fox Film Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Warner Bros.'
#  'Columbia Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Paramount Pictures'
#  'Paramount'
#  'Samuel Goldwyn Company
#  'Twentieth Century Fox Film Corporation'
#  'Two Cities Films'
#  'Columbia Pictures Corporation'
#  'Paramount Pictures'
#  'Columbia Pictures Corporation'
#  'Columbia Pictures'
#  'United Artists'
#  'United Artists'
#  'Woodfall Film Productions'
#  'Columbia Pictures Corporation'
#  'United Artists'
#  'Columbia Pictures Corporation'
#  'United Artists'
#  'Twentieth Century Fox Film Corporation'
#  'United Artists'
#  'Columbia Pictures'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Columbia Pictures'
#  'United Artists'
#  'The Zanuck Company'
#  'Palomar Pictures'
#  'Gus Productions'
#  'Edge City'
#  'Allagash Films'
#  'Lucasfilm'
#  'Universal Pictures'
#  'New Line Cinema'
#  'New Line Cinema'
#  'New Line Cinema'
#  'New Line Cinema'
#  'New Line Cinema'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Compass International Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Dimension Films'
#  'Trans Pacific Films'
#  'Guardian Trust Company'
#  'Simcom Limited'
#  'Norstar Entertainment'
#  'Norstar Entertainment'
#  'United Artists'
#  'Universal Pictures'
#  'Universal Pictures'
#  'SLM Production Group'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Morgan Creek Productions'
#  'Silver Pictures'
#  'Silver Pictures'
#  'Silver Pictures'
#  'Amblin Entertainment'
#  'Amblin Entertainment'
#  'Amblin Entertainment'
#  'Amblin Entertainment'
#  'Fox Searchlight Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Toho Company'
#  'Lorimar Film Entertainment'
#  'Dino De Laurentiis Company'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Fine Line Features'
#  'Pathé'
#  'Village Roadshow Pictures'
#  'Tapestry Films'
#  'Paramount Pictures'
#  'Revolutionary Eye LLC'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney'
#  'Amblin Entertainment'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney Pictures'
#  'Buena Vista'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Regency Enterprises'
#  'Walt Disney Pictures'
#  'Universal Pictures'
#  'Arts Council of England'
#  'Warner Bros.'
#  'Orion Pictures'
#  'RKO Radio Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Sveriges Television (SVT)'
#  'FilmDallas Pictures'
#  'Antron Media Production'
#  'HBO Films'
#  'Imagine Entertainment'
#  'Amblin Entertainment'
#  'Ital-Noleggio Cinematografico'
#  'Mafilm'
#  'De Laurentiis Entertainment Group (DEG)'
#  'Buena Vista Distribution Company'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney'
#  'Walt Disney Pictures'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'RKO Radio Pictures'
#  'Paramount Pictures'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Television Animation'
#  'Silver Screen Partners II'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Walt Disney'
#  'Walt Disney Pictures'
#  'Touchstone Pictures'
#  'Walt Disney Pictures'
#  'Walt Disney Pictures'
#  'Walt Disney Pictures'
#  'Walt Disney Productions'
#  'Walt Disney Pictures'
#  'Hollywood Pictures'
#  'Dimension Films'
#  'TriStar Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Warner Bros.'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'American Zoetrope'
#  'Lucasfilm'
#  'United Artists'
#  'Umbrella-Rosenblum Film Production'
#  'Paramount Pictures'
#  'De Laurentiis Entertainment Group (DEG)'
#  'New Line Cinema'
#  'TAFT Entertainment Pictures'
#  'Hal Roach Studios'
#  'United Artists'
#  'Paramount Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Forensic Films'
#  'October Films'
#  'Paramount Pictures'
#  'Personafilm'
#  'Chenault Productions'
#  'Silver Screen Partners III'
#  'Universal Studios'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'AVCO Embassy Pictures'
#  'United Artists'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Universal Studios'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Columbia Pictures'
#  'The Guber-Peters Company'
#  'New World Pictures'
#  'New World Pictures'
#  'CAT Films'
#  'Weintraub Entertainment Group'
#  'Dimension Films'
#  'Jerry Weintraub Productions'
#  'Twentieth Century Fox Film Corporation'
#  'Fox Searchlight Pictures'
#  'Maljack Productions'
#  'Paramount Pictures'
#  'Producers Sales Organization'
#  'Bavaria Film'
#  'Four Square Productions'
#  'Propaganda Films'
#  'Propaganda Films'
#  'New Line Cinema'
#  'Columbia Pictures'
#  'Paramount Pictures'
#  'Pathé Films'
#  'New Zealand Film Commission'
#  'Geffen Company
#  'Rainbow Film Company
#  'Transatlantic Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Warner Bros.'
#  'Paramount Pictures'
#  'Paramount Pictures'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Redeemable Features'
#  'Bill Plympton Studios'
#  'Rhino Films'
#  'BBC Films'
#  'Fidélité Productions'
#  'Lucasfilm'
#  'Paramount Pictures'
#  'Robert Simonds Productions'
#  'TriStar Pictures'
#  'Hollywood Pictures'
#  'Transatlantic Pictures'
#  'The Selznik Studio'
#  'Twentieth Century Fox Film Corporation'
#  'Universal Pictures'
#  'Universal Pictures'
#  'RKO Radio Pictures'
#  'RKO Radio Pictures'
#  'Mayflower Pictures Corporation'
#  'Gainsborough Pictures'
#  'Gaumont British Picture Corporation'
#  'Gaumont British Picture Corporation'
#  'Gaumont British Picture Corporation'
#  'Gaumont British Picture Corporation'
#  'Gaumont British Picture Corporation'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'British International Pictures (BIP)'
#  'Gainsborough Pictures'
#  'Gainsborough Pictures'
#  'British International Pictures (BIP)'
#  'Carlyle Blackwell Productions'
#  'Gainsborough Pictures'
#  'Miramax Films'
#  'Téléfilm Canada'
#  'Davis Entertainment Classics'
#  'Filmax'
#  'Caravan Pictures'
#  'Cruise/Wagner Productions'
#  'Medusa Distribuzione'
#  'Medusa Produzione'
#  'Twentieth Century Fox Film Corporation'
#  'Orion Pictures'
#  'CBS Entertainment Productions'
#  'Gracie Films'
#  'Twentieth Century Fox Film Corporation'
#  'Orion Pictures'
#  'Gracie Films'
#  'Warner Bros.'
#  'Geffen Company
#  'Columbia Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Delphi II Productions'
#  'Sherwood'
#  'Gladden Entertainment'
#  'A&M Films'
#  'TriStar Pictures'
#  'TriStar Pictures'
#  'Paramount Pictures'
#  'Warner Bros.'
#  'Paramount Pictures'
#  'Columbia Pictures'
#  'David Brown Productions'
#  'Paramount Pictures'
#  'JD Productions'
#  'Universal Pictures'
#  'New Line Cinema'
#  'Movieco Australia'
#  'HSX Films'
#  'Capitol Films'
#  'Sideshow Pictures'
#  'United Artists'
#  'Original Film'
#  'Intermedia Films'
#  'Clinica Estetico'
#  'Polar Entertainment'
#  'Warner Bros.'
#  'Channel Four Films'
#  'Paramount Pictures'
#  'Playboy Enterprises'
#  'Warner Bros.'
#  'Universal Pictures'
#  'Fine Line Features'
#  'United Artists'
#  'Twentieth Century Fox Film Corporation'
#  'New Line Cinema'
#  'Nu Image Films'
#  'DreamWorks SKG'
#  'Fox Searchlight Pictures'
#  'Paramount Pictures'
#  'PolyGram Filmed Entertainment'
#  'Shooting Gallery'
#  'Prometheus Film Productions Ltd'
#  'Embassy Pictures Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Twentieth Century Fox Film Corporation'
#  'Paramount Pictures'
#  'Caravan Pictures'
#  'Patriot Pictures'
#  'Holly Hill Productions'
#  'Bayerischer Rundfunk'
#  'Miramax Films'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Paramount Pictures'
#  'Brooksfilms'
#  'Harpo Films'
#  'Universal Pictures'
#  'Village Roadshow Pictures'
#  'Killer Films'
#  'Gramercy Pictures'
#  'TriStar Pictures'
#  'New Line Cinema'
#  'Impact Pictures'
#  'Charter Films Inc.'
#  'Miramax Films'
#  'Kuzui Enterprises'
#  'Paramount Pictures'
#  'Columbia Pictures'
#  'New Line Cinema'
#  'New Line Cinema'
#  'Artisan Entertainment'
#  'Lions Gate Films'
#  'Twentieth Century Fox Film Corporation'
#  'Touchstone Pictures'
#  'Channel Four Films'
#  'Channel Four Films'
#  'Columbia Pictures'
#  'Walt Disney Pictures'
#  'Universal Pictures'
#  'Sony Pictures Classics'
#  'Terminal City Pictures'
#  'Cannon Group'
#  'Palomar Pictures'
#  'United Artists'
#  'Zenith Entertainment'
#  'The Criterion Collection'
#  'New Line Cinema'
#  'Dino de Laurentiis Cinematografica'
#  'Columbia Pictures'
#  'Jerry Bruckheimer Films'
#  'Paramount Pictures'
#  'Walt Disney Pictures'
#  'Sweetland Films'
#  'MACT Productions'
#  'Initial Entertainment Group (IEG)'
#  'Fox Searchlight Pictures'
#  'Nordic Film'
#  'Dreamland Productions'
#  'Screen Classics (II)'
#  'Toho Film (Eiga) Co. Ltd.'
#  'New World Pictures'
#  'Toho Company'
#  'RKO Radio Pictures'
#  'Paramount Pictures'
#  'De Laurentiis Entertainment Group (DEG)'
#  'Orion Pictures'
#  'Embassy Pictures Corporation'
#  'Universal Pictures'
#  'Universal Pictures'
#  'Famous Films (II)'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Eon Productions'
#  'TriStar Pictures'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Warner Bros.'
#  'Kennedy Miller Productions'
#  'Warner Bros.'
#  'Artisan Entertainment'
#  'Initial Entertainment Group (IEG)'
#  'Imagine Entertainment'
#  'Miramax Films'
#  'Paramount Pictures'
#  'Warner Bros.'
#  'Paramount Pictures'
#  'DreamWorks SKG'
#  'Touchstone Pictures'
#  'Miramax Films'
#  'Twentieth Century Fox Film Corporation'
#  'TriStar Pictures'
#  'Orion Pictures'
#  'Warner Bros.'
#  'TriStar Pictures'
#  'Orion Pictures'
#  'TriStar Pictures'
#  'Twentieth Century Fox Film Corporation'
# ...
#  'NALA Films'
#  'A&E IndieFilms'
#  'Trimark Pictures'
#  'Sundial Pictures'
#  'Westerly Films'
#  'Shaw Brothers'
#  'First Artists'
#  'BBC Films'
#  'Warner Bros.'
#  'Production I.G.'
#  'Production I.G.'
#  'HBO Documentary Films'
#  'Toho Company'
#  'Sony Pictures'
#  'Legendary Pictures'
#  'WWE Studios'
#  'UTV Motion Pictures'
#  'Appian Way'
#  'Hammer Films'
#  'New World Television'
#  'Wild Bunch'
#  'Blind Spot Pictures Oy'
#  "Panda Societa per L'Industria Cinematografica"
#  'Blue Dot Productions'
#  'Moxie Firecracker Films'
#  'Universal Pictures'
#  'Celluloid Dreams'
#  'Lionsgate'
#  'StudioCanal'
#  'Jerkschool Productions'
#  'Edison Manufacturing Company'
#  'National Film Organization'
#  'Angoa-Agicoa'
#  'Columbia Pictures Corporation'
#  'Southern Cross Feature Film Company'
#  'Kaplan Film'
#  'Da Huang Pictures'
#  'Philip A. Waxman Productions Inc.'
#  'Illuminati Films Pvt Ltd'
#  'Romania Film'
#  'United King Films'
#  'Item 7'
#  'Stardust Pictures'
#  'Bigfoot Entertainment'
#  'Elle Driver'
#  'Elle Driver'
#  'Wessler Entertainment'
#  'Relativity Media'
#  'Walt Disney Pictures'
#  'North by Northwest Entertainment'
#  'Relativity Media'
#  'Universal Pictures'
#  'CinéCinéma'
#  'BBC'
#  'Daiei Studios'
#  'cattleya'
#  'Amicus Productions'
#  'Centre National de la Cinématographie'
#  'Participant Media'
#  'Twentieth Century Fox Film Corporation'
#  'Life Sentence Films'
#  'MACT Productions'
#  'Gaumont'
#  'Princessa Productions'
#  'Waterland'
#  'Renn Productions'
#  'CiBy 2000'
#  'Columbia Pictures Corporation'
#  'Seoul Films'
#  'Kirghizfilm'
#  'Arte France Cinéma'
#  'Synthetic Fur Productions'
#  'Crown Film Unit'
#  'Les Films de la Pléiade'
#  'Dong Woo Animation'
#  'Cinergi Pictures Entertainment'
#  'Zespol Filmowy'
#  'RKO Radio Pictures'
#  "Children's Television Workshop"
#  'Gorham Productions'
#  'Deputy Corporation'
#  'Universal Pictures'
#  'Shadow Theatre Films'
#  'Filmové Studio Barrandov'
#  'Infinity Prague'
#  'Continental Films'
#  'Lost Toys'
#  'Paramount Vantage'
#  'Universal Pictures'
#  'Paramount Pictures'
#  'Universal International Pictures (UI)'
#  'New Zealand Film Commission'
#  'Rainforest Films'
#  'Village Roadshow Pictures'
#  'Pope Productions'
#  'Allied Artists Pictures'
#  'Batjac Productions'
#  'Veterans'
#  'Samsa Film'
#  'Spera Productions Inc.'
#  'Perfect Weekend'
#  'Lawrence Bender Productions'
#  'Central Motion Pictures Corporation'
#  'NHK Enterprises'
#  'MK2 Productions'
#  'Cinema Artists'
#  'RKO Radio Pictures'
#  'Elkcreek Cinema'
#  'Edison Manufacturing Company'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Film Par Film'
#  'TriStar Pictures'
#  'Chunichi Eigasha'
#  'Neo Art & Logic'
#  'Screen Australia'
#  'Jonai Productions'
#  'Village Roadshow Pictures'
#  'Universal Pictures'
#  'WG Film'
#  'Sandrew Metronome Distribution'
#  'Perfect Weekend'
#  'Blue Star Pictures'
#  'Scottish Screen'
#  'Process Film'
#  'Formosa Productions'
#  'Portobello Pictures'
#  'Canal Sur Televisión'
#  'IFC Films'
#  'Chromewood Productions'
#  'Bananeira Filmes'
#  'The Bubble Factory'
#  'Edison Manufacturing Company'
#  'BBC'
#  'Yash Raj Films'
#  'Eros International'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'El Pampero Cine'
#  'Antena 3 Films'
#  'Paramount Pictures'
#  'Merchant Ivory Productions'
#  'Coyote Productions'
#  'BBC'
#  'American Mutoscope & Biograph'
#  'Wild Bunch'
#  'Twentieth Century Fox Film Corporation'
#  'The Hatchery'
#  'Titanus'
#  'Les Films Raoul Ploquin'
#  'Suomi-Filmi'
#  'Producciones Filmamento'
#  'The American Film Theatre'
#  'Amblin Entertainment'
#  'Universal Pictures'
#  'Filminor'
#  'Universal Pictures'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Skyscraper Films'
#  'Thor Productions'
#  'Seven Arts Pictures'
#  'Christiano Film Group'
#  'UTV Motion Pictures'
#  'Wild Bunch'
#  'Alcon Entertainment'
#  'Celluloid Dreams'
#  'Brownstone Productions'
#  'Columbia Pictures'
#  'Les Films du Lendemain'
#  'Home Box Office (HBO)'
#  'Ibermedia'
#  'Stone River Productions'
#  'Twentieth Century Fox Film Corporation'
#  'Preferred Content'
#  'Mercy Creek Entretainment'
#  'Castle Rock Entertainment'
#  'Eros International'
#  'Twentieth Century Fox Film Corporation'
#  '40 Acres & A Mule Filmworks'
#  'Twentieth Century Fox Film Corporation'
#  '26 Films'
#  "Joe's Daughter"
#  'Film i Väst'
#  'Lois Weber Productions'
#  'Torchlight Productions'
#  'Edison Manufacturing Company'
#  'Relativity Media'
#  'Columbia Pictures Corporation'
#  'Warner Bros.'
#  'Scott Rudin Productions'
#  'Forward Pass'
#  'DC Comics'
#  'Chugoku Broadcasting (RCC)'
#  'Les Films Ariane'
#  'Hammer Film Productions'
#  'Icon Productions'
#  'Steamroller Productions'
#  'Midnight Sun Pictures'
#  'Senator Film Produktion'
#  'DC Comics'
#  'Les Ballets Suedois'
#  'Rhône-Alpes Cinéma'
#  'Boyana Film'
#  'Ital-Noleggio Cinematografico'
#  'Culver Entertainment'
#  'Paramount Pictures'
#  'Solar Films inc.'
#  'Parabolic Pictures'
#  'Les films du Worso'
#  'MGM Television'
#  'France 2 Cinéma'
#  'Berkshire Axis Media'
#  'Paramount Pictures'
#  'Disneynature'
#  'Steve White Entertainment'
#  'Duplass Brothers Productions'
#  'DreamWorks Animation'
#  'ANOC Productions'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Paramount Pictures'
#  'Quickfire Films'
#  'Ada Films'
#  'Kazakhfilm Studios'
#  'Greek Television ET-1'
#  'Toei Animation'
#  'Toei Animation'
#  'DC Comics'
#  'Film Roman Productions'
#  'Vaca Films'
#  'Progefi'
#  'Pluck Productions'
#  'Toei Animation'
#  'Toei Animation'
#  'Walt Disney Pictures'
#  'Walt Disney Television Animation'
#  'Hallmark Entertainment'
#  'Toei Animation'
#  'Walt Disney Pictures'
#  'Rai Cinema'
#  'Alcon Entertainment'
#  'Gravier Productions'
#  'AVCO Embassy Pictures'
#  'Twentieth Century Fox Film Corporation'
#  'Thalia Productions'
#  'First Position Films'
#  'Unstoppable Entertainment'
#  'Paramount Pictures'
#  'Detention Films'
#  'Warner Bros.'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Dos Corazones'
#  'CJ Entertainment'
#  'Medusa Film'
#  'Lenfilm'
#  'New Line Cinema'
#  'Mandate Pictures'
#  'Pixar Animation Studios'
#  'Walt Disney Pictures'
#  'London Weekend Television (LWT)'
#  'Walt Disney Pictures'
#  'Pixar Animation Studios'
#  'American Cinema Releasing'
#  'Universal Pictures'
#  'Pixar Animation Studios'
#  'Extension 765'
#  'Toei Animation'
#  'Toei Animation'
#  'Artistes Alliance Ltd.'
#  'BTA Films & Video'
#  'Korean Film'
#  'Centerpoint'
#  'American Zoetrope'
#  'North by Northwest Entertainment'
#  'Toei Animation'
#  'Toei Animation'
#  'Antena 3 Films'
#  'UK Film Studio'
#  'Columbia Pictures'
#  'Toei Animation'
#  'Vaughan Films'
#  'Xanadeux Company'
#  'Zentropa Entertainments'
#  'Nikkatsu'
#  'Bioskop-Film GmbH'
#  'Constantin Film'
#  'Edison Manufacturing Company'
#  'Blue Sky Studios'
#  'Journeyman Pictures'
#  'Incorporated Television Company (ITC)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Michael Cacoyannis Productions'
#  'DreamWorks SKG'
#  'Nikkatsu'
#  'Nikkatsu'
#  'Shochiku'
#  'Atossa Film Produktion GmbH'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Ixtlan'
#  'Universal Studios'
#  'Mirror Maze'
#  'Zentropa'
#  'Hallmark Hall of Fame Productions'
#  'StellaNova Film'
#  'PBS'
#  'Florentine Films'
#  'Les Films Christian Fechner'
#  'Vertigo Films'
#  'Pixar Animation Studios'
#  'Capital Productions'
#  'Monogram Pictures'
#  'Pixar Animation Studios'
#  'Tyler Perry Company
#  'Universal Pictures'
#  'Art Port'
#  'Kindle Entertainment'
#  'Ingenious Film Partners'
#  'Left Field Ventures'
#  'Rai Cinema'
#  'Senator Film Produktion'
#  'Asylum
#  'Dong-a Exports Co. Ltd.'
#  'TLA Releasing'
#  'Voltage pictures'
#  'National Geographic'
#  'Toei Animation'
#  'Kadokawa Pictures'
#  'Unified Pictures'
#  'Toei Animation'
#  'Toei Animation'
#  'Teuvo Tulio'
#  'Castel Film Romania'
#  '20ten Media'
#  'Depth of Field'
#  'London Film Productions'
#  'London Film Productions'
#  'Jetlag Productions'
#  'Cyprus Films'
#  'Turner Network Television (TNT)'
#  'Dynamo'
#  'Pixar Animation Studios'
#  'Pixar Animation Studios'
#  'Fox Searchlight Pictures'
#  'Columbia Pictures'
#  'Copperheart Entertainment'
#  'PeaceOut Productions'
#  'Pandora Filmproduktion'
#  'New Horizons'
#  'WGBH'
#  'Toho Company'
#  'Wild Bunch'
#  'My Own Worst Enemy'
#  'Medusa Film'
#  'Toei Animation'
#  'Toei Animation'
#  'Pure Flix Entertainment'
#  'Castel Film Romania'
#  'Avalanche Productions'
#  'Canal Plus'
#  'Film Victoria'
#  'Insight Film Studios'
#  'Senator Film Produktion'
#  'Toei Animation'
#  'Toei Animation'
#  'Edison Manufacturing Company'
#  'Pandora Filmproduktion'
#  'RKO Radio Pictures'
#  'After Dark Films'
#  'Motion Picture Corporation of America'
#  'Decoys Production'
#  '2 Smooth Film Productions'
#  'Telecinco Cinema'
#  'Walt Disney Productions'
#  'Palladium Productions'
#  'Clinica Estetico'
#  'Studio Film Corp.'
#  'Dark Castle Entertainment'
#  '120dB Films'
#  'DisneyToon Studios'
#  'Columbia Pictures'
#  'Galatea Film'
#  'Merchant Ivory Productions'
#  'Gaumont'
#  'MNP Entreprise'
#  'Nu Image Films'
#  'Everyman Pictures'
#  'Lightning Entertainment'
#  'Columbia Pictures'
#  'Daiei Studios'
#  'Norris Brothers Entertainment'
#  'Nu Image Films'
#  'RKO Radio Pictures'
#  'Centre National de la Cinématographie'
#  'Columbia Pictures Corporation'
#  'Solar Films inc.'
#  'Showbox'
#  'Momentum Films'
#  'Nikkatsu'
#  'Greek Film Center'
#  'Toho Company'
#  'Nikkatsu'
#  'ArieScope Pictures'
#  'Soon Lee Films'
#  'Great Earth Film Company'
#  'Toei Video Company'
#  'Film International Rotterdam'
#  'Art Theatre Guild'
#  'Why Not Productions'
#  'Hunting Lane Films'
#  'Nikkatsu'
#  'Merchant Ivory Productions'
#  'Great Earth Film Company'
#  'Focus Features'
#  'Fox 2000 Pictures'
#  'Cinema Artists'
#  'Universum Film (UFA)'
#  'Video Flims'
#  'Lotte Entertainment'
#  'Rezo Films'
#  'Team Todd'
#  'Les Films du Losange'
#  'Primate Pictures'
#  'Lookout Films'
#  'BBC Films'
#  'Entertainment One'
#  'Paradise Films'
#  'Walt Disney Television Animation'
#  'Shapiro-Glickenhaus Entertainment'
#  'Comedy Central'
#  'Art Theatre Guild'
#  'Pariah Entertainment Group'
#  'Mosfilm'
#  'Universal Pictures'
#  'Bavaria Film'
#  'Walt Disney Pictures'
#  'The Weinstein Company'
#  'Mega Film'
#  'Dimension Films'
#  'Avala Film'
#  'Buffalo Gal Pictures'
#  'TAT Communications Company'
#  'Sleepwalkers Anonymous'
#  'Granada Television'
#  'WGBH'
#  'Films 59'
#  'Passion Pictures'
#  'Ghost House Pictures'
#  'Motion Picture Corporation of America (MPCA)'
#  'Moonlighting Films'
#  'M6 Films'
#  'StudioCanal'
#  'Cannon and Morley Productions'
#  'Solar Films inc.'
#  'British Broadcasting Corporation (BBC)'
#  'WGBH'
#  'Last Picture Pro'
#  'APT Films'
#  'Filmax Entertainment'
#  'Universal Pictures'
#  "Institut National de l'Audiovisuel (INA)"
#  'Gary Sanchez Productions'
#  'CBS Films'
#  'Minerva Film SpA'
#  'Solar Productions'
#  'Norddeutscher Rundfunk (NDR)'
#  'Federiz'
#  'Films du Rond-Point'
#  'Brownstone Productions'
#  'Summit Entertainment'
#  'Next Wednesday Productions'
#  'Toho Company'
#  'Lionsgate'
#  'Larry Levinson Productions'
#  'Magidson Films'
#  'Walt Disney Pictures'
#  'Endgame Entertainment'
#  'Muskat Filmed Properties'
#  'Centerstage Productions'
#  'Columbia Pictures'
#  'Sofica Europacorp'
#  'Palo Alto Productions'
#  'Aries Film International'
#  'Magnet Releasing'
#  'Titanus'
#  'Toho Company'
#  'Films 59'
#  'Samuel Goldwyn Films'
#  'Mouka Filmi Oy'
#  'Les Films des Tournelles'
#  'Film Tiger'
#  'RAI Radiotelevisione Italiana'
#  'Red Om Films'
#  'Blueshift Entertainment'
#  'Davis-Films'
#  'Malpaso Productions'
#  'RKO Radio Pictures'
#  'BBC Films'
#  'sabotage film GmbH'
#  'Universal Film Manufacturing Company'
#  'First National Pictures'
#  'Cinéas'
#  'Kunsthochschule Kassel'
#  'Radical Media'
#  'Fox Searchlight Pictures'
#  'Ghoulardi Film Company'
#  'Columbia Broadcasting System (CBS)'
#  'DNA Films'
#  'Samuel Goldwyn Company
#  'Sarke Studio'
#  'Lionsgate'
#  'Ruckus Films'
#  'RKO Radio Pictures'
#  'Loki Films'
#  'Kazakhfilm Studios'
#  'Filmové Studio Barrandov'
#  'Zweites Deutsches Fernsehen (ZDF)'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Dry County Films'
#  'Prescience'
#  'Propaganda Films'
#  'Anchor Bay'
#  'Ambrosia Pictures'
#  'Emmett/Furla Films'
#  'Paramount Pictures'
#  'The Collective'
#  'TLA Releasing'
#  'Summit Entertainment'
#  'Zentropa Entertainments'
#  'Pandora Filmproduktion'
#  'Break Thru Films'
#  'Mistress Inc.'
#  'Telecine'
#  'TriStar Pictures'
#  'ATO Pictures'
#  'First Generation Films'
#  'Twentieth Century Fox Film Corporation'
#  'Lee Daniels Entertainment'
#  'London Film Productions'
#  'Les Films Modernes'
#  'Dentsu Inc.'
#  'Turner Entertainment'
#  'RAI Radiotelevisione Italiana'
#  'Kumie'
#  'Zentropa Entertainments'
#  'A Bigger Boat'
#  'Epix'
#  'Stefano Film'
#  'The Asylum'
#  'The Filmakers'
#  'Bavaria Film'
#  'Gaumont'
#  'The Film'
#  'Nord-Ouest Productions'
#  'Dudley Pictures Corporation'
#  'Fox Film Corporation'
#  'SND'
#  'MK2 Productions'
#  'Castle Rock Entertainment'
#  'Metro-Goldwyn-Mayer (MGM)'
#  'Double Feature Films'
#  "Maítrise Artisanale de l'Industrie Cinematographique (MAIC)"
#  'Filmové Studio Barrandov'
#  'Goalpost Pictures'
#  'Universal TV'
#  'Vivendi Entertainment'
#  'Filmové Studio Barrandov'
#  'France 2 Cinéma'
#  'Fox Film Corporation'
#  'Shôchiku Eiga'
#  'Shôchiku Eiga'
#  'Shochiku'
#  'Gainsborough Pictures'
#  'The Rank Organisation'
#  'Morbido Films'
#  'Efish Entertainment'
#  'Film i Väst'
#  'Paramount Pictures'
#  'Universal Pictures'
#  'Mosfilm'
#  'London Film Productions'
#  'Merchant Ivory Productions'
#  'Nikkatsu'
#  'Peter Jones Productions'
#  'Sveriges Television (SVT)'
#  'Columbia Pictures Corporation'
#  'Warner Bros.'
#  'Carmel Productions'
#  'Top Hat Productions'
#  'Angoa-Agicoa'
#  'Maipo'
#  'Shangri-La Entertainment'
#  'Tim Burton Productions'
#  'Paramount Pictures'
#  'AMLF'
#  'Alliance Films'
#  'Universal Studios Home Video'
#  'Access Pictures'
#  'The Rank Organisation'
#  'Annapurna Productions'
#  'Killer Films'
#  'Columbia Pictures'
#  'Di San Luca Films'
#  'Endgame Entertainment'
#  'Columbia TriStar Home Entertainment'
#  'StudioCanal'
#  'British Lion Films'
#  'Twentieth Century Fox Film Corporation'
#  'Fox Film Corporation'
#  'Universal Pictures'
#  'Merchant Ivory Productions'
#  'A-1 Kino Video'
#  'Roger Corman Productions'
#  'Nikkatsu'
#  'American International Pictures (AIP)'
#  'National Film Board of Canada (NFB)'
#  'GK Films'
#  'Blueprint Pictures'
#  'Michael De Luca Productions'
#  'Cinema Vehicle Services'
#  'BBC Films'
#  'Tom Sawyer Entertainment'
#  'Filmirage'
#  'Ross Hunter Productions Inc.'
#  'Active Entertainment'
#  'Les Films du Lendemain'
#  'Regency Enterprises'
#  'British Broadcasting Corporation (BBC)'
#  'InterPositive Media'
#  'Filmmakers'
#  'Twentieth Century Fox Film Corporation'
#  'HW Two'
#  'Benaroya Pictures'
#  'CBS Entertainment Productions'
#  'Robert Stillman Productions'
#  'RabbitBandini Productions'
#  'Shôchiku Eiga'
#  'Titanus'
#  'Sveriges Radio'
#  'Viacom Productions'
#  'Arte'
#  'Abbott Vision'
#  'France 2 Cinéma'
#  'Nikkatsu'
#  'Duck Farm Films'
#  'Filmax'
#  'Twentieth Century Fox Film Corporation'
#  'Anurag Kashyap Films'
#  'Australian Film Finance Corporation'
#  'Pantelion Films'
#  'France 2 Cinéma'
#  'Warner Bros.'
#  'RKO Radio Pictures'
#  'RKO Radio Pictures'
#  'Lolafilms'
#  'Equinoxe Productions'
#  'Luminant Media'
#  'Dark Castle Entertainment'
#  'StudioCanal'
#  'Paramount Pictures'
#  'Studio Filmowe Kadr'
#  'TriStar Pictures'
#  'Fine & Mellow Productions'
#  'Huayi Brothers'
#  'Titanus'
#  'Blumhouse Productions'
#  'Hollywood Media Bridge'
#  'Kwai River'
#  'First Floor Features'
#  'Summit Entertainment'
#  'Drafthouse Films'
#  'Anarchos Productions'
#  'Inscription Films'
#  'Pyramide Productions'
#  'Home Box Office (HBO)'
#  'Believe Entertainment'
#  'Davis-Films'
#  '360 Pictures'
#  'RKO Radio Pictures'
#  'Warner Bros.'
#  'Filmlance International AB'
#  'Zentropa Entertainments'
#  'United Artists'
#  'Thomas H. Ince Corporation'
#  'Perfect World Pictures'
#  'ARTE France Cinéma'
#  'Fox 2000 Pictures'
#  'Columbia Pictures'
#  'Turner Classic Movies (TCM)'
#  "Hitman's Run Productions"
#  'Screen Australia'
#  'Plan B Entertainment'
#  'A&E IndieFilms'
#  'Rhino Films'
#  'Twentieth Century Fox Film Corporation'
#  'Stanley Kramer Productions'
#  'BBC Films'
#  'Mirisch Films'
#  'Element Pictures'
#  'Showcase Entertaiment Inc.'
#  'Somerset Film Productions'
#  'Super Crispy Entertainment'
#  'Atlantic Pictures'
#  'Forensic Films'
#  'Walt Disney Animation Studios'
#  'Lorimar Productions'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8458ef2fd314> in <module>
#       2 for i,m in movies.iterrows():
#       3     if str(m['production_companies'])!='[]':
# ----> 4         print(m['production_companies'].split(",")[0].split(":")[1])
#       5     else:
#       6         dfdict[i] = None
#
# AttributeError: 'float' object has no attribute 'split'

# %%
os.getcwd()
# Out:
# '/Users/ryanfisher/Documents/Springboard/Springboard/Capstone 2/3405-6663-bundle-archive'

# %%
movies_credits = pd.read_csv('movies_credits', header=0)
movies_credits.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage  movieId    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story      862  tt0114709                en
# 1                                   NaN     8844  tt0113497                en
# 2                                   NaN    15602  tt0113228                en
# 3                                   NaN    31357  tt0114885                en
# 4                                   NaN    11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...     81.0
# 1  When siblings Judy and Peter discover an encha...  ...    104.0
# 2  A family wedding reignites the ancient feud be...  ...    101.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...    127.0
# 4  Just when George Banks has recovered from his ...  ...    106.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average vote_count  \
# 0                    Toy Story  False           7.7     5415.0
# 1                      Jumanji  False           6.9     2413.0
# 2             Grumpier Old Men  False           6.5       92.0
# 3            Waiting to Exhale  False           6.1       34.0
# 4  Father of the Bride Part II  False           5.7      173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
# [5 rows x 26 columns]

# %%
genre_list = []
for i,m in movies_credits.iterrows():
    if str(m['genres'])!='[]':
        genre_list.append(m['genres'].split(",")[1].split(":")[1].split("}")[0].replace("'",""))
    else:
        genre_list.append(None)

# %%
collection_list = []
for i,m in movies_credits.iterrows():
    if str(m['belongs_to_collection'])!='nan':
        collection_list.append(m['belongs_to_collection'].split(",")[1].split(":")[1].replace("'",""))
    else:
        collection_list.append(None)

# %%
production_comp_list = []
for i,m in movies_credits.iterrows():
    if str(m['production_companies'])!='nan':
        #print(m['production_companies'].split(",")[0].split(":")[1].replace("'",""))
        production_comp_list.append(m['production_companies'].split(",")[0].split(":")[1].replace("'",""))
    else:
        #production_comp_list[i] = None
        production_comp_list.append(None)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-41fd8b102cc5> in <module>
#       3     if str(m['production_companies'])!='nan':
#       4         #print(m['production_companies'].split(",")[0].split(":")[1].replace("'",""))
# ----> 5         production_comp_list.append(m['production_companies'].split(",")[0].split(":")[1].replace("'",""))
#       6     else:
#       7         #production_comp_list[i] = None
#
# IndexError: list index out of range

# %%
production_comp_list
# Out:
# ['[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[{name',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[]',
#  '[]',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  '[{name',
#  ...]

# %%
df = pd.DataFrame(credits['cast'])
x = df['cast'].iloc[0]
json.loads(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-acdb881cf8ba> in <module>
# ----> 1 df = pd.DataFrame(credits['cast'])
#       2 x = df['cast'].iloc[0]
#       3 json.loads(x)
#
# TypeError: '_Printer' object is not subscriptable

# %%
ast.literal_eval(x)

# %%
ast.literal_eval(x)[:5]

# %%
movies_credits['new_genres'] = genre_list

# %%
movies_credits['collection'] = collection_list

# %%
del movies_credits['genres']
del movies_credits['homepage']
del movies_credits['overview']
del movies_credits['tagline']
del movies_credits['poster_path']
del movies_credits['original_title']
del movies_credits['belongs_to_collection']
del movies_credits['production_countries']
del movies_credits['video']
del movies_credits['spoken_languages']
del movies_credits['status']

# %%
movies_credits
# Out:
#        adult    budget  movieId    imdb_id original_language  popularity  \
# 0      False  30000000      862  tt0114709                en   21.946943
# 1      False  65000000     8844  tt0113497                en   17.015539
# 2      False         0    15602  tt0113228                en   11.712900
# 3      False  16000000    31357  tt0114885                en    3.859495
# 4      False         0    11862  tt0113041                en    8.387519
# ...      ...       ...      ...        ...               ...         ...
# 45533  False         0   439050  tt6209470                fa    0.072051
# 45534  False         0   111109  tt2028550                tl    0.178241
# 45535  False         0    67758  tt0303758                en    0.903007
# 45536  False         0   227506  tt0008536                en    0.003503
# 45537  False         0   461257  tt6980792                en    0.163015
#
#                                     production_companies release_date  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...   1995-12-15
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   1995-12-22
# 3      [{'name': 'Twentieth Century Fox Film Corporat...   1995-12-22
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...   1995-02-10
# ...                                                  ...          ...
# 45533                                                 []          NaN
# 45534             [{'name': 'Sine Olivia', 'id': 19653}]   2011-11-17
# 45535  [{'name': 'American World Pictures', 'id': 6165}]   2003-08-01
# 45536               [{'name': 'Yermoliev', 'id': 88753}]   1917-10-21
# 45537                                                 []   2017-06-09
#
#            revenue  runtime                        title  vote_average  \
# 0      373554033.0     81.0                    Toy Story           7.7
# 1      262797249.0    104.0                      Jumanji           6.9
# 2              0.0    101.0             Grumpier Old Men           6.5
# 3       81452156.0    127.0            Waiting to Exhale           6.1
# 4       76578911.0    106.0  Father of the Bride Part II           5.7
# ...            ...      ...                          ...           ...
# 45533          0.0     90.0                       Subdue           4.0
# 45534          0.0    360.0          Century of Birthing           9.0
# 45535          0.0     90.0                     Betrayal           3.8
# 45536          0.0     87.0             Satan Triumphant           0.0
# 45537          0.0     75.0                     Queerama           0.0
#
#        vote_count                                               cast  \
# 0          5415.0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1          2413.0  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2            92.0  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3            34.0  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4           173.0  [{'cast_id': 1, 'character': 'George Banks', '...
# ...           ...                                                ...
# 45533         1.0  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45534         3.0  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45535         6.0  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45536         0.0  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45537         0.0                                                 []
#
#                                                     crew  new_genres  \
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...   Animation
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   Adventure
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...     Romance
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...      Comedy
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...      Comedy
# ...                                                  ...         ...
# 45533  [{'credit_id': '5894a97d925141426c00818c', 'de...       Drama
# 45534  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...       Drama
# 45535  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...      Action
# 45536  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...        None
# 45537  [{'credit_id': '593e676c92514105b702e68e', 'de...        None
#
#                             collection
# 0                 Toy Story Collection
# 1                                 None
# 2            Grumpy Old Men Collection
# 3                                 None
# 4       Father of the Bride Collection
# ...                                ...
# 45533                             None
# 45534                             None
# 45535                             None
# 45536                             None
# 45537                             None
#
# [45538 rows x 17 columns]

# %%
director_list = []
for i,m in movies_credits.iterrows():
    #print(i)
    x = ast.literal_eval(m['crew'])
    temp = {}
    for y in x:
        temp[y['job']] = y['name']
    if 'Director' in temp.keys():
        director_list.append(temp['Director'])
    else:
        director_list.append(None)

# %%
director_list
# Out:
# ['John Lasseter',
#  'Joe Johnston',
#  'Howard Deutch',
#  'Forest Whitaker',
#  'Charles Shyer',
#  'Michael Mann',
#  'Sydney Pollack',
#  'Peter Hewitt',
#  'Peter Hyams',
#  'Martin Campbell',
#  'Rob Reiner',
#  'Mel Brooks',
#  'Simon Wells',
#  'Oliver Stone',
#  'Renny Harlin',
#  'Martin Scorsese',
#  'Ang Lee',
#  'Quentin Tarantino',
#  'Steve Oedekerk',
#  'Joseph Ruben',
#  'Barry Sonnenfeld',
#  'Jon Amiel',
#  'Richard Donner',
#  'Victor Salva',
#  'Mike Figgis',
#  'Oliver Parker',
#  'Lesli Linka Glatter',
#  'Roger Michell',
#  'Marc Caro',
#  'Zhang Yimou',
#  'John N. Smith',
#  'Terry Gilliam',
#  'Jean-Jacques Annaud',
#  'Chris Noonan',
#  'Christopher Hampton',
#  'Tim Robbins',
#  'Stephen Low',
#  'Andy Tennant',
#  'Amy Heckerling',
#  'Darrell James Roodt',
#  'Richard Loncraine',
#  'Allen Hughes',
#  'Michael Hoffman',
#  'Paul W.S. Anderson',
#  'Gus Van Sant',
#  'Jocelyn Moorhouse',
#  'David Fincher',
#  'Eric Goldberg',
#  'Patricia Rozema',
#  'Bryan Singer',
#  'Richard W. Munchkin',
#  'Woody Allen',
#  'Gianni Amelio',
#  'Holly Goldberg Sloan',
#  'Ulu Grosbard',
#  'Robert Tinnell',
#  'Jodie Foster',
#  'Michael Radford',
#  'Robert Lepage',
#  'Frank Oz',
#  'John Schlesinger',
#  'Stephen Herek',
#  'Paris Barclay',
#  'Bill Bennett',
#  'Jason Bloom',
#  'Farhad Mann',
#  'James Foley',
#  'Josiane Balasko',
#  'F. Gary Gray',
#  'Robert Rodriguez',
#  'Andrew Sipes',
#  'Noah Baumbach',
#  'Claude Lelouch',
#  'Michael Goldenberg',
#  'Steve Miner',
#  'Christian Duguay',
#  'Susanne Ofteringer',
#  'Sean Penn',
#  'Brian Gibson',
#  'Jafar Panahi',
#  'Gary Fleder',
#  'Marleen Gorris',
#  'Tim Reid',
#  'Henry Jaglom',
#  'Philip Haas',
#  'Ridley Scott',
#  'Ken Kwapis',
#  'Penelope Spheeris',
#  'John Badham',
#  'John Duigan',
#  'Stephen Frears',
#  'Wes Craven',
#  'Ted Demme',
#  'John Woo',
#  'Kenneth Branagh',
#  'Mathieu Kassovitz',
#  'Paul W.S. Anderson',
#  'Nick Broomfield',
#  'Harold Becker',
#  'Wes Anderson',
#  'Nick Castle',
#  'John Dahl',
#  'Dennis Dugan',
#  'Clint Eastwood',
#  'Doris Dörrie',
#  'Brian Henson',
#  'Robert Leacock',
#  'James Bruce',
#  'Mel Gibson',
#  'Martin Scorsese',
#  'Stanley Tong',
#  'Barbet Schroeder',
#  'Mort Ransen',
#  'Étienne Chatiliez',
#  'Jon Blair',
#  'Benjamin Ross',
#  'Eric Schaeffer',
#  'Andrew Davis',
#  'Charles T. Kanganis',
#  'John N. Smith',
#  'Reginald Hudlin',
#  'Wong Kar-wai',
#  'Giuseppe Tornatore',
#  'David O. Russell',
#  'Peter MacDonald',
#  'Moufida Tlatli',
#  'Michel Negroponte',
#  'Bryan Gordon',
#  'Rebecca Miller',
#  'Michael Lindsay-Hogg',
#  'William Friedkin',
#  'Ángel Muñiz',
#  'Craig Baldwin',
#  'David S. Ward',
#  'Mark Rappaport',
#  'Dirk Shafer',
#  'Terence Davies',
#  'Sandip Ray',
#  'Jon Avnet',
#  'Mike Nichols',
#  'Jakov Sedlar',
#  'Edward Burns',
#  'Michael Bay',
#  'Christopher Cain',
#  'Scott Kalvert',
#  'Mike Newell',
#  'Hal Hartley',
#  'Ron Howard',
#  'Michael Caton-Jones',
#  'Abel Ferrara',
#  'Joel Schumacher',
#  'Luis Buñuel',
#  'John Boorman',
#  'Wayne Wang',
#  'Michael Moore',
#  'Brad Silberling',
#  'Spike Lee',
#  'Frank Marshall',
#  'Tony Scott',
#  'Terry Zwigoff',
#  'Robert Rodriguez',
#  'Carl Franklin',
#  'John McTiernan',
#  'Gregg Araki',
#  'Christopher Menaul',
#  'Jerry Zucker',
#  'Dwight H. Little',
#  'Iain Softley',
#  'Christopher Ashley',
#  'Robert Longo',
#  'Danny Cannon',
#  'John Fortenberry',
#  'Larry Clark',
#  'Tom DiCillo',
#  'Clive Barker',
#  'Denys Arcand',
#  'Antonia Bird',
#  'Kevin Smith',
#  'Bryan Spicer',
#  'David Anspaugh',
#  'Anthony Waller',
#  'Michael Almereyda',
#  'Irwin Winkler',
#  'Chris Columbus',
#  'Daisy von Scherler Mayer',
#  'Gregory Widen',
#  'Norman René',
#  'Todd Haynes',
#  'Roland Joffé',
#  None,
#  'Paul Verhoeven',
#  'Paul Auster',
#  'Lasse Hallström',
#  'Roger Donaldson',
#  'James Keach',
#  'Kathryn Bigelow',
#  'Jacques Demy',
#  'Wesley Strick',
#  'Martha Coolidge',
#  'Agnieszka Holland',
#  'Beeban Kidron',
#  'Geoff Murphy',
#  'Diane Keaton',
#  'Douglas Keeve',
#  'Alfonso Aráu',
#  'Kevin Reynolds',
#  'Desmond Nakano',
#  'Walter Hill',
#  'Mike Figgis',
#  'Greg Beeman',
#  'Nikita Mikhalkov',
#  'Milčo Mančevski',
#  'Richard Linklater',
#  'Tamra Davis',
#  'Guy Ferland',
#  'Herbert Ross',
#  'Peter Horton',
#  'Stuart Gordon',
#  "Pat O'Connor",
#  'Kevin Smith',
#  'Jeremy Leven',
#  'Barry Levinson',
#  'René Bonnière',
#  'John Badham',
#  'Jack Baran',
#  'Roman Polanski',
#  'Taylor Hackford',
#  'Bobby Farrelly',
#  'Ang Lee',
#  'Atom Egoyan',
#  'Garry Marshall',
#  'Tim Burton',
#  'Lawrence Kasdan',
#  'Billy Crystal',
#  'Phillip Borsos',
#  'Paul Brizzi',
#  'Brett Leonard',
#  'Carlo Carlei',
#  'Gérard Corbiau',
#  'Mark Lewis',
#  'Art Clokey',
#  'Charles Burnett',
#  'Steve James',
#  'Peter Jackson',
#  'Randall Miller',
#  'Bernard Rose',
#  'Steven Brill',
#  'J. F. Lawton',
#  'Fred Schepisi',
#  'Neil Jordan',
#  'James Ivory',
#  'James Melkonian',
#  'Ivan Reitman',
#  'Arne Glimcher',
#  'Michael Gottlieb',
#  'Barbet Schroeder',
#  'George Lucas',
#  'Gillian Armstrong',
#  'Alfonso Cuarón',
#  'Ken Loach',
#  'Claude Chabrol',
#  'Alfonso Aráu',
#  'Edward Zwick',
#  'Nick Castle',
#  'James Gray',
#  'Allison Anders',
#  'Glenn Gordon Caron',
#  'Stephen Gyllenhaal',
#  'Nicholas Hytner',
#  'Kenneth Branagh',
#  'James Orr',
#  'Nora Ephron',
#  'Richard Benjamin',
#  'Les Mayfield',
#  'David Frankel',
#  'Gregory Nava',
#  'Marc Rocco',
#  'Robert Benton',
#  'Michael Apted',
#  'Nick Gomez',
#  'Tōru Murakawa',
#  'Vadim Jean',
#  'Albert Pyun',
#  'Alan Jacobs',
#  'Oliver Stone',
#  'Norman Jewison',
#  'Lee Tamahori',
#  'Anne Goursaud',
#  'Wolfgang Petersen',
#  'Luc Besson',
#  'Mira Nair',
#  'Joshua Brand',
#  'Quentin Tarantino',
#  'Mario Van Peebles',
#  'Ang Lee',
#  'Antonia Bird',
#  'Robert Redford',
#  'Kayo Hatta',
#  'Patrice Chéreau',
#  'Sam Raimi',
#  'Peter Yates',
#  'Robert Altman',
#  'Krzysztof Kieślowski',
#  'Krzysztof Kieślowski',
#  'Krzysztof Kieślowski',
#  'He Ping',
#  'Fred Gerber',
#  'George Mihalka',
#  'Harold Ramis',
#  'Richard Rich',
#  'John Sayles',
#  'Luis Llosa',
#  'Roland Emmerich',
#  'John Pasquin',
#  'Frank Darabont',
#  'Danny Boyle',
#  'David Siegel',
#  'Juan Carlos Tabío',
#  'George Huang',
#  'Geoff Burton',
#  'Kelly Makin',
#  'Zhang Yimou',
#  'Rachel Talalay',
#  'Ernest R. Dickerson',
#  'David Carson',
#  'Rusty Cundieff',
#  'Brian Gilbert',
#  'John Carpenter',
#  'Peter Segal',
#  'Louis Malle',
#  'Steven Soderbergh',
#  'Preston A. Whitmore II',
#  'Lasse Hallström',
#  'Brett Leonard',
#  'Jon Turteltaub',
#  'Jon Avnet',
#  'Mina Shum',
#  'P.J. Hogan',
#  'Melanie Mayron',
#  'Tom Shadyac',
#  'Stephan Elliott',
#  'Iain Softley',
#  'Roman Polanski',
#  'Woody Allen',
#  'Phillip Noyce',
#  'Joel Schumacher',
#  'Jessie Nelson',
#  'Spike Lee',
#  'Alex Proyas',
#  'Ron Shelton',
#  'Brian Levant',
#  'Robert Zemeckis',
#  'Mike Newell',
#  'John Singleton',
#  'Darnell Martin',
#  'Charles Shyer',
#  'Andrew Bergman',
#  'Stephen Sommers',
#  'Ray Müller',
#  'Rob Minkoff',
#  'Bernardo Bertolucci',
#  'Wes Craven',
#  'Chuck Russell',
#  'Richard Donner',
#  'Alan Rudolph',
#  'Peter Segal',
#  'Ron Howard',
#  'Ben Stiller',
#  'John Dahl',
#  'Donald Petrie',
#  'Robert Allan Ackerman',
#  'Curtis Hanson',
#  'Jan de Bont',
#  'Ron Underwood',
#  'Peter Hyams',
#  'James Cameron',
#  'Luis Mandoki',
#  'Mike Nichols',
#  'Lawrence Kasdan',
#  'Damian Harris',
#  'Suri Krishnamma',
#  'Jefery Levy',
#  'Keenen Ivory Wayans',
#  "Raoul O'Connell",
#  'Yves Angelo',
#  'Russ Meyer',
#  'Doug McHenry',
#  'Dave Borthwick',
#  'Steven E. de Souza',
#  'Wallace Wolodarsky',
#  'Michael A. Nickles',
#  'Paul Warner',
#  'Vincent Robert',
#  'Theodore Thomas',
#  'Lucas Platt',
#  'Ross Kagan Marks',
#  'Paul Williams',
#  'Robert Wuhl',
#  'Roberto Sneider',
#  'Jefri Aalmuhammed',
#  'Andrew Morahan',
#  'Michael Corrente',
#  'John Carpenter',
#  'John G. Avildsen',
#  'Jeff Pollack',
#  'Barry Sonnenfeld',
#  'Thomas Schlamme',
#  'Martin Scorsese',
#  'Michael Lehmann',
#  'Paul Michael Glaser',
#  'John Badham',
#  'Jonathan Kaplan',
#  'Whit Stillman',
#  'Bill Forsyth',
#  'Penelope Spheeris',
#  'John Landis',
#  'Caroline Thompson',
#  'Michael Apted',
#  'Stephen Hopkins',
#  'William Friedkin',
#  'Tony Richardson',
#  'Abel Ferrara',
#  'Jennifer Chambers Lynch',
#  'Robert De Niro',
#  'Adam Resnick',
#  'John Whitesell',
#  'Brian De Palma',
#  'Paul Weiland',
#  'Mick Jackson',
#  'Renny Harlin',
#  'Steve Barron',
#  'Richard Rush',
#  'Michael Ritchie',
#  'Gregg Champion',
#  'Abel Ferrara',
#  'Ivan Reitman',
#  'Richard Linklater',
#  'Marco Brambilla',
#  'Bruce Brown',
#  'Gus Van Sant',
#  'Carl Reiner',
#  'Chen Kaige',
#  'Donald Petrie',
#  'Peter Weir',
#  'Rusty Cundieff',
#  'Alek Keshishian',
#  'Steve Kloves',
#  'John Irvin',
#  'Barry Sonnenfeld',
#  'Sydney Pollack',
#  'Simon Wincer',
#  'Boaz Yakin',
#  'Andrew Davis',
#  'Walter Hill',
#  'Roger Donaldson',
#  'Howard Deutch',
#  'Rose Troche',
#  'Bruce Beresford',
#  'Sidney Lumet',
#  'John Woo',
#  'Oliver Stone',
#  'Jim Abrahams',
#  'Julianna Lavin',
#  'Christopher Monger',
#  'Bille August',
#  'Eric Meza',
#  'Joel Coen',
#  'James L. Brooks',
#  'Daniel Petrie, Jr.',
#  'Wolfgang Petersen',
#  'Jim Sheridan',
#  'Matty Rich',
#  'Brian Gibson',
#  'Barry Levinson',
#  'Stephen Hopkins',
#  'Steven Spielberg',
#  'Dominic Sena',
#  'Roger Avary',
#  'Steven Soderbergh',
#  'Daniel Petrie',
#  'John McTiernan',
#  'James Lapine',
#  'Greg Coote',
#  'David Cronenberg',
#  'Richard Benjamin',
#  'Harold Becker',
#  'Mel Gibson',
#  'Woody Allen',
#  'Allen Hughes',
#  'Stuart Baird',
#  'Nagisa Ōshima',
#  'Tom Noonan',
#  'Kenneth Branagh',
#  'Mike Figgis',
#  'Anthony Minghella',
#  'Chris Columbus',
#  'Mike Leigh',
#  'Christopher Cain',
#  'Michael Tolkin',
#  'Martin Campbell',
#  'Rob Reiner',
#  'Sally Potter',
#  'Clint Eastwood',
#  'Jonathan Demme',
#  'Jane Campion',
#  'John Singleton',
#  'David S. Ward',
#  'Stuart Orme',
#  'Mel Smith',
#  'Ted Demme',
#  'James Ivory',
#  'Penny Marshall',
#  'Philip Kaufman',
#  'Alan Parker',
#  'Fred Dekker',
#  'Mel Brooks',
#  'Peter Medak',
#  'Geoffrey Wright',
#  'Victor Nunez',
#  'David Anspaugh',
#  'Tim Hunter',
#  'Cyril Collard',
#  'Steven Spielberg',
#  'Michael Ritchie',
#  'Steven Zaillian',
#  'Chris Menges',
#  'Agnieszka Holland',
#  'John Waters',
#  'Russell Mulcahy',
#  'Richard Attenborough',
#  'Robert Altman',
#  'Gillies MacKinnon',
#  'John Duigan',
#  'Fred Schepisi',
#  'Nora Ephron',
#  'Phillip Noyce',
#  'Ridley Scott',
#  'Steve Rash',
#  'Thomas Schlamme',
#  'Rowdy Herrington',
#  'Arthur Joffé',
#  'Rocky Morton',
#  'Ernest R. Dickerson',
#  'Deran Sarafian',
#  'François Girard',
#  'Andrew Fleming',
#  'Henry Selick',
#  'Stephen Herek',
#  'George P. Cosmatos',
#  'Heywood Gould',
#  'Tony Scott',
#  'Chris Hegedus',
#  'Maurice Hunt',
#  'Jerry Ciccoritti',
#  'Jennifer Warren',
#  'Mark Malone',
#  'Todd Solondz',
#  'Claude Berri',
#  'Dennis Hopper',
#  'Guillermo del Toro',
#  'Daniel Algrant',
#  'Pedro Almodóvar',
#  'Gurinder Chadha',
#  'Andrew Scheinman',
#  'Åke Sandgren',
#  'Richard Loncraine',
#  'Eva Sereny',
#  'Lina Wertmüller',
#  'David O. Russell',
#  'Penelope Spheeris',
#  'Rémy Duchemin',
#  'George T. Miller',
#  'Ricky Tognazzi',
#  'Michael Austin',
#  'Jeffrey Friedman',
#  'Mathieu Kassovitz',
#  'Nanni Moretti',
#  'María Luisa Bemberg',
#  'Betty Thomas',
#  'Chris Columbus',
#  'Jerry Zucker',
#  'John Musker',
#  'James Cameron',
#  'Kevin Costner',
#  'Steve Cohen',
#  'Tim Burton',
#  'Jonathan Demme',
#  'David Hand',
#  'Kirk Wise',
#  'Ben Sharpsteen',
#  'Garry Marshall',
#  'Yuri Mamin',
#  'Sam Peckinpah',
#  'C.M. Talkington',
#  'Huang Jianxin',
#  'Jean Bach',
#  'Sam Weisman',
#  'Michael Hoffman',
#  'Bill Condon',
#  'Stephen Poliakoff',
#  'Joel Coen',
#  'David R. Ellis',
#  'Gerald Potterton',
#  'Joe Chappelle',
#  'Matt Reeves',
#  'Franco Zeffirelli',
#  'Anna Campion',
#  'Franco Brusati',
#  'Wolfgang Reitherman',
#  'Pedro Almodóvar',
#  'Fernando Trueba',
#  'Bill Couturié',
#  'Werner Herzog',
#  'André Téchiné',
#  None,
#  'Mika Kaurismäki',
#  'Férid Boughedir',
#  'Martin Lawrence',
#  'Stacy Title',
#  'Gregory Hoblit',
#  'Clément Virgo',
#  'Bruno Barreto',
#  'Larry Leker',
#  'Ken Loach',
#  'Hal Salwen',
#  'Jonathan R. Betuel',
#  'Richard Pearce',
#  'Todd Verow',
#  'Jonathan Lynn',
#  'Tim Sullivan',
#  'Spike Lee',
#  'Jeremiah S. Chechik',
#  'Hervé Palud',
#  'Martin Enlen',
#  'Carlo Rola',
#  None,
#  'Claude Sautet',
#  'Edward Zwick',
#  'Brian De Palma',
#  'Friðrik Þór Friðriksson',
#  'Pen Densham',
#  'Sönke Wortmann',
#  'Park Chul-soo',
#  'Rob Cohen',
#  'Joseph Vilsmaier',
#  'Michael Verhoeven',
#  'Steve Rash',
#  'Gray Hofmeyr',
#  'Richard Wherrett',
#  'René Clément',
#  'Anthony Hopkins',
#  'Henry Selick',
#  'James Foley',
#  'Kelly Makin',
#  'Paul Mazursky',
#  'Emir Kusturica',
#  'Bo Widerberg',
#  'Alan Mehrez',
#  'Satyajit Ray',
#  'Satyajit Ray',
#  'Jim Mallon',
#  None,
#  'Joe Pytka',
#  'Roger Vadim',
#  'Catherine Cyran',
#  'Brett Piper',
#  'George Hickenlooper',
#  'Peter Yates',
#  'Jean-Luc Godard',
#  'Bertrand Tavernier',
#  'Mika Kaurismäki',
#  'Claude Chabrol',
#  'Gordon Willis',
#  'Randal Kleiser',
#  'Michael Blakemore',
#  'Simon Wincer',
#  'Margarethe von Trotta',
#  'Margarethe von Trotta',
#  'Margarethe von Trotta',
#  'Margarethe von Trotta',
#  'Richard Benjamin',
#  'Norberto Barba',
#  'Eli Cohen',
#  'Robert Mandel',
#  'Pat Verducci',
#  'Michael Winterbottom',
#  'Steven Baigelman',
#  'Zalman King',
#  'Barry Caillier',
#  'Patrick Read Johnson',
#  'Stijn Coninx',
#  'John Cassavetes',
#  'Stacy Cochran',
#  'Jean-Claude Van Damme',
#  'Mark Joffe',
#  'Steve Gomer',
#  'Lee Tamahori',
#  'Michael Lehmann',
#  'George Scribner',
#  'Tom DeCerchio',
#  'Alan Shapiro',
#  'Angela Pope',
#  'Betty Kaplan',
#  'Jim Jarmusch',
#  'Jean-Paul Rappeneau',
#  'Jack Hill ',
#  'Manuel Gómez Pereira',
#  'Jean-Marie Poiré',
#  'Harold Ramis',
#  'Brett Thompson',
#  'Spiro Scimone',
#  'Andrew Fleming',
#  'Reginald Hudlin',
#  'Bruce Beresford',
#  None,
#  'John Schlesinger',
#  'Timothy Quay',
#  'Phil Joanou',
#  'Larry Cohen',
#  'Michael Bay',
#  'Harvey Miller',
#  'Michele Soavi',
#  'Jan de Bont',
#  'David Hogan',
#  'Maurice Pialat',
#  'Gabriel Barylli',
#  'Mamoru Oshii',
#  'Tom Holland',
#  'Rick Friedberg',
#  'Udayan Prasad',
#  'Nick Park',
#  'Abraham Polonsky',
#  'John Landis',
#  'David Twohy',
#  'Robert Z. Leonard',
#  'Stanley Kubrick',
#  'Guy Maddin',
#  "John O'Brien",
#  'John Irvin',
#  'Kevin James Dobson',
#  'Victor Saville',
#  'Helena Solberg',
#  'Wong Kar-wai',
#  'Ebrahim Forouzesh',
#  'Freida Lee Mock',
#  'Joseph Vilsmaier',
#  'Simon Wincer',
#  'Andrew Bergman',
#  'David Keating',
#  'James Mangold',
#  'Francis Ford Coppola',
#  'Mary Harron',
#  'Charles Matthau',
#  'Goran Paskaljević',
#  'Benoît Lamy',
#  'Jean-Pierre Bekolo',
#  'Djibril Diop Mambéty',
#  'Gaston Kaboré',
#  'Roger Vadim',
#  'Victoria Foyt',
#  'Robby Henson',
#  'Danny Boyle',
#  'Scott Winant',
#  'Roland Emmerich',
#  'Bernardo Bertolucci',
#  'Tony Scott',
#  'Kirk Wise',
#  'Ben Stiller',
#  'Peter Farrelly',
#  'Chuck Russell',
#  'Richard Gordon',
#  'Tom Shadyac',
#  'María Luisa Bemberg',
#  'Lucian Pintilie',
#  'Gazdag Gyula',
#  'Gérard Mordillat',
#  'Mel Chionglo',
#  'Alexandre Rockwell',
#  'Christopher Larkin',
#  'Laurent Heynemann  ',
#  'Rob Cohen',
#  'Peter Jackson',
#  'John Sayles',
#  'Bronwen Hughes',
#  'Jon Turteltaub',
#  'Nicole Holofcener',
#  'Edward Burns',
#  'Joel Schumacher',
#  'Michael Corrente',
#  'Éric Rohmer',
#  'Fraser Clarke Heston',
#  'Kevin Hooks',
#  'Paul Michael Glaser',
#  'Ildikó Enyedi',
#  'Howard Franklin',
#  'Mitch Marcus',
#  'Jaime Hellman',
#  'Nicolas Roeg',
#  'Arlene Sanford',
#  'Maurizio Nichetti',
#  'Luis Buñuel',
#  'Paul Turner',
#  'Éric Rohmer',
#  'Gernot Roll',
#  'Rolf Silber',
#  'Peter Weck',
#  'Manoel de Oliveira',
#  'Steve Barron',
#  'John Payson',
#  'Hugh Wilson',
#  'Nigel Finch',
#  'Ron Howard',
#  'Hart Bochner',
#  'Doug Ellin',
#  'Annette Haywood-Carter',
#  'Andrew Davis',
#  'Danny DeVito',
#  'Douglas McGrath',
#  'Tim Pope',
#  'Harry Winer',
#  'Georges Franju',
#  'Gilbert Adler',
#  'John Rubino',
#  'Yin Li',
#  'Yim Ho',
#  'Hal Hartley',
#  'Marcus DeLeon',
#  'Lee David Zlotoff',
#  'John Carpenter',
#  'Tran Anh Hung',
#  'Julian Schnabel',
#  'Ron Shelton',
#  'Rolf de Heer',
#  'Keisuke Kinoshita',
#  'Nicole Garcia',
#  'Leone Pompucci',
#  'Zheng Jun-Li',
#  'Francis Ford Coppola',
#  'Sönke Wortmann',
#  'Stanley Tong',
#  'Lisa Krueger',
#  'Mikio Naruse',
#  'Mikio Naruse',
#  'Mikio Naruse',
#  'Mikio Naruse',
#  'Gillies MacKinnon',
#  'Lilly Wachowski',
#  'Arthur Hiller',
#  'John Ruane',
#  'Robert Altman',
#  'Christopher Cain',
#  'Peter Shaner',
#  'Tsai Ming-liang',
#  'Daniel Schmid',
#  'Tim Metcalfe',
#  'Izidore K. Musallam',
#  'Stanley Tong',
#  'Jim McKay',
#  'Karim Dridi',
#  'Peter Hyams',
#  'Richard Stanley',
#  'David M. Evans',
#  'David Koepp',
#  'Gary Winick',
#  'Norman Jewison',
#  'Ernest R. Dickerson',
#  'Nick Hamm',
#  'Roy Allen Smith',
#  'Theo van Gogh',
#  None,
#  'Joe Chappelle',
#  'Trevor Nunn',
#  'Keith Gordon',
#  'Max Ophüls',
#  'Jan Jakub Kolski',
#  'André Téchiné',
#  'Sam Wood',
#  'George Cukor',
#  'Gene Kelly',
#  'Vincente Minnelli',
#  'Stanley Donen',
#  'Blake Edwards',
#  'Alfred Hitchcock',
#  'Alfred Hitchcock',
#  'Frank Capra',
#  'George Cukor',
#  'Mark Sandrich',
#  'Alfred Hitchcock',
#  'Billy Wilder',
#  'Billy Wilder',
#  'Stanley Donen',
#  'Michael Curtiz',
#  'John Huston',
#  'George Cukor',
#  'Billy Wilder',
#  'William Wyler',
#  'Walter Lang',
#  'Vincente Minnelli',
#  'Victor Fleming',
#  'Victor Fleming',
#  'Richard Benjamin',
#  'Billy Wilder',
#  'Orson Welles',
#  'Stanley Kubrick',
#  'Mitchell Leisen',
#  'Joseph L. Mankiewicz',
#  'George Cukor',
#  'Alfred Hitchcock',
#  'Alfred Hitchcock',
#  'Alfred Hitchcock',
#  'Alfred Hitchcock',
#  'Leo McCarey',
#  'Alfred Hitchcock',
#  'Vincente Minnelli',
#  'Vincente Minnelli',
#  'Ernst Lubitsch',
#  'Billy Wilder',
#  'Vincente Minnelli',
#  'Vincente Minnelli',
#  'William Keighley',
#  'Rouben Mamoulian',
#  'Otto Preminger',
#  'Joseph L. Mankiewicz',
#  'Frank Capra',
#  'Mark Sandrich',
#  'Ernst Lubitsch',
#  'Gregory La Cava',
#  'George Stevens',
#  'Elia Kazan',
#  'W.S. Van Dyke',
#  'Howard Hawks',
#  'Michael Anderson',
#  'Frank Capra',
#  'Frank Capra',
#  'Howard Hawks',
#  'George Stevens',
#  'Victor Sjöström',
#  'William A. Wellman',
#  'John Cromwell',
#  'Archie Mayo',
#  'John Cromwell',
#  'Busby Berkeley',
#  'Henry Koster',
#  'James Edward Grant',
#  'Alfred Hitchcock',
#  'Lewis Milestone',
#  'Howard Hughes',
#  'George A. Romero',
#  'John Huston',
#  'John Huston',
#  'Richard Brooks',
#  'Richard Brooks',
#  'Frank Capra',
#  'John Cromwell',
#  'Victor Schertzinger',
#  'Frank Borzage',
#  'Frank Borzage',
#  'Frank Borzage',
#  'Frank Borzage',
#  'Edwin L. Marin',
#  "Thaddeus O'Sullivan",
#  'Corey Yuen Kwai',
#  'Darrell James Roodt',
#  'Joshua Logan',
#  'Chris Newby',
#  'Richard Schenkman',
#  'Allan Miller',
#  'Carroll Ballard',
#  'Lance Young',
#  'Allison Anders',
#  'Joseph Vilsmaier',
#  'Ringo Lam',
#  'Neil Jordan',
#  'Amy Holden Jones',
#  'Matthew Broderick',
#  'Campbell Scott',
#  'Walter Hill',
#  'Robert M. Young',
#  'F. Gary Gray',
#  'John Herzfeld',
#  'Reb Braddock',
#  'René Gainville',
#  'John Walsh',
#  'Michael Apted',
#  'John Gray',
#  'Robert Lieberman',
#  'James Foley',
#  'Norman Tokar',
#  'Norman Foster',
#  'John Hough',
#  'Robert Stevenson',
#  'Robert Stevenson',
#  'Robert Stevenson',
#  'David Swift',
#  'David Swift',
#  'Duwayne Dunham',
#  'Charles Barton',
#  'Ken Annakin',
#  'Robert Stevenson',
#  'Richard Fleischer',
#  ...]

# %%
movies_credits['director'] = director_list

# %%
del movies_credits['crew']

# %%
cast_list = []
for i,m in movies_credits.iterrows():
    x = ast.literal_eval(m['cast'])
    #print(x)
    temp = {}
    for y in x:
        temp[y['order']] = y['name']
    for key, val in temp.items(): 
        if int(key) >= 0 and int(key) <= 4: 
            cast_list.append(val)
        else:
            cast_list.append(None)

# %%
cast_list = []
for i,m in movies_credits.iterrows():
    x = ast.literal_eval(m['cast'])
    if len(x) > 4:
        y = x[:5]
    else:
        y = x
    temp = ''
    for el in y:
        temp = temp + el['name'] + ','
    temp = temp[:-1]
    cast_list.append(temp)

# %%
cast_list[0].split(',')
# Out:
# ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim Varney', 'Wallace Shawn']

# %%
movies_credits['cast'] = cast_list

# %%
top_actor_list = pd.read_csv('Top_1000_Actors_Actresses.csv', header=0, encoding = "ISO-8859-1")

# %%
a_list = top_actor_list.loc[top_actor_list['Position'] <= 500]
a_list_actors = a_list['Name'].tolist()

# %%
b_list = top_actor_list.loc[top_actor_list['Position'] > 500]
b_list_actors = b_list['Name'].tolist()

# %%
a_list_count = []
for i,m in movies_credits.iterrows():
    a_list_match = []
    for x in m['cast'].split(','):
        if x in a_list_actors:
            a_list_match.append(1)
    a_list_count.append(sum(a_list_match))

# %%
movies_credits['a_list_sum'] = a_list_count

# %%
b_list_count = []
for i,m in movies_credits.iterrows():
    b_list_match = []
    for x in m['cast'].split(','):
        if x in b_list_actors:
            b_list_match.append(1)
    b_list_count.append(sum(b_list_match))

# %%
movies_credits['b_list_sum'] = b_list_count

# %%
movies_credits['budget'] = movies_credits['budget'].astype(float)

# %%
movies_credits
# Out:
#        adult      budget  movieId    imdb_id original_language  popularity  \
# 0      False  30000000.0      862  tt0114709                en   21.946943
# 1      False  65000000.0     8844  tt0113497                en   17.015539
# 2      False         0.0    15602  tt0113228                en   11.712900
# 3      False  16000000.0    31357  tt0114885                en    3.859495
# 4      False         0.0    11862  tt0113041                en    8.387519
# ...      ...         ...      ...        ...               ...         ...
# 45533  False         0.0   439050  tt6209470                fa    0.072051
# 45534  False         0.0   111109  tt2028550                tl    0.178241
# 45535  False         0.0    67758  tt0303758                en    0.903007
# 45536  False         0.0   227506  tt0008536                en    0.003503
# 45537  False         0.0   461257  tt6980792                en    0.163015
#
#                                     production_companies release_date  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]   1995-10-30
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...   1995-12-15
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   1995-12-22
# 3      [{'name': 'Twentieth Century Fox Film Corporat...   1995-12-22
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...   1995-02-10
# ...                                                  ...          ...
# 45533                                                 []          NaN
# 45534             [{'name': 'Sine Olivia', 'id': 19653}]   2011-11-17
# 45535  [{'name': 'American World Pictures', 'id': 6165}]   2003-08-01
# 45536               [{'name': 'Yermoliev', 'id': 88753}]   1917-10-21
# 45537                                                 []   2017-06-09
#
#            revenue  runtime                        title  vote_average  \
# 0      373554033.0     81.0                    Toy Story           7.7
# 1      262797249.0    104.0                      Jumanji           6.9
# 2              0.0    101.0             Grumpier Old Men           6.5
# 3       81452156.0    127.0            Waiting to Exhale           6.1
# 4       76578911.0    106.0  Father of the Bride Part II           5.7
# ...            ...      ...                          ...           ...
# 45533          0.0     90.0                       Subdue           4.0
# 45534          0.0    360.0          Century of Birthing           9.0
# 45535          0.0     90.0                     Betrayal           3.8
# 45536          0.0     87.0             Satan Triumphant           0.0
# 45537          0.0     75.0                     Queerama           0.0
#
#        vote_count                                               cast  \
# 0          5415.0  Tom Hanks,Tim Allen,Don Rickles,Jim Varney,Wal...
# 1          2413.0  Robin Williams,Jonathan Hyde,Kirsten Dunst,Bra...
# 2            92.0  Walter Matthau,Jack Lemmon,Ann-Margret,Sophia ...
# 3            34.0  Whitney Houston,Angela Bassett,Loretta Devine,...
# 4           173.0  Steve Martin,Diane Keaton,Martin Short,Kimberl...
# ...           ...                                                ...
# 45533         1.0            Leila Hatami,Kourosh Tahami,Elham Korda
# 45534         3.0  Angel Aquino,Perry Dizon,Hazel Orencio,Joel To...
# 45535         6.0  Erika Eleniak,Adam Baldwin,Julie du Page,James...
# 45536         0.0  Iwan Mosschuchin,Nathalie Lissenko,Pavel Pavlo...
# 45537         0.0
#
#        new_genres                       collection          director  \
# 0       Animation             Toy Story Collection     John Lasseter
# 1       Adventure                             None      Joe Johnston
# 2         Romance        Grumpy Old Men Collection     Howard Deutch
# 3          Comedy                             None   Forest Whitaker
# 4          Comedy   Father of the Bride Collection     Charles Shyer
# ...           ...                              ...               ...
# 45533       Drama                             None  Hamid Nematollah
# 45534       Drama                             None          Lav Diaz
# 45535      Action                             None    Mark L. Lester
# 45536        None                             None  Yakov Protazanov
# 45537        None                             None     Daisy Asquith
#
#        a_list_sum  b_list_sum
# 0               1           1
# 1               2           1
# 2               4           0
# 3               1           1
# 4               2           0
# ...           ...         ...
# 45533           0           0
# 45534           0           0
# 45535           0           0
# 45536           0           0
# 45537           0           0
#
# [45538 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import r2_score, mean_squared_error
import scipy.stats as stats

# %%
X, y = movies_credits, movies_credits['vote_average']
X, X_test, y, y_test = train_test_split(X, y, test_size=.25, random_state=20)

# %%
movies_credits.to_csv('movies_credits_actors', index=False)
